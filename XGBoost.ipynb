# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import (log_loss, brier_score_loss, roc_auc_score, accuracy_score)
import optuna

# %%
# Expected Calibration Error (ECE): Good way of measuring probability calibration (check readme for betetr description)
def expected_calibration_error(y_out, y_prob, n_bins=10, return_bins=False):
    y_out = np.asarray(y_out).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    m = ~np.isnan(y_prob)
    y_out = y_out[m]
    y_prob = y_prob[m]
    bin_edges = np.linspace(0.0, 1.0, n_bins + 1)
    bin_ids = np.digitize(y_prob, bin_edges, right=True) - 1
    bin_ids = np.clip(bin_ids, 0, n_bins - 1)
    acc = np.full(n_bins, np.nan)
    conf = np.full(n_bins, np.nan)
    counts = np.zeros(n_bins, dtype=int)
    n = len(y_out)
    ece = 0.0

    for b in range(n_bins):
        idx = bin_ids == b
        counts[b] = idx.sum()
        if counts[b] > 0:
            acc[b] = y_out[idx].mean()
            conf[b] = y_prob[idx].mean()
            ece += (counts[b] / n) * abs(acc[b] - conf[b])
    if return_bins:
        return ece, acc, conf, counts, bin_edges
    return ece

#Plot reliability diagram and a probability histogram 
def reliability_diagram(y_out,y_prob,n_bins=10,hist_bins=30,title="Reliability Diagram"):
    
    ece, acc, conf, counts, bin_edges = expected_calibration_error(y_out, y_prob, n_bins=n_bins, return_bins=True)
    centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    width = (bin_edges[1] - bin_edges[0]) * 0.9
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 7),gridspec_kw={"height_ratios": [3, 2]})

    #reliability diagram
    ax1.plot([0, 1], [0, 1], linestyle="--", linewidth=2, label="Perfect calibration")
    ax1.bar(centers, np.nan_to_num(acc, nan=0.0), width=width, label="Accuracy")
    bottom = np.nan_to_num(np.minimum(acc, conf), nan=0.0)
    height = np.nan_to_num(np.abs(acc - conf), nan=0.0)
    ax1.bar(centers, height, bottom=bottom, width=width, hatch="xx", alpha=0.35,color="tab:red", label="Gap")
    ax1.set_xlim(0, 1)
    ax1.set_ylim(0, 1)
    ax1.set_xlabel("Confidence")
    ax1.set_ylabel("Accuracy")
    ax1.set_title(title)

    # Display ECE in percentage points
    ax1.text(0.62, 0.06, f"ECE={ece*100:.2f}",
        transform=ax1.transAxes,
        bbox=dict(boxstyle="round", facecolor="white", alpha=0.85))
    ax1.legend(loc="upper left")

    #probability histogram 
    ax2.hist(y_prob, bins=hist_bins)
    ax2.set_xlim(0, 1)
    ax2.set_xlabel("Predicted probability")
    ax2.set_ylabel("Count")
    ax2.set_title("Predicted probability distribution")
    plt.tight_layout()
    plt.show()

    return ece

# %%
data = pd.read_csv("Train_Test/final.csv")

X = data.drop(columns=["result"]).values
y = data["result"].astype(int).values

X = np.asarray(X)
y = np.asarray(y).astype(int)


def ts_cv_oof_probs(params, n_splits=5):
    tscv = TimeSeriesSplit(n_splits=n_splits)
    oof = np.full(len(y), np.nan, dtype=float)

    for train_idx, test_idx in tscv.split(X):
        model = XGBClassifier(
            **params,
            objective="binary:logistic",
            eval_metric="logloss",
            tree_method="hist",
            random_state=42,
            n_jobs=-1
        )
        model.fit(X[train_idx], y[train_idx])
        oof[test_idx] = model.predict_proba(X[test_idx])[:, 1]

    return oof

def ts_cv_logloss(params, n_splits=5):
    oof = ts_cv_oof_probs(params, n_splits)
    m = ~np.isnan(oof)
    return log_loss(y[m], oof[m])

def ts_cv_error_rate(params, n_splits=5):
    oof = ts_cv_oof_probs(params, n_splits)
    m = ~np.isnan(oof)
    preds = (oof[m] >= 0.5).astype(int)
    return 1.0 - accuracy_score(y[m], preds)

# %%
# LOG-LOSS OPTIMIZATION

def objective(trial):
    params = {
        "max_depth": trial.suggest_int("max_depth", 2, 8),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "min_child_weight": trial.suggest_float("min_child_weight", 1.0, 10.0),
        "n_estimators": trial.suggest_int("n_estimators", 300, 1500),
    }

    ll = ts_cv_logloss(params, n_splits=3)
    return ll

study1 = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study1.optimize(objective, n_trials=50) 

print("Best params:", study1.best_params)
print("Best CV log loss:", study1.best_value)
# Out:
# [I 2026-01-02 22:07:13,510] A new study created in memory with name: no-name-83ffb646-0c69-46d0-8429-6616f28ada3b
# [I 2026-01-02 22:07:22,494] Trial 0 finished with value: 0.6340503718467179 and parameters: {'max_depth': 4, 'learning_rate': 0.22648248189516842, 'subsample': 0.8927975767245621, 'colsample_bytree': 0.8394633936788146, 'min_child_weight': 2.4041677639819286, 'n_estimators': 487}. Best is trial 0 with value: 0.6340503718467179.
# [I 2026-01-02 22:07:37,874] Trial 1 finished with value: 0.6114144792339857 and parameters: {'max_depth': 2, 'learning_rate': 0.13983740016490975, 'subsample': 0.8404460046972835, 'colsample_bytree': 0.8832290311184182, 'min_child_weight': 1.185260448662222, 'n_estimators': 1464}. Best is trial 1 with value: 0.6114144792339857.
# [I 2026-01-02 22:08:24,126] Trial 2 finished with value: 0.6002285713316878 and parameters: {'max_depth': 7, 'learning_rate': 0.0033572967053517922, 'subsample': 0.6727299868828402, 'colsample_bytree': 0.6733618039413735, 'min_child_weight': 3.7381801866358395, 'n_estimators': 930}. Best is trial 2 with value: 0.6002285713316878.
# [I 2026-01-02 22:08:47,931] Trial 3 finished with value: 0.5997870374348045 and parameters: {'max_depth': 5, 'learning_rate': 0.005265139631677754, 'subsample': 0.8447411578889518, 'colsample_bytree': 0.6557975442608167, 'min_child_weight': 3.629301836816963, 'n_estimators': 740}. Best is trial 3 with value: 0.5997870374348045.
# [I 2026-01-02 22:09:00,105] Trial 4 finished with value: 0.6092983379829194 and parameters: {'max_depth': 5, 'learning_rate': 0.08810003129071789, 'subsample': 0.6798695128633439, 'colsample_bytree': 0.8056937753654446, 'min_child_weight': 6.331731119758382, 'n_estimators': 355}. Best is trial 3 with value: 0.5997870374348045.
# [I 2026-01-02 22:11:00,244] Trial 5 finished with value: 0.5997765515833928 and parameters: {'max_depth': 6, 'learning_rate': 0.0026448980183927102, 'subsample': 0.6260206371941118, 'colsample_bytree': 0.9795542149013333, 'min_child_weight': 9.690688297671034, 'n_estimators': 1270}. Best is trial 5 with value: 0.5997765515833928.
# [I 2026-01-02 22:11:50,395] Trial 6 finished with value: 0.6118260062314419 and parameters: {'max_depth': 4, 'learning_rate': 0.0017456037635797405, 'subsample': 0.8736932106048627, 'colsample_bytree': 0.7760609974958405, 'min_child_weight': 2.0983441136030097, 'n_estimators': 894}. Best is trial 5 with value: 0.5997765515833928.
# [I 2026-01-02 22:12:06,804] Trial 7 finished with value: 0.6116168313942779 and parameters: {'max_depth': 2, 'learning_rate': 0.1788532743297921, 'subsample': 0.7035119926400067, 'colsample_bytree': 0.8650089137415928, 'min_child_weight': 3.8053996848046987, 'n_estimators': 924}. Best is trial 5 with value: 0.5997765515833928.
# [I 2026-01-02 22:12:48,588] Trial 8 finished with value: 0.5999113856057774 and parameters: {'max_depth': 5, 'learning_rate': 0.002870165242185818, 'subsample': 0.9878338511058234, 'colsample_bytree': 0.9100531293444458, 'min_child_weight': 9.455490474077703, 'n_estimators': 1374}. Best is trial 5 with value: 0.5997765515833928.
# [I 2026-01-02 22:13:10,312] Trial 9 finished with value: 0.7243519797457543 and parameters: {'max_depth': 6, 'learning_rate': 0.19212959255386386, 'subsample': 0.6353970008207678, 'colsample_bytree': 0.678393144967658, 'min_child_weight': 1.4070456001948426, 'n_estimators': 690}. Best is trial 5 with value: 0.5997765515833928.
# [I 2026-01-02 22:14:22,715] Trial 10 finished with value: 0.6054392185887589 and parameters: {'max_depth': 8, 'learning_rate': 0.01487610271655032, 'subsample': 0.747491509088439, 'colsample_bytree': 0.9820579316166452, 'min_child_weight': 9.855066118782934, 'n_estimators': 1239}. Best is trial 5 with value: 0.5997765515833928.
# [I 2026-01-02 22:15:24,390] Trial 11 finished with value: 0.5995827670747654 and parameters: {'max_depth': 6, 'learning_rate': 0.009378932289269854, 'subsample': 0.7763158241762175, 'colsample_bytree': 0.6052706929853362, 'min_child_weight': 6.972052469409832, 'n_estimators': 1137}. Best is trial 11 with value: 0.5995827670747654.
# [I 2026-01-02 22:16:28,656] Trial 12 finished with value: 0.6012233909185074 and parameters: {'max_depth': 7, 'learning_rate': 0.01191113516325091, 'subsample': 0.7890856026631795, 'colsample_bytree': 0.6080121909938832, 'min_child_weight': 7.824532344488821, 'n_estimators': 1169}. Best is trial 11 with value: 0.5995827670747654.
# [I 2026-01-02 22:17:49,675] Trial 13 finished with value: 0.6217778912033657 and parameters: {'max_depth': 7, 'learning_rate': 0.03979831790194308, 'subsample': 0.6291133553272192, 'colsample_bytree': 0.9995058837473269, 'min_child_weight': 7.944977289312444, 'n_estimators': 1157}. Best is trial 11 with value: 0.5995827670747654.
# [I 2026-01-02 22:18:59,159] Trial 14 finished with value: 0.608452653999045 and parameters: {'max_depth': 6, 'learning_rate': 0.0012111454708039907, 'subsample': 0.7545371496856135, 'colsample_bytree': 0.7509860916746386, 'min_child_weight': 6.240957978736688, 'n_estimators': 1307}. Best is trial 11 with value: 0.5995827670747654.
# [I 2026-01-02 22:19:41,244] Trial 15 finished with value: 0.5992394536891235 and parameters: {'max_depth': 6, 'learning_rate': 0.006461077012942123, 'subsample': 0.9259134876019591, 'colsample_bytree': 0.9417252951066649, 'min_child_weight': 8.286210265178028, 'n_estimators': 1074}. Best is trial 15 with value: 0.5992394536891235.
# [I 2026-01-02 22:20:48,322] Trial 16 finished with value: 0.6007246707781907 and parameters: {'max_depth': 8, 'learning_rate': 0.006906653771056682, 'subsample': 0.9654410343761857, 'colsample_bytree': 0.9340612845693029, 'min_child_weight': 7.968691172532845, 'n_estimators': 1034}. Best is trial 15 with value: 0.5992394536891235.
. Best is trial 24 with value: 0.5986536518660278.
# [I 2026-01-02 22:35:55,129] Trial 40 finished with value: 0.5988860519494342 and parameters: {'max_depth': 4, 'learning_rate': 0.007609082457315417, 'subsample': 0.7402390824886863, 'colsample_bytree': 0.7872533483023878, 'min_child_weight': 6.5067383313966065, 'n_estimators': 1376}. Best is trial 24 with value: 0.5986536518660278.
# [I 2026-01-02 22:36:35,521] Trial 41 finished with value: 0.5987530988387068 and parameters: {'max_depth': 5, 'learning_rate': 0.00571684464925064, 'subsample': 0.7196757742444407, 'colsample_bytree': 0.891715836823192, 'min_child_weight': 8.958194504646638, 'n_estimators': 1436}. Best is trial 24 with value: 0.5986536518660278.
# [I 2026-01-02 22:37:13,221] Trial 42 finished with value: 0.5986200658377498 and parameters: {'max_depth': 5, 'learning_rate': 0.0052666819596050175, 'subsample': 0.6989504701254187, 'colsample_bytree': 0.9416938812662302, 'min_child_weight': 9.8950776142487, 'n_estimators': 1416}. Best is trial 42 with value: 0.5986200658377498.
# [I 2026-01-02 22:37:51,339] Trial 43 finished with value: 0.5996303899403328 and parameters: {'max_depth': 5, 'learning_rate': 0.0029254661836359847, 'subsample': 0.6996826268513696, 'colsample_bytree': 0.9518918420694135, 'min_child_weight': 9.895958721404028, 'n_estimators': 1295}. Best is trial 42 with value: 0.5986200658377498.
# [I 2026-01-02 22:38:37,094] Trial 44 finished with value: 0.6027542943242123 and parameters: {'max_depth': 6, 'learning_rate': 0.01563043922926506, 'subsample': 0.6504351616491002, 'colsample_bytree': 0.9740605346002869, 'min_child_weight': 9.605417844268663, 'n_estimators': 1348}. Best is trial 42 with value: 0.5986200658377498.
# [I 2026-01-02 22:39:13,561] Trial 45 finished with value: 0.5991655594278776 and parameters: {'max_depth': 4, 'learning_rate': 0.004128258079479357, 'subsample': 0.8101085267661466, 'colsample_bytree': 0.9217520013762401, 'min_child_weight': 3.099364159016779, 'n_estimators': 1415}. Best is trial 42 with value: 0.5986200658377498.
# [I 2026-01-02 22:39:51,618] Trial 46 finished with value: 0.8128184827591823 and parameters: {'max_depth': 6, 'learning_rate': 0.2886507305899359, 'subsample': 0.7724746202502178, 'colsample_bytree': 0.9843570646294649, 'min_child_weight': 9.546133893779682, 'n_estimators': 983}. Best is trial 42 with value: 0.5986200658377498.
# [I 2026-01-02 22:40:38,296] Trial 47 finished with value: 0.6011316724054351 and parameters: {'max_depth': 5, 'learning_rate': 0.002268964575314779, 'subsample': 0.6883570686331626, 'colsample_bytree': 0.945747433211429, 'min_child_weight': 8.810456167655891, 'n_estimators': 1266}. Best is trial 42 with value: 0.5986200658377498.
# [I 2026-01-02 22:41:15,160] Trial 48 finished with value: 0.5987370645801435 and parameters: {'max_depth': 5, 'learning_rate': 0.005320972055121835, 'subsample': 0.7412557651245785, 'colsample_bytree': 0.8516789324828022, 'min_child_weight': 7.965910828628027, 'n_estimators': 1462}. Best is trial 42 with value: 0.5986200658377498.
# [I 2026-01-02 22:42:01,836] Trial 49 finished with value: 0.5997983075778124 and parameters: {'max_depth': 6, 'learning_rate': 0.008845997341125655, 'subsample': 0.7493108769623192, 'colsample_bytree': 0.8453825050867296, 'min_child_weight': 8.09266503507714, 'n_estimators': 1206}. Best is trial 42 with value: 0.5986200658377498.
# Best params: {'max_depth': 5, 'learning_rate': 0.0052666819596050175, 'subsample': 0.6989504701254187, 'colsample_bytree': 0.9416938812662302, 'min_child_weight': 9.8950776142487, 'n_estimators': 1416}
# Best CV log loss: 0.5986200658377498

# %%
best_params1 = study1.best_params
oof_probs1 = ts_cv_oof_probs(best_params1, n_splits=10)

m = ~np.isnan(oof_probs1)
oof_logloss = log_loss(y[m], oof_probs1[m])
oof_acc = accuracy_score(y[m], (oof_probs1[m] >= 0.5).astype(int))
oof_error_rate = 1.0 - oof_acc
ece = expected_calibration_error(y, oof_probs1, n_bins=10)

print(f"OOF log loss: {oof_logloss}")
print(f"OOF accuracy: {oof_acc}")
print(f"OOF error rate: {oof_error_rate}")
print(f"OOF ECE: {ece}")
print(f"OOF ECE (% points): {ece*100}")

figurea = reliability_diagram(y, oof_probs1, n_bins=10, title="XGBoost Log-Loss Optimized Test Calibration")
# Out:
# OOF log loss: 0.601638454557524
# OOF accuracy: 0.6698500576701268
# OOF error rate: 0.33014994232987316
# OOF ECE: 0.003509692946726044
# OOF ECE (% points): 0.3509692946726044

# %%
# ERROR RATE OPTIMIZATION
def objective(trial):
    params = {
        "max_depth": trial.suggest_int("max_depth", 2, 8),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "min_child_weight": trial.suggest_float("min_child_weight", 1.0, 10.0),
        "n_estimators": trial.suggest_int("n_estimators", 300, 1500),
    }

    err = ts_cv_error_rate(params, n_splits=3)
    return err

study2 = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study2.optimize(objective, n_trials=50) 

print("Best params:", study2.best_params)
print("Best CV Error Rate:", study2.best_value)
# Out:
# [I 2026-01-02 22:55:29,120] A new study created in memory with name: no-name-8c4f5d45-6fdd-4e37-8464-027535384943
# [I 2026-01-02 22:55:38,184] Trial 0 finished with value: 0.34894937717569097 and parameters: {'max_depth': 4, 'learning_rate': 0.22648248189516842, 'subsample': 0.8927975767245621, 'colsample_bytree': 0.8394633936788146, 'min_child_weight': 2.4041677639819286, 'n_estimators': 487}. Best is trial 0 with value: 0.34894937717569097.
# [I 2026-01-02 22:55:53,019] Trial 1 finished with value: 0.3381565518880454 and parameters: {'max_depth': 2, 'learning_rate': 0.13983740016490975, 'subsample': 0.8404460046972835, 'colsample_bytree': 0.8832290311184182, 'min_child_weight': 1.185260448662222, 'n_estimators': 1464}. Best is trial 1 with value: 0.3381565518880454.
# [I 2026-01-02 22:56:42,179] Trial 2 finished with value: 0.3293069943659215 and parameters: {'max_depth': 7, 'learning_rate': 0.0033572967053517922, 'subsample': 0.6727299868828402, 'colsample_bytree': 0.6733618039413735, 'min_child_weight': 3.7381801866358395, 'n_estimators': 930}. Best is trial 2 with value: 0.3293069943659215.
# [I 2026-01-02 22:57:25,945] Trial 3 finished with value: 0.32888758405681606 and parameters: {'max_depth': 5, 'learning_rate': 0.005265139631677754, 'subsample': 0.8447411578889518, 'colsample_bytree': 0.6557975442608167, 'min_child_weight': 3.629301836816963, 'n_estimators': 740}. Best is trial 3 with value: 0.32888758405681606.
# [I 2026-01-02 22:57:42,019] Trial 4 finished with value: 0.33762529882984527 and parameters: {'max_depth': 5, 'learning_rate': 0.08810003129071789, 'subsample': 0.6798695128633439, 'colsample_bytree': 0.8056937753654446, 'min_child_weight': 6.331731119758382, 'n_estimators': 355}. Best is trial 3 with value: 0.32888758405681606.
# [I 2026-01-02 22:58:37,991] Trial 5 finished with value: 0.32916719092955304 and parameters: {'max_depth': 6, 'learning_rate': 0.0026448980183927102, 'subsample': 0.6260206371941118, 'colsample_bytree': 0.9795542149013333, 'min_child_weight': 9.690688297671034, 'n_estimators': 1270}. Best is trial 3 with value: 0.32888758405681606.
# [I 2026-01-02 22:59:03,023] Trial 6 finished with value: 0.3306211466677851 and parameters: {'max_depth': 4, 'learning_rate': 0.0017456037635797405, 'subsample': 0.8736932106048627, 'colsample_bytree': 0.7760609974958405, 'min_child_weight': 2.0983441136030097, 'n_estimators': 894}. Best is trial 3 with value: 0.32888758405681606.
# [I 2026-01-02 22:59:15,029] Trial 7 finished with value: 0.3378350039843979 and parameters: {'max_depth': 2, 'learning_rate': 0.1788532743297921, 'subsample': 0.7035119926400067, 'colsample_bytree': 0.8650089137415928, 'min_child_weight': 3.8053996848046987, 'n_estimators': 924}. Best is trial 3 with value: 0.32888758405681606.
# [I 2026-01-02 22:59:55,548] Trial 8 finished with value: 0.3296005815822953 and parameters: {'max_depth': 5, 'learning_rate': 0.002870165242185818, 'subsample': 0.9878338511058234, 'colsample_bytree': 0.9100531293444458, 'min_child_weight': 9.455490474077703, 'n_estimators': 1374}. Best is trial 3 with value: 0.32888758405681606.
# [I 2026-01-02 23:00:17,913] Trial 9 finished with value: 0.3595324973087839 and parameters: {'max_depth': 6, 'learning_rate': 0.19212959255386386, 'subsample': 0.6353970008207678, 'colsample_bytree': 0.678393144967658, 'min_child_weight': 1.4070456001948426, 'n_estimators': 690}. Best is trial 3 with value: 0.32888758405681606.
# [I 2026-01-02 23:01:21,504] Trial 10 finished with value: 0.3311523997259853 and parameters: {'max_depth': 8, 'learning_rate': 0.013974247277478223, 'subsample': 0.7719908794019466, 'colsample_bytree': 0.6071847502459278, 'min_child_weight': 6.380929601266475, 'n_estimators': 1128}. Best is trial 3 with value: 0.32888758405681606.
# [I 2026-01-02 23:02:10,560] Trial 11 finished with value: 0.32923709264773726 and parameters: {'max_depth': 6, 'learning_rate': 0.009378932289269854, 'subsample': 0.7763158241762175, 'colsample_bytree': 0.9983179421021507, 'min_child_weight': 9.931637050154507, 'n_estimators': 1209}. Best is trial 3 with value: 0.32888758405681606.
# [I 2026-01-02 23:02:28,586] Trial 12 finished with value: 0.32846817374771076 and parameters: {'max_depth': 4, 'learning_rate': 0.005295538311222704, 'subsample': 0.9770670017204383, 'colsample_bytree': 0.9777271173783676, 'min_child_weight': 7.832070110558008, 'n_estimators': 673}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:02:38,465] Trial 13 finished with value: 0.32989416879866906 and parameters: {'max_depth': 3, 'learning_rate': 0.03979831790194308, 'subsample': 0.976007343095396, 'colsample_bytree': 0.7382774980993067, 'min_child_weight': 7.839479925579493, 'n_estimators': 629}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:02:55,545] Trial 14 finished with value: 0.3287617609640845 and parameters: {'max_depth': 4, 'learning_rate': 0.00987457031404807, 'subsample': 0.9170568439631313, 'colsample_bytree': 0.9392227666815668, 'min_child_weight': 4.962737807561268, 'n_estimators': 705}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:03:05,595] Trial 15 finished with value: 0.32908330886773196 and parameters: {'max_depth': 3, 'learning_rate': 0.033991535575107694, 'subsample': 0.9311253818964451, 'colsample_bytree': 0.9359564995033216, 'min_child_weight': 8.148510361271079, 'n_estimators': 532}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:03:29,679] Trial 16 finished with value: 0.3290413678368215 and parameters: {'max_depth': 4, 'learning_rate': 0.009544751692140387, 'subsample': 0.9337585570065023, 'colsample_bytree': 0.9482282539305692, 'min_child_weight': 5.512355217410985, 'n_estimators': 814}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:03:37,226] Trial 17 finished with value: 0.32897146611863715 and parameters: {'max_depth': 3, 'learning_rate': 0.03236914406369151, 'subsample': 0.9281889012746768, 'colsample_bytree': 0.9493053024643935, 'min_child_weight': 7.666524056651884, 'n_estimators': 307}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:04:06,264] Trial 18 finished with value: 0.33186539725146447 and parameters: {'max_depth': 4, 'learning_rate': 0.0013061305556121279, 'subsample': 0.9933461999552865, 'colsample_bytree': 0.9027898473777111, 'min_child_weight': 6.592854264814066, 'n_estimators': 1054}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23
. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:08:20,084] Trial 32 finished with value: 0.3291532105859162 and parameters: {'max_depth': 2, 'learning_rate': 0.010256168140702494, 'subsample': 0.9591211443788257, 'colsample_bytree': 0.9708177493417772, 'min_child_weight': 2.304076119648517, 'n_estimators': 798}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:08:29,387] Trial 33 finished with value: 0.3288456430259056 and parameters: {'max_depth': 3, 'learning_rate': 0.024412246532965552, 'subsample': 0.8535215197047613, 'colsample_bytree': 0.9064406701000566, 'min_child_weight': 3.0666664284244862, 'n_estimators': 579}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:08:39,031] Trial 34 finished with value: 0.32890156440045293 and parameters: {'max_depth': 3, 'learning_rate': 0.01244533282347473, 'subsample': 0.8507830681665114, 'colsample_bytree': 0.9146177965436375, 'min_child_weight': 3.0428629638796756, 'n_estimators': 570}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:08:56,939] Trial 35 finished with value: 0.3301178542968586 and parameters: {'max_depth': 5, 'learning_rate': 0.027038222230638922, 'subsample': 0.8630821671418691, 'colsample_bytree': 0.840063443783597, 'min_child_weight': 3.2799113183503286, 'n_estimators': 660}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:09:25,278] Trial 36 finished with value: 0.3289994268059109 and parameters: {'max_depth': 4, 'learning_rate': 0.004064683202404571, 'subsample': 0.7982814719475396, 'colsample_bytree': 0.9696680311444408, 'min_child_weight': 1.7839647267443248, 'n_estimators': 876}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:09:35,242] Trial 37 finished with value: 0.3320751024060171 and parameters: {'max_depth': 4, 'learning_rate': 0.06185061647864665, 'subsample': 0.899709558054135, 'colsample_bytree': 0.7013952542511458, 'min_child_weight': 2.5746091427023767, 'n_estimators': 396}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:09:55,811] Trial 38 finished with value: 0.3286359378713529 and parameters: {'max_depth': 5, 'learning_rate': 0.007365308437947321, 'subsample': 0.8348137293015416, 'colsample_bytree': 0.7807905778563413, 'min_child_weight': 4.138651101082805, 'n_estimators': 525}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:10:08,440] Trial 39 finished with value: 0.3292231123041004 and parameters: {'max_depth': 3, 'learning_rate': 0.0077369133229943585, 'subsample': 0.7432619046210834, 'colsample_bytree': 0.7816886739604733, 'min_child_weight': 4.131322148178396, 'n_estimators': 500}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:10:34,560] Trial 40 finished with value: 0.3293768960841057 and parameters: {'max_depth': 5, 'learning_rate': 0.0030584104016910226, 'subsample': 0.8354245733382515, 'colsample_bytree': 0.8699099595001875, 'min_child_weight': 7.196515123295161, 'n_estimators': 600}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:11:10,998] Trial 41 finished with value: 0.33006193292231123 and parameters: {'max_depth': 6, 'learning_rate': 0.004756090628313091, 'subsample': 0.877675856948471, 'colsample_bytree': 0.9002118397123064, 'min_child_weight': 5.1045536046440185, 'n_estimators': 677}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:11:27,754] Trial 42 finished with value: 0.3316277314096381 and parameters: {'max_depth': 4, 'learning_rate': 0.002302416916602496, 'subsample': 0.8215376661955515, 'colsample_bytree': 0.823008048869822, 'min_child_weight': 3.5505355719747675, 'n_estimators': 504}. Best is trial 12 with value: 0.32846817374771076.
# [I 2026-01-02 23:12:02,647] Trial 43 finished with value: 0.3284541934040739 and parameters: {'max_depth': 5, 'learning_rate': 0.007328709346686408, 'subsample': 0.8004021304815936, 'colsample_bytree': 0.9391214444900701, 'min_child_weight': 4.124383864049013, 'n_estimators': 975}. Best is trial 43 with value: 0.3284541934040739.
# [I 2026-01-02 23:12:31,379] Trial 44 finished with value: 0.3292510729913741 and parameters: {'max_depth': 5, 'learning_rate': 0.007486584207052181, 'subsample': 0.7934397732258752, 'colsample_bytree': 0.9349837199182222, 'min_child_weight': 2.6638383661282337, 'n_estimators': 976}. Best is trial 43 with value: 0.3284541934040739.
# [I 2026-01-02 23:12:58,547] Trial 45 finished with value: 0.3296145619259322 and parameters: {'max_depth': 5, 'learning_rate': 0.01342735049906186, 'subsample': 0.7435247922885846, 'colsample_bytree': 0.9887323777498295, 'min_child_weight': 5.877494612668447, 'n_estimators': 1033}. Best is trial 43 with value: 0.3284541934040739.
# [I 2026-01-02 23:13:50,086] Trial 46 finished with value: 0.36164352919794773 and parameters: {'max_depth': 6, 'learning_rate': 0.2886507305899359, 'subsample': 0.7592269490040702, 'colsample_bytree': 0.7715550333058535, 'min_child_weight': 4.270734893346214, 'n_estimators': 1491}. Best is trial 43 with value: 0.3284541934040739.
# [I 2026-01-02 23:14:17,936] Trial 47 finished with value: 0.32955864055138473 and parameters: {'max_depth': 4, 'learning_rate': 0.011655886274162227, 'subsample': 0.9793649985367165, 'colsample_bytree': 0.9544120781096189, 'min_child_weight': 3.9892677964473364, 'n_estimators': 1141}. Best is trial 43 with value: 0.3284541934040739.
# [I 2026-01-02 23:14:45,294] Trial 48 finished with value: 0.33283004096240687 and parameters: {'max_depth': 4, 'learning_rate': 0.027067968083406658, 'subsample': 0.9530660618498058, 'colsample_bytree': 0.9324443107368762, 'min_child_weight': 3.4655093302247573, 'n_estimators': 1392}. Best is trial 43 with value: 0.3284541934040739.
# [I 2026-01-02 23:14:59,414] Trial 49 finished with value: 0.3326622768387647 and parameters: {'max_depth': 3, 'learning_rate': 0.05465219714348233, 'subsample': 0.7124871481504083, 'colsample_bytree': 0.9785819905038935, 'min_child_weight': 1.8758012027701199, 'n_estimators': 870}. Best is trial 43 with value: 0.3284541934040739.
# Best params: {'max_depth': 5, 'learning_rate': 0.007328709346686408, 'subsample': 0.8004021304815936, 'colsample_bytree': 0.9391214444900701, 'min_child_weight': 4.124383864049013, 'n_estimators': 975}
# Best CV Error Rate: 0.3284541934040739

# %%
best_params2 = study2.best_params
oof_probs2 = ts_cv_oof_probs(best_params2, n_splits=10)

m = ~np.isnan(oof_probs2)

oof_logloss = log_loss(y[m], oof_probs2[m])
oof_acc = accuracy_score(y[m], (oof_probs2[m] >= 0.5).astype(int))
oof_error_rate = 1.0 - oof_acc
ece = expected_calibration_error(y, oof_probs2, n_bins=10)

print(f"OOF log loss: {oof_logloss}")
print(f"OOF accuracy: {oof_acc}")
print(f"OOF error rate: {oof_error_rate}")
print(f"OOF ECE: {ece}")
print(f"OOF ECE (% points): {ece*100}")

figureb = reliability_diagram(y, oof_probs2, n_bins=10, title="XGBoost Error Optimized Test Calibration")
# Out:
# OOF coverage: 0.909  |  NaNs: 8675 / 95375
# OOF log loss (masked): 0.6017818748233208
# OOF accuracy (masked): 0.6696193771626298
# OOF error rate (masked): 0.33038062283737024
# OOF ECE (fraction): 0.003179269194078752
# OOF ECE (% points): 0.3179269194078752
