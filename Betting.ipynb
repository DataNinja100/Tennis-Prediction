# %% [markdown]
# # IMPORTING AND CLEANING BETTING DATASET (PINNACLE SPORTS)

# %% [markdown]
# imports and setup

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, brier_score_loss, accuracy_score, roc_auc_score
import torch
import torch.nn as nn
import torch.optim as optim
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
from sklearn.calibration import calibration_curve
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np

# %%
betting_df=pd.read_csv("CODE/Final/usopen.csv")
betting_df=betting_df[['Date', 'Winner', 'Loser', 'WRank', 'LRank', 'Wsets', 'Lsets', 'Comment', 'PSW', 'PSL']]
betting_df = betting_df[betting_df['Loser'] != "Forbes M."] #we have to drop this row as there was missing data for this game in the original dataset so it's not present in the testset
betting_df
# Out:
#            Date            Winner         Loser  WRank  LRank  Wsets  Lsets  \
# 0    26/08/2024         Zverev A.   Marterer M.      4    100      3      1
# 1    26/08/2024  Bautista Agut R.      Nardi L.     67     90      3      0
# 2    26/08/2024       Comesana F.   Stricker D.    108    169      3      1
# 3    26/08/2024        Humbert U.   Monteiro T.     17     75      3      0
# 4    26/08/2024        Krueger M.    Grenier H.    179    173      3      1
# ..          ...               ...           ...    ...    ...    ...    ...
# 122  04/09/2024         Draper J.  De Minaur A.     25     10      3      0
# 123  05/09/2024         Sinner J.   Medvedev D.      1      5      3      1
# 124  06/09/2024         Sinner J.     Draper J.      1     25      3      0
# 125  07/09/2024          Fritz T.     Tiafoe F.     12     20      3      2
# 126  08/09/2024         Sinner J.      Fritz T.      1     12      3      0
#
#        Comment   PSW    PSL
# 0    Completed  1.02  27.72
# 1    Completed  1.28   4.10
# 2    Completed  3.45   1.36
# 3    Completed  1.13   7.11
# 4    Completed  1.73   2.25
# ..         ...   ...    ...
# 122  Completed  2.33   1.68
# 123  Completed  1.36   3.44
# 124  Completed  1.16   6.20
# 125  Completed  1.34   3.60
# 126  Completed  1.26   4.37
#
# [126 rows x 10 columns]

# %% [markdown]
# computing Pinnacle implied probabilities, and margin

# %%
betting_df['winner_prob'], betting_df['loser_prob'] = 1/betting_df['PSW'], 1/betting_df['PSL']
betting_df['margin'] = betting_df['winner_prob'] + betting_df['loser_prob'] - 1
betting_df
# Out:
#            Date            Winner         Loser  WRank  LRank  Wsets  Lsets  \
# 0    26/08/2024         Zverev A.   Marterer M.      4    100      3      1
# 1    26/08/2024  Bautista Agut R.      Nardi L.     67     90      3      0
# 2    26/08/2024       Comesana F.   Stricker D.    108    169      3      1
# 3    26/08/2024        Humbert U.   Monteiro T.     17     75      3      0
# 4    26/08/2024        Krueger M.    Grenier H.    179    173      3      1
# ..          ...               ...           ...    ...    ...    ...    ...
# 122  04/09/2024         Draper J.  De Minaur A.     25     10      3      0
# 123  05/09/2024         Sinner J.   Medvedev D.      1      5      3      1
# 124  06/09/2024         Sinner J.     Draper J.      1     25      3      0
# 125  07/09/2024          Fritz T.     Tiafoe F.     12     20      3      2
# 126  08/09/2024         Sinner J.      Fritz T.      1     12      3      0
#
#        Comment   PSW    PSL  winner_prob  loser_prob    margin
# 0    Completed  1.02  27.72     0.980392    0.036075  0.016467
# 1    Completed  1.28   4.10     0.781250    0.243902  0.025152
# 2    Completed  3.45   1.36     0.289855    0.735294  0.025149
# 3    Completed  1.13   7.11     0.884956    0.140647  0.025603
# 4    Completed  1.73   2.25     0.578035    0.444444  0.022479
# ..         ...   ...    ...          ...         ...       ...
# 122  Completed  2.33   1.68     0.429185    0.595238  0.024423
# 123  Completed  1.36   3.44     0.735294    0.290698  0.025992
# 124  Completed  1.16   6.20     0.862069    0.161290  0.023359
# 125  Completed  1.34   3.60     0.746269    0.277778  0.024046
# 126  Completed  1.26   4.37     0.793651    0.228833  0.022484
#
# [126 rows x 13 columns]

# %% [markdown]
# # TRAINING 5 MODELS FROM PREVIOUS PART WITH OPTIMAL HYPERPARAMS FROM TEST DATA ONLY

# %% [markdown]
# Load train and test - valid not needed as validation & hyperparam tuning already done

# %%
# Load train and test data
train_data = pd.read_csv("CODE/Final/train.csv")
test_data = pd.read_csv("CODE/Final/test.csv")  

X_train = train_data.drop(columns=["result"])
y_train = train_data["result"]

X_test = test_data.drop(columns=["result"])
y_test = test_data["result"]

print(f"Training samples: {len(X_train)}")
print(f"Test samples: {len(X_test)}") #test on grand slam+rest of 2024 after it
# Out:
# Training samples: 58128
# Test samples: 705

# %% [markdown]
# Log model

# %%
# Pipeline from log model
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("logit", LogisticRegression(
        penalty="l2",
        C=1.0,
        solver="lbfgs",
        max_iter=2000,
        random_state=42
    ))
])

# Train on ALL training data
pipe.fit(X_train, y_train)

# Predict on test set
y_prob = pipe.predict_proba(X_test)[:, 1]
y_pred = (y_prob >= 0.5).astype(int)

# Evaluate
print("\n=== Logistic Regression Test Results ===")
print(f"Log Loss:  {log_loss(y_test, y_prob):.6f}")
print(f"Brier:     {brier_score_loss(y_test, y_prob):.6f}")
print(f"AUC:       {roc_auc_score(y_test, y_prob):.6f}")
print(f"Accuracy:  {accuracy_score(y_test, y_pred):.6f}")
# Out:
# === Logistic Regression Test Results ===
# Log Loss:  0.611696
# Brier:     0.212559
# AUC:       0.722014
# Accuracy:  0.651064

# %% [markdown]
# XGB

# %%
# Best hyperparameters from tuning
best_params_ll = {
    'max_depth': 4,
    'learning_rate': 0.0072712729339508,
    'subsample': 0.6890395724443819,
    'colsample_bytree': 0.7688217801997627,
    'min_child_weight': 4.637518788125464,
    'n_estimators': 1030
}

best_params_err = {
    'max_depth': 7,
    'learning_rate': 0.0033260426407191995,
    'subsample': 0.6708653731479767,
    'colsample_bytree': 0.6656222143908919,
    'min_child_weight': 3.3103624507248526,
    'n_estimators': 1008
}

# XGBoost Log Loss Optimized
model_ll = XGBClassifier(
    **best_params_ll,
    objective="binary:logistic",
    eval_metric="logloss",
    tree_method="hist",
    random_state=42,
    n_jobs=-1
)

model_ll.fit(X_train, y_train)
y_prob_ll = model_ll.predict_proba(X_test)[:, 1]
y_pred_ll = (y_prob_ll >= 0.5)

print("=== XGBoost (Log Loss Tuned) ===")
print(f"Log Loss:  {log_loss(y_test, y_prob_ll):.6f}")
print(f"Brier:     {brier_score_loss(y_test, y_prob_ll):.6f}")
print(f"AUC:       {roc_auc_score(y_test, y_prob_ll):.6f}")
print(f"Accuracy:  {accuracy_score(y_test, y_pred_ll):.6f}")

# XGBoost Error Rate Optimized
model_err = XGBClassifier(
    **best_params_err,
    objective="binary:logistic",
    eval_metric="logloss",
    tree_method="hist",
    random_state=42,
    n_jobs=-1
)

model_err.fit(X_train, y_train)
y_prob_err = model_err.predict_proba(X_test)[:, 1]
y_pred_err = (y_prob_err >= 0.5)

print("\n=== XGBoost (Error Tuned) ===")
print(f"Log Loss:  {log_loss(y_test, y_prob_err):.6f}")
print(f"Brier:     {brier_score_loss(y_test, y_prob_err):.6f}")
print(f"AUC:       {roc_auc_score(y_test, y_prob_err):.6f}")
print(f"Accuracy:  {accuracy_score(y_test, y_pred_err):.6f}")
# Out:
# === XGBoost (Log Loss Tuned) ===
# Log Loss:  0.606358
# Brier:     0.209705
# AUC:       0.729896
# Accuracy:  0.660993
#
# === XGBoost (Error Tuned) ===
# Log Loss:  0.606595
# Brier:     0.209569
# AUC:       0.730373
# Accuracy:  0.672340

# %% [markdown]
# MLP

# %%
def test_mlp(X_train, y_train, X_test, y_test, params, name):
    torch.manual_seed(42)
    
    # Scale
    scaler = StandardScaler()
    X_tr = torch.tensor(scaler.fit_transform(X_train), dtype=torch.float32)
    X_te = torch.tensor(scaler.transform(X_test), dtype=torch.float32)
    y_tr = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)
    
    # Model
    d = params['dropout']
    model = nn.Sequential(
        nn.Linear(X_tr.shape[1], 256), nn.ReLU(), nn.Dropout(d),
        nn.Linear(256, 256), nn.ReLU(), nn.Dropout(d),
        nn.Linear(256, 256), nn.ReLU(), nn.Dropout(d),
        nn.Linear(256, 256), nn.ReLU(), nn.Dropout(d),
        nn.Linear(256, 1)
    )
    
    # Train
    optimizer = optim.Adam(model.parameters(), lr=params['lr'], weight_decay=params['weight_decay'])
    loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(X_tr, y_tr), 
        batch_size=params['batch_size'], shuffle=True
    )
    
    model.train()
    for _ in range(params['n_epochs']):
        for xb, yb in loader:
            optimizer.zero_grad()
            loss = nn.BCEWithLogitsLoss()(model(xb), yb)
            loss.backward()
            optimizer.step()
    
    # Predict
    model.eval()
    with torch.no_grad():
        y_prob = torch.sigmoid(model(X_te)).squeeze().numpy()
    y_pred = (y_prob >= 0.5).astype(int)
    
    # Results
    print(f"\n=== {name} ===")
    print(f"Log Loss:  {log_loss(y_test, y_prob):.6f}")
    print(f"Brier:     {brier_score_loss(y_test, y_prob):.6f}")
    print(f"AUC:       {roc_auc_score(y_test, y_prob):.6f}")
    print(f"Accuracy:  {accuracy_score(y_test, y_pred):.6f}")

    return model, scaler

# Run both with best hyperparams found previously
best_ll = {'lr': 0.0006087625617834723, 'weight_decay': 8.681907424878423e-07, 'dropout': 0.49838921329214125, 'batch_size': 1024, 'n_epochs': 16}
best_err = {'lr': 0.00043284502212938834, 'weight_decay': 0.0006351221010640698, 'dropout': 0.36599697090570255, 'batch_size': 256, 'n_epochs': 6}

mlp_ll_model, mlp_ll_scaler = test_mlp(X_train, y_train, X_test, y_test, best_ll, "MLP (Log Loss Tuned)")
mlp_err_model, mlp_err_scaler = test_mlp(X_train, y_train, X_test, y_test, best_err, "MLP (Error Tuned)")
# Out:
# === MLP (Log Loss Tuned) ===
# Log Loss:  0.608085
# Brier:     0.210617
# AUC:       0.726581
# Accuracy:  0.658156
#
# === MLP (Error Tuned) ===
# Log Loss:  0.610986
# Brier:     0.211979
# AUC:       0.720890
# Accuracy:  0.662411

# %% [markdown]
# # STRATEGY

# %% [markdown]
# align both datasets

# %%
order=pd.read_csv("CODE/Final/order.csv") #we need to align games of betting df to our test set
order_l=list(zip(order['winner_rank'], order['loser_rank']))
s=0
rows = []
for i in order_l:
    row = betting_df[(betting_df['WRank'] == i[0]) & (betting_df['LRank'] == i[1])] #unique
    rows.append(row.iloc[0])
    s+=len(row)
print(s) #126 as needed (remember 1 missing row, so no other missing or duplicate matches!)
betting_df_ordered = pd.DataFrame(rows).reset_index(drop=True)
# Out:
# 126

# %%
betting_df_ordered
# Out:
#            Date        Winner         Loser  WRank  LRank  Wsets  Lsets  \
# 0    27/08/2024     Sinner J.   Mcdonald M.      1    140      3      1
# 1    27/08/2024  Michelsen A.  Spizzirri E.     49    341      3      0
# 2    28/08/2024   Bellucci M.   Wawrinka S.    101    176      3      0
# 3    27/08/2024  O Connell C.      Jarry N.     87     26      3      1
# 4    27/08/2024       Fils A.       Tien L.     24    191      3      1
# ..          ...           ...           ...    ...    ...    ...    ...
# 121  03/09/2024      Fritz T.     Zverev A.     12      4      3      1
# 122  04/09/2024     Tiafoe F.   Dimitrov G.     20      9      2      1
# 123  06/09/2024     Sinner J.     Draper J.      1     25      3      0
# 124  07/09/2024      Fritz T.     Tiafoe F.     12     20      3      2
# 125  08/09/2024     Sinner J.      Fritz T.      1     12      3      0
#
#        Comment   PSW    PSL  winner_prob  loser_prob    margin
# 0    Completed  1.02  28.96     0.980392    0.034530  0.014923
# 1    Completed  1.24   4.63     0.806452    0.215983  0.022434
# 2    Completed  1.40   3.20     0.714286    0.312500  0.026786
# 3    Completed  2.84   1.49     0.352113    0.671141  0.023254
# 4    Completed  1.35   3.50     0.740741    0.285714  0.026455
# ..         ...   ...    ...          ...         ...       ...
# 121  Completed  2.49   1.61     0.401606    0.621118  0.022724
# 122    Retired  2.44   1.63     0.409836    0.613497  0.023333
# 123  Completed  1.16   6.20     0.862069    0.161290  0.023359
# 124  Completed  1.34   3.60     0.746269    0.277778  0.024046
# 125  Completed  1.26   4.37     0.793651    0.228833  0.022484
#
# [126 rows x 13 columns]

# %%
test_slam=test_data.iloc[0:126] #testing strategy only on last grand slam
test_slam
# Out:
#      draw_size  best_of  ATP_Point_Diff  Rank_Diff  Height_Diff  Age_Diff  \
# 0          128        5         -8938.0      139.0        -13.0       6.3
# 1          128        5          -970.0      292.0        -10.0       2.6
# 2          128        5          -222.0       75.0          8.0      16.2
# 3          128        5         -1004.0       61.0        -18.0       1.4
# 4          128        5         -1461.0      167.0         -5.0      -1.5
# ..         ...      ...             ...        ...          ...       ...
# 121        128        5          3915.0       -8.0          2.0       0.5
# 122        128        5         -1535.0       11.0         -3.0      -6.7
# 123        128        5          7665.0      -24.0         -2.0       0.4
# 124        128        5          1000.0       -8.0          8.0       0.3
# 125        128        5          6240.0      -11.0         -5.0      -3.8
#
#      H2H_Diff  H2H_Surface_Diff  N_Games_Diff  Win_Rate_3_Diff  ...  \
# 0        -2.0              -1.0         -90.0        -1.000000  ...
# 1        -0.0              -0.0         -59.0        -0.166667  ...
# 2        -0.0              -0.0         882.0        -0.000000  ...
# 3         0.0               0.0        -104.0         0.333333  ...
# 4        -0.0              -0.0         -80.0         0.333333  ...
# ..        ...               ...           ...              ...  ...
# 121       1.0              -1.0         181.0        -0.000000  ...
# 122      -1.0               0.0        -343.0         0.000000  ...
# 123      -1.0               0.0         203.0         0.000000  ...
# 124       5.0               5.0          65.0         0.000000  ...
# 125       0.0               0.0        -128.0         0.000000  ...
#
#      p_1stIn_diff_last_2000  p_1stWon_diff_last_2000  p_2ndWon_diff_last_2000  \
# 0                  0.040335                -0.060441                -0.039738
# 1                 -0.053786                 0.050586                 0.006958
# 2                 -0.052375                -0.007273                 0.034970
# 3                 -0.016709                -0.015879                -0.002571
# 4                  0.073136                -0.124586                -0.033377
# ..                      ...                      ...                      ...
# 121                0.067369                -0.019160                -0.041751
# 122               -0.011319                -0.025198                 0.007661
# 123                0.001621                -0.027807                 0.012493
# 124               -0.010726                 0.038313                 0.007366
# 125                0.001945                -0.015381                 0.009432
#
#      p_bpSaved_diff_last_2000  p_bpConv_diff_last_2000  p_rpw_diff_last_2000  \
# 0                   -0.059859                -0.037054             -0.032386
# 1                    0.043966                 0.032540             -0.018582
# 2                    0.002619                 0.134458              0.037642
# 3                   -0.010613                -0.073161             -0.002004
# 4                    0.019507                -0.043978              0.019707
# ..                        ...                      ...                   ...
# 121                 -0.005328                 0.038992              0.023424
# 122                 -0.001766                -0.021651             -0.020461
# 123                  0.010717                 0.015970              0.023377
# 124                  0.002622                 0.008596              0.009168
# 125                  0.038950                 0.065060              0.041738
#
#      p_acedAgainst_diff_last_2000  p_totalPtsWon_diff_last_2000  \
# 0                        0.009722                     -0.037964
# 1                       -0.044996                     -0.006011
# 2                       -0.068101                      0.020022
# 3                        0.031055                     -0.011350
# 4                        0.008924                     -0.023871
# ..                            ...                           ...
# 121                     -0.022903                      0.007721
# 122                      0.042903                     -0.016559
# 123                     -0.011594                      0.009174
# 124                     -0.032897                      0.015363
# 125                     -0.012143                      0.018756
#
#      p_dominanceRatio_diff_last_2000  result
# 0                          -0.280750     0.0
# 1                          -0.029277     0.0
# 2                           0.153696     0.0
# 3                          -0.103109     1.0
# 4                          -0.157248     0.0
# ..                               ...     ...
# 121                         0.083079     0.0
# 122                        -0.158489     1.0
# 123                         0.016856     1.0
# 124                         0.141133     1.0
# 125                         0.143180     1.0
#
# [126 rows x 124 columns]

# %% [markdown]
# Strategy 1 (all in on predicted winner) & strategy 2 (hedge bets if higher than a certain threshold)

# %%
#tracking strat 1
log_reg_cum, xgb_ll_cum, xgb_err_cum, mlp_ll_cum, mlp_err_cum={'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[]}, {'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[]}, {'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[]}, {'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[]}, {'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[]}
#tracking strat 2
log_reg_cum2, xgb_ll_cum2, xgb_err_cum2, mlp_ll_cum2, mlp_err_cum2={'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[], 'Thresh':[], 'Dist':[]},{'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[], 'Thresh':[], 'Dist':[]},{'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[], 'Thresh':[], 'Dist':[]},{'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[], 'Thresh':[], 'Dist':[]},{'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[], 'Thresh':[], 'Dist':[]}
bet_size=100 #100 per bet

# function to update betting stats
def update_betting_stats(dic, winnings, staked, prob, outcome, thresh=None, dist=None):
    dic['Winnings'].append(winnings)
    dic['Staked'].append(staked)
    if staked>0: #only add probabilities when we placed a bet
        dic['Prob'].append(prob)
        dic['Act'].append(outcome)
    if thresh is not None: #for strat 2
        dic['Thresh'].append(thresh)
        dic['Dist'].append(dist)
    return dic

# %% [markdown]
# Run betting simulation

# %%
for idx, match in test_slam.iterrows(): #run through all games in grand slam
    w_odds = betting_df_ordered.iloc[idx]['PSW']
    win_ret = w_odds*bet_size
    row = match.drop('result').to_frame().T  # Keeps column names
    actual = match['result']
    p1_prob=betting_df_ordered.iloc[idx]['winner_prob'] if actual==1 else betting_df_ordered.iloc[idx]['loser_prob']
    p2_prob=betting_df_ordered.iloc[idx]['winner_prob'] if actual==0 else betting_df_ordered.iloc[idx]['loser_prob']
    margin=betting_df_ordered.iloc[idx]['margin']
    required_dist=((margin*p1_prob*p2_prob)**0.5)/(1+margin) #for strategy 2, our model's predicted probability-implied probability needs to exceed this margin
    
    # Logistic Regression
    prob_lr = pipe.predict_proba(row)[:, 1][0]
    
    # XGBoost
    prob_xgb_ll = model_ll.predict_proba(row)[:, 1][0]
    prob_xgb_err = model_err.predict_proba(row)[:, 1][0]
    
    # MLP Log Loss
    row_scaled_ll = torch.tensor(mlp_ll_scaler.transform(row), dtype=torch.float32)
    mlp_ll_model.eval()
    with torch.no_grad():
        prob_mlp_ll = torch.sigmoid(mlp_ll_model(row_scaled_ll)).item()
    
    # MLP Error
    row_scaled_err = torch.tensor(mlp_err_scaler.transform(row), dtype=torch.float32)
    mlp_err_model.eval()
    with torch.no_grad():
        prob_mlp_err = torch.sigmoid(mlp_err_model(row_scaled_err)).item()

    # Compute if distance is far enough for strategy 2
    log_dist, xgb_ll_dist, xgb_err_dist, mlp_ll_dist, mlp_err_dist = prob_lr-(p1_prob/(1+margin)), prob_xgb_ll-(p1_prob/(1+margin)), prob_xgb_err-(p1_prob/(1+margin)), prob_mlp_ll-(p1_prob/(1+margin)), prob_mlp_err-(p1_prob/(1+margin))
    ev_log, ev_xgb_ll, ev_xgb_err, ev_mlp_ll, ev_mlp_err=abs(log_dist)>required_dist, abs(xgb_ll_dist)>required_dist, abs(xgb_err_dist)>required_dist, abs(mlp_ll_dist)>required_dist, abs(mlp_err_dist)>required_dist
    
    strat1=[win_ret if (prob_lr >= 0.5) == actual else 0,
            win_ret if (prob_xgb_ll >= 0.5) == actual else 0,
            win_ret if (prob_xgb_err >= 0.5) == actual else 0,
            win_ret if (prob_mlp_ll >= 0.5) == actual else 0,
            win_ret if (prob_mlp_err >= 0.5) == actual else 0] #winning return if we predicted on the right player to win (act=1 means p1 win, act=0 means p2 win)
    
    strat2=[0 if not ev_log else (win_ret * (1-prob_lr) if actual==0 else win_ret*prob_lr),
            0 if not ev_xgb_ll else (win_ret * (1-prob_xgb_ll) if actual==0 else win_ret*prob_xgb_ll),
            0 if not ev_xgb_err else (win_ret * (1-prob_xgb_err) if actual==0 else win_ret*prob_xgb_err),
            0 if not ev_mlp_ll else (win_ret * (1-prob_mlp_ll) if actual==0 else win_ret*prob_mlp_ll),
            0 if not ev_mlp_err else (win_ret * (1-prob_mlp_err) if actual==0 else win_ret*prob_mlp_err)] #winning return * predicted win probability (hedged) if we met strat 2 requirement else 0 (we don't bet otherwise)
    
    print(f"\n=== Match {idx} | Actual: {'P1 Win' if actual == 1 else 'P2 Win'} ===") #match by match breakdown per model per strategy
    print(f"Strat 2 requirement threshold: {required_dist:.6f} | Winner odds: {w_odds} | Loser odds: {betting_df_ordered.iloc[idx]['PSL']} | Margin: {margin:.6f} | P1 Prob: {p1_prob:.6f} | P2 Prob: {p2_prob:.6f}")
    print(f"LogReg:      P1 Win: {prob_lr:.2%} | P2 Win: {1-prob_lr:.2%} | Pred: {'P1' if prob_lr >= 0.5 else 'P2'} {'✓' if (prob_lr >= 0.5) == actual else '✗'} | Strat1: {round(strat1[0]-bet_size,2)} | Strat2: {round(strat2[0]-(bet_size if ev_log else 0),2)} | Strat2 Distance: {log_dist:.6f} | Requirement Met: {'✓' if ev_log else '✗'}")
    print(f"XGB (LL):    P1 Win: {prob_xgb_ll:.2%} | P2 Win: {1-prob_xgb_ll:.2%} | Pred: {'P1' if prob_xgb_ll >= 0.5 else 'P2'} {'✓' if (prob_xgb_ll >= 0.5) == actual else '✗'} | Strat1: {round(strat1[1]-bet_size,2)} | Strat2: {round(strat2[1]-(bet_size if ev_xgb_ll else 0),2)} | Strat2 Distance: {xgb_ll_dist:.6f} | Requirement Met: {'✓' if ev_xgb_ll else '✗'}")
    print(f"XGB (Err):   P1 Win: {prob_xgb_err:.2%} | P2 Win: {1-prob_xgb_err:.2%} | Pred: {'P1' if prob_xgb_err >= 0.5 else 'P2'} {'✓' if (prob_xgb_err >= 0.5) == actual else '✗'} | Strat1: {round(strat1[2]-bet_size,2)} | Strat2: {round(strat2[2]-(bet_size if ev_xgb_err else 0),2)} | Strat2 Distance: {xgb_err_dist:.6f} | Requirement Met: {'✓' if ev_xgb_err else '✗'}")
    print(f"MLP (LL):    P1 Win: {prob_mlp_ll:.2%} | P2 Win: {1-prob_mlp_ll:.2%} | Pred: {'P1' if prob_mlp_ll >= 0.5 else 'P2'} {'✓' if (prob_mlp_ll >= 0.5) == actual else '✗'} | Strat1: {round(strat1[3]-bet_size,2)} | Strat2: {round(strat2[3]-(bet_size if ev_mlp_ll else 0),2)} | Strat2 Distance: {mlp_ll_dist:.6f} | Requirement Met: {'✓' if ev_mlp_ll else '✗'}")
    print(f"MLP (Err):   P1 Win: {prob_mlp_err:.2%} | P2 Win: {1-prob_mlp_err:.2%} | Pred: {'P1' if prob_mlp_err >= 0.5 else 'P2'} {'✓' if (prob_mlp_err >= 0.5) == actual else '✗'} | Strat1: {round(strat1[4]-bet_size,2)} | Strat2: {round(strat2[4]-(bet_size if ev_mlp_err else 0),2)} | Strat2 Distance: {mlp_err_dist:.6f} | Requirement Met: {'✓' if ev_mlp_err else '✗'}")
    
    # update strat 1
    update_betting_stats(log_reg_cum, strat1[0], bet_size, prob_lr, actual)
    update_betting_stats(xgb_ll_cum, strat1[1], bet_size, prob_xgb_ll, actual)
    update_betting_stats(xgb_err_cum, strat1[2], bet_size, prob_xgb_err, actual)
    update_betting_stats(mlp_ll_cum, strat1[3], bet_size, prob_mlp_ll, actual)
    update_betting_stats(mlp_err_cum, strat1[4], bet_size, prob_mlp_err, actual)
    # update strat 2
    update_betting_stats(log_reg_cum2, strat2[0], bet_size if ev_log else 0, prob_lr, actual, required_dist, abs(log_dist))
    update_betting_stats(xgb_ll_cum2, strat2[1], bet_size if ev_xgb_ll else 0, prob_xgb_ll, actual, required_dist, abs(xgb_ll_dist))
    update_betting_stats(xgb_err_cum2, strat2[2], bet_size if ev_xgb_err else 0, prob_xgb_err, actual, required_dist, abs(xgb_err_dist))
    update_betting_stats(mlp_ll_cum2, strat2[3], bet_size if ev_mlp_ll else 0, prob_mlp_ll, actual, required_dist, abs(mlp_ll_dist))
    update_betting_stats(mlp_err_cum2, strat2[4], bet_size if ev_mlp_err else 0, prob_mlp_err, actual, required_dist, abs(mlp_err_dist))
# Out:
# === Match 0 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.022146 | Winner odds: 1.02 | Loser odds: 28.96 | Margin: 0.014923 | P1 Prob: 0.034530 | P2 Prob: 0.980392
# LogReg:      P1 Win: 4.00% | P2 Win: 96.00% | Pred: P2 ✓ | Strat1: 2.0 | Strat2: 0 | Strat2 Distance: 0.006008 | Requirement Met: ✗
# XGB (LL):    P1 Win: 5.90% | P2 Win: 94.10% | Pred: P2 ✓ | Strat1: 2.0 | Strat2: -4.02 | Strat2 Distance: 0.025018 | Requirement Met: ✓
# XGB (Err):   P1 Win: 7.66% | P2 Win: 92.34% | Pred: P2 ✓ | Strat1: 2.0 | Strat2: -5.82 | Strat2 Distance: 0.042613 | Requirement Met: ✓
# MLP (LL):    P1 Win: 4.36% | P2 Win: 95.64% | Pred: P2 ✓ | Strat1: 2.0 | Strat2: 0 | Strat2 Distance: 0.009608 | Requirement Met: ✗
# MLP (Err):   P1 Win: 4.79% | P2 Win: 95.21% | Pred: P2 ✓ | Strat1: 2.0 | Strat2: 0 | Strat2 Distance: 0.013847 | Requirement Met: ✗
#
# === Match 1 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.061139 | Winner odds: 1.24 | Loser odds: 4.63 | Margin: 0.022434 | P1 Prob: 0.215983 | P2 Prob: 0.806452
# LogReg:      P1 Win: 24.71% | P2 Win: 75.29% | Pred: P2 ✓ | Strat1: 24.0 | Strat2: 0 | Strat2 Distance: 0.035854 | Requirement Met: ✗
# XGB (LL):    P1 Win: 29.74% | P2 Win: 70.26% | Pred: P2 ✓ | Strat1: 24.0 | Strat2: -12.87 | Strat2 Distance: 0.086132 | Requirement Met: ✓
# XGB (Err):   P1 Win: 29.44% | P2 Win: 70.56% | Pred: P2 ✓ | Strat1: 24.0 | Strat2: -12.51 | Strat2 Distance: 0.083197 | Requirement Met: ✓
# MLP (LL):    P1 Win: 25.59% | P2 Win: 74.41% | Pred: P2 ✓ | Strat1: 24.0 | Strat2: 0 | Strat2 Distance: 0.044610 | Requirement Met: ✗
# MLP (Err):   P1 Win: 27.20% | P2 Win: 72.80% | Pred: P2 ✓ | Strat1: 24.0 | Strat2: 0 | Strat2 Distance: 0.060756 | Requirement Met: ✗
#
# === Match 2 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.075307 | Winner odds: 1.4 | Loser odds: 3.2 | Margin: 0.026786 | P1 Prob: 0.312500 | P2 Prob: 0.714286
# LogReg:      P1 Win: 60.54% | P2 Win: 39.46% | Pred: P1 ✗ | Strat1: -100 | Strat2: -44.75 | Strat2 Distance: 0.301005 | Requirement Met: ✓
# XGB (LL):    P1 Win: 52.33% | P2 Win: 47.67% | Pred: P1 ✗ | Strat1: -100 | Strat2: -33.26 | Strat2 Distance: 0.218942 | Requirement Met: ✓
# XGB (Err):   P1 Win: 53.60% | P2 Win: 46.40% | Pred: P1 ✗ | Strat1: -100 | Strat2: -35.03 | Strat2 Distance: 0.231610 | Requirement Met: ✓
# MLP (LL):    P1 Win: 55.95% | P2 Win: 44.05% | Pred: P1 ✗ | Strat1: -100 | Strat2: -38.33 | Strat2 Distance: 0.255180 | Requirement Met: ✓
# MLP (Err):   P1 Win: 58.41% | P2 Win: 41.59% | Pred: P1 ✗ | Strat1: -100 | Strat2: -41.77 | Strat2 Distance: 0.279720 | Requirement Met: ✓
#
# === Match 3 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.072445 | Winner odds: 2.84 | Loser odds: 1.49 | Margin: 0.023254 | P1 Prob: 0.352113 | P2 Prob: 0.671141
# LogReg:      P1 Win: 34.09% | P2 Win: 65.91% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.003258 | Requirement Met: ✗
# XGB (LL):    P1 Win: 35.01% | P2 Win: 64.99% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.006039 | Requirement Met: ✗
# XGB (Err):   P1 Win: 33.13% | P2 Win: 66.87% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.012817 | Requirement Met: ✗
# MLP (LL):    P1 Win: 29.95% | P2 Win: 70.05% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.044602 | Requirement Met: ✗
# MLP (Err):   P1 Win: 29.39% | P2 Win: 70.61% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.050219 | Requirement Met: ✗
#
# === Match 4 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.072898 | Winner odds: 1.35 | Loser odds: 3.5 | Margin: 0.026455 | P1 Prob: 0.285714 | P2 Prob: 0.740741
# LogReg:      P1 Win: 30.60% | P2 Win: 69.40% | Pred: P2 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: 0.027698 | Requirement Met: ✗
# XGB (LL):    P1 Win: 23.89% | P2 Win: 76.11% | Pred: P2 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: -0.039466 | Requirement Met: ✗
# XGB (Err):   P1 Win: 26.63% | P2 Win: 73.37% | Pred: P2 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: -0.012015 | Requirement Met: ✗
# MLP (LL):    P1 Win: 27.60% | P2 Win: 72.40% | Pred: P2 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: -0.002381 | Requirement Met: ✗
# MLP (Err):   P1 Win: 22.25% | P2 Win: 77.75% | Pred: P2 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: -0.055802 | Requirement Met: ✗
#
# === Match 5 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.076127 | Winner odds: 1.98 | Loser odds: 1.93 | Margin: 0.023185 | P1 Prob: 0.505051 | P2 Prob: 0.518135
# LogReg:      P1 Win: 63.11% | P2 Win: 36.89% | Pred: P1 ✓ | Strat1: 98.0 | Strat2: 24.96 | Strat2 Distance: 0.137501 | Requirement Met: ✓
# XGB (LL):    P1 Win: 62.97% | P2 Win: 37.03% | Pred: P1 ✓ | Strat1: 98.0 | Strat2: 24.69 | Strat2 Distance: 0.136121 | Requirement Met: ✓
# XGB (Err):   P1 Win: 60.96% | P2 Win: 39.04% | Pred: P1 ✓ | Strat1: 98.0 | Strat2: 20.69 | Strat2 Distance: 0.115962 | Requirement Met: ✓
# MLP (LL):    P1 Win: 70.18% | P2 Win: 29.82% | Pred: P1 ✓ | Strat1: 98.0 | Strat2: 38.96 | Strat2 Distance: 0.208217 | Requirement Met: ✓
# MLP (Err):   P1 Win: 68.98% | P2 Win: 31.02% | Pred: P1 ✓ | Strat1: 98.0 | Strat2: 36.58 | Strat2 Distance: 0.196200 | Requirement Met: ✓
#
# === Match 6 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.078277 | Winner odds: 2.19 | Loser odds: 1.76 | Margin: 0.024803 | P1 Prob: 0.456621 | P2 Prob: 0.568182
# LogReg:      P1 Win: 46.64% | P2 Win: 53.36% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.020781 | Requirement Met: ✗
# XGB (LL):    P1 Win: 42.39% | P2 Win: 57.61% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.021713 | Requirement Met: ✗
# XGB (Err):   P1 Win: 43.11% | P2 Win: 56.89% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.014420 | Requirement Met: ✗
# MLP (LL):    P1 Win: 41.97% | P2 Win: 58.03% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.025894 | Requirement Met: ✗
# MLP (Err):   P1 Win: 41.75% | P2 Win: 58.25% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.028116 | Requirement Met: ✗
#
# === Match 7 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.059785 | Winner odds: 1.24 | Loser odds: 4.65 | Margin: 0.021505 | P1 Prob: 0.806452 | P2 Prob: 0.215054
# LogReg:      P1 Win: 66.67% | P2 Win: 33.33% | Pred: P1 ✓ | Strat1: 24.0 | Strat2: -17.33 | Strat2 Distance: -0.122776 | Requirement Met: ✓
# XGB (LL):    P1 Win: 72.26% | P2 Win: 27.74% | Pred: P1 ✓ | Strat1: 24.0 | Strat2: -10.39 | Strat2 Distance: -0.066851 | Requirement Met: ✓
# XGB (Err):   P1 Win: 71.10% | P2 Win: 28.90% | Pred: P1 ✓ | Strat1: 24.0 | Strat2: -11.84 | Strat2 Distance: -0.078507 | Requirement Met: ✓
# MLP (LL):    P1 Win: 65.98% | P2 Win: 34.02% | Pred: P1 ✓ | Strat1: 24.0 | Strat2: -18.18 | Strat2 Distance: -0.129653 | Requirement Met: ✓
# MLP (Err):   P1 Win: 69.36% | P2 Win: 30.64% | Pred: P1 ✓ | Strat1: 24.0 | Strat2: -13.99 | Strat2 Distance: -0.095861 | Requirement Met: ✓
#
# === Match 8 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.059994 | Winner odds: 3.15 | Loser odds: 1.43 | Margin: 0.016761 | P1 Prob: 0.317460 | P2 Prob: 0.699301
# LogReg:      P1 Win: 21.34% | P2 Win: 78.66% | Pred: P2 ✗ | Strat1: -100 | Strat2: -32.78 | Strat2 Distance: -0.098826 | Requirement Met: ✓
# XGB (LL):    P1 Win: 17.16% | P2 Win: 82.84% | Pred: P2 ✗ | Strat1: -100 | Strat2: -45.93 | Strat2 Distance: -0.140583 | Requirement Met: ✓
# XGB (Err):   P1 Win: 17.76% | P2 Win: 82.24% | Pred: P2 ✗ | Strat1: -100 | Strat2: -44.05 | Strat2 Distance: -0.134595 | Requirement Met: ✓
# MLP (LL):    P1 Win: 22.12% | P2 Win: 77.88% | Pred: P2 ✗ | Strat1: -100 | Strat2: -30.32 | Strat2 Distance: -0.091028 | Requirement Met: ✓
# MLP (Err):   P1 Win: 21.36% | P2 Win: 78.64% | Pred: P2 ✗ | Strat1: -100 | Strat2: -32.71 | Strat2 Distance: -0.098622 | Requirement Met: ✓
#
# === Match 9 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.048468 | Winner odds: 1.1 | Loser odds: 8.73 | Margin: 0.023638 | P1 Prob: 0.909091 | P2 Prob: 0.114548
# LogReg:      P1 Win: 72.98% | P2 Win: 27.02% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: -19.73 | Strat2 Distance: -0.158330 | Requirement Met: ✓
# XGB (LL):    P1 Win: 75.17% | P2 Win: 24.83% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: -17.32 | Strat2 Distance: -0.136422 | Requirement Met: ✓
# XGB (Err):   P1 Win: 73.06% | P2 Win: 26.94% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: -19.64 | Strat2 Distance: -0.157521 | Requirement Met: ✓
# MLP (LL):    P1 Win: 74.10% | P2 Win: 25.90% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: -18.49 | Strat2 Distance: -0.147122 | Requirement Met: ✓
# MLP (Err):   P1 Win: 75.12% | P2 Win: 24.88% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: -17.37 | Strat2 Distance: -0.136879 | Requirement Met: ✓
#
# === Match 10 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.075711 | Winner odds: 2.53 | Loser odds: 1.59 | Margin: 0.024188 | P1 Prob: 0.628931 | P2 Prob: 0.395257
# LogReg:      P1 Win: 40.50% | P2 Win: 59.50% | Pred: P2 ✓ | Strat1: 153.0 | Strat2: 50.53 | Strat2 Distance: -0.209056 | Requirement Met: ✓
# XGB (LL):    P1 Win: 45.50% | P2 Win: 54.50% | Pred: P2 ✓ | Strat1: 153.0 | Strat2: 37.89 | Strat2 Distance: -0.159078 | Requirement Met: ✓
# XGB (Err):   P1 Win: 47.91% | P2 Win: 52.09% | Pred: P2 ✓ | Strat1: 153.0 | Strat2: 31.78 | Strat2 Distance: -0.134956 | Requirement Met: ✓
# MLP (LL):    P1 Win: 34.15% | P2 Win: 65.85% | Pred: P2 ✓ | Strat1: 153.0 | Strat2: 66.59 | Strat2 Distance: -0.272529 | Requirement Met: ✓
# MLP (Err):   P1 Win: 31.07% | P2 Win: 68.93% | Pred: P2 ✓ | Strat1: 153.0 | Strat2: 74.39 | Strat2 Distance: -0.303378 | Requirement Met: ✓
#
# === Match 11 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.064126 | Winner odds: 4.14 | Loser odds: 1.28 | Margin: 0.022796 | P1 Prob: 0.781250 | P2 Prob: 0.241546
# LogReg:      P1 Win: 71.25% | P2 Win: 28.75% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.051294 | Requirement Met: ✗
# XGB (LL):    P1 Win: 73.68% | P2 Win: 26.32% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.027052 | Requirement Met: ✗
# XGB (Err):   P1 Win: 73.83% | P2 Win: 26.17% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.025550 | Requirement Met: ✗
# MLP (LL):    P1 Win: 66.78% | P2 Win: 33.22% | Pred: P1 ✗ | Strat1: -100 | Strat2: 37.51 | Strat2 Distance: -0.095988 | Requirement Met: ✓
# MLP (Err):   P1 Win: 72.23% | P2 Win: 27.77% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.041562 | Requirement Met: ✗
#
# === Match 12 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.068325 | Winner odds: 1.32 | Loser odds: 3.75 | Margin: 0.024242 | P1 Prob: 0.757576 | P2 Prob: 0.266667
# LogReg:      P1 Win: 70.66% | P2 Win: 29.34% | Pred: P1 ✓ | Strat1: 32.0 | Strat2: 0 | Strat2 Distance: -0.033045 | Requirement Met: ✗
# XGB (LL):    P1 Win: 74.29% | P2 Win: 25.71% | Pred: P1 ✓ | Strat1: 32.0 | Strat2: 0 | Strat2 Distance: 0.003301 | Requirement Met: ✗
# XGB (Err):   P1 Win: 73.22% | P2 Win: 26.78% | Pred: P1 ✓ | Strat1: 32.0 | Strat2: 0 | Strat2 Distance: -0.007483 | Requirement Met: ✗
# MLP (LL):    P1 Win: 72.22% | P2 Win: 27.78% | Pred: P1 ✓ | Strat1: 32.0 | Strat2: 0 | Strat2 Distance: -0.017471 | Requirement Met: ✗
# MLP (Err):   P1 Win: 78.65% | P2 Win: 21.35% | Pred: P1 ✓ | Strat1: 32.0 | Strat2: 0 | Strat2 Distance: 0.046836 | Requirement Met: ✗
#
# === Match 13 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.076803 | Winner odds: 1.75 | Loser odds: 2.21 | Margin: 0.023917 | P1 Prob: 0.571429 | P2 Prob: 0.452489
# LogReg:      P1 Win: 40.39% | P2 Win: 59.61% | Pred: P2 ✗ | Strat1: -100 | Strat2: -29.32 | Strat2 Distance: -0.154182 | Requirement Met: ✓
# XGB (LL):    P1 Win: 42.51% | P2 Win: 57.49% | Pred: P2 ✗ | Strat1: -100 | Strat2: -25.62 | Strat2 Distance: -0.133028 | Requirement Met: ✓
# XGB (Err):   P1 Win: 42.46% | P2 Win: 57.54% | Pred: P2 ✗ | Strat1: -100 | Strat2: -25.7 | Strat2 Distance: -0.133510 | Requirement Met: ✓
# MLP (LL):    P1 Win: 36.24% | P2 Win: 63.76% | Pred: P2 ✗ | Strat1: -100 | Strat2: -36.58 | Strat2 Distance: -0.195659 | Requirement Met: ✓
# MLP (Err):   P1 Win: 36.73% | P2 Win: 63.27% | Pred: P2 ✗ | Strat1: -100 | Strat2: -35.73 | Strat2 Distance: -0.190808 | Requirement Met: ✓
#
# === Match 14 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.080223 | Winner odds: 1.79 | Loser odds: 2.14 | Margin: 0.025949 | P1 Prob: 0.558659 | P2 Prob: 0.467290
# LogReg:      P1 Win: 47.67% | P2 Win: 52.33% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.067879 | Requirement Met: ✗
# XGB (LL):    P1 Win: 49.34% | P2 Win: 50.66% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.051154 | Requirement Met: ✗
# XGB (Err):   P1 Win: 51.09% | P2 Win: 48.91% | Pred: P1 ✓ | Strat1: 79.0 | Strat2: 0 | Strat2 Distance: -0.033666 | Requirement Met: ✗
# MLP (LL):    P1 Win: 48.19% | P2 Win: 51.81% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.062653 | Requirement Met: ✗
# MLP (Err):   P1 Win: 46.89% | P2 Win: 53.11% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.075648 | Requirement Met: ✗
#
# === Match 15 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.030452 | Winner odds: 1.06 | Loser odds: 14.11 | Margin: 0.014268 | P1 Prob: 0.943396 | P2 Prob: 0.070872
# LogReg:      P1 Win: 91.55% | P2 Win: 8.45% | Pred: P1 ✓ | Strat1: 6.0 | Strat2: 0 | Strat2 Distance: -0.014603 | Requirement Met: ✗
# XGB (LL):    P1 Win: 91.59% | P2 Win: 8.41% | Pred: P1 ✓ | Strat1: 6.0 | Strat2: 0 | Strat2 Distance: -0.014248 | Requirement Met: ✗
# XGB (Err):   P1 Win: 88.52% | P2 Win: 11.48% | Pred: P1 ✓ | Strat1: 6.0 | Strat2: -6.17 | Strat2 Distance: -0.044961 | Requirement Met: ✓
# MLP (LL):    P1 Win: 93.84% | P2 Win: 6.16% | Pred: P1 ✓ | Strat1: 6.0 | Strat2: 0 | Strat2 Distance: 0.008306 | Requirement Met: ✗
# MLP (Err):   P1 Win: 92.65% | P2 Win: 7.35% | Pred: P1 ✓ | Strat1: 6.0 | Strat2: 0 | Strat2 Distance: -0.003596 | Requirement Met: ✗
#
# === Match 16 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.015182 | Winner odds: 1.01 | Loser odds: 47.27 | Margin: 0.011254 | P1 Prob: 0.990099 | P2 Prob: 0.021155
# LogReg:      P1 Win: 96.41% | P2 Win: 3.59% | Pred: P1 ✓ | Strat1: 1.0 | Strat2: 0 | Strat2 Distance: -0.014985 | Requirement Met: ✗
# XGB (LL):    P1 Win: 96.56% | P2 Win: 3.44% | Pred: P1 ✓ | Strat1: 1.0 | Strat2: 0 | Strat2 Distance: -0.013511 | Requirement Met: ✗
# XGB (Err):   P1 Win: 94.46% | P2 Win: 5.54% | Pred: P1 ✓ | Strat1: 1.0 | Strat2: -4.59 | Strat2 Distance: -0.034447 | Requirement Met: ✓
# MLP (LL):    P1 Win: 96.78% | P2 Win: 3.22% | Pred: P1 ✓ | Strat1: 1.0 | Strat2: 0 | Strat2 Distance: -0.011265 | Requirement Met: ✗
# MLP (Err):   P1 Win: 97.13% | P2 Win: 2.87% | Pred: P1 ✓ | Strat1: 1.0 | Strat2: 0 | Strat2 Distance: -0.007820 | Requirement Met: ✗
#
# === Match 17 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.065150 | Winner odds: 3.78 | Loser odds: 1.32 | Margin: 0.022126 | P1 Prob: 0.757576 | P2 Prob: 0.264550
# LogReg:      P1 Win: 65.48% | P2 Win: 34.52% | Pred: P1 ✗ | Strat1: -100 | Strat2: 30.48 | Strat2 Distance: -0.086350 | Requirement Met: ✓
# XGB (LL):    P1 Win: 62.01% | P2 Win: 37.99% | Pred: P1 ✗ | Strat1: -100 | Strat2: 43.6 | Strat2 Distance: -0.121070 | Requirement Met: ✓
# XGB (Err):   P1 Win: 61.14% | P2 Win: 38.86% | Pred: P1 ✗ | Strat1: -100 | Strat2: 46.9 | Strat2 Distance: -0.129794 | Requirement Met: ✓
# MLP (LL):    P1 Win: 64.47% | P2 Win: 35.53% | Pred: P1 ✗ | Strat1: -100 | Strat2: 34.31 | Strat2 Distance: -0.096488 | Requirement Met: ✓
# MLP (Err):   P1 Win: 68.79% | P2 Win: 31.21% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.053274 | Requirement Met: ✗
#
# === Match 18 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.077105 | Winner odds: 2.33 | Loser odds: 1.68 | Margin: 0.024423 | P1 Prob: 0.429185 | P2 Prob: 0.595238
# LogReg:      P1 Win: 33.97% | P2 Win: 66.03% | Pred: P2 ✗ | Strat1: -100 | Strat2: -20.85 | Strat2 Distance: -0.079268 | Requirement Met: ✓
# XGB (LL):    P1 Win: 37.25% | P2 Win: 62.75% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.046441 | Requirement Met: ✗
# XGB (Err):   P1 Win: 37.80% | P2 Win: 62.20% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.040919 | Requirement Met: ✗
# MLP (LL):    P1 Win: 32.97% | P2 Win: 67.03% | Pred: P2 ✗ | Strat1: -100 | Strat2: -23.18 | Strat2 Distance: -0.089273 | Requirement Met: ✓
# MLP (Err):   P1 Win: 35.78% | P2 Win: 64.22% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.061173 | Requirement Met: ✗
#
# === Match 19 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.066147 | Winner odds: 1.31 | Loser odds: 3.85 | Margin: 0.023099 | P1 Prob: 0.763359 | P2 Prob: 0.259740
# LogReg:      P1 Win: 70.17% | P2 Win: 29.83% | Pred: P1 ✓ | Strat1: 31.0 | Strat2: 0 | Strat2 Distance: -0.044452 | Requirement Met: ✗
# XGB (LL):    P1 Win: 72.95% | P2 Win: 27.05% | Pred: P1 ✓ | Strat1: 31.0 | Strat2: 0 | Strat2 Distance: -0.016634 | Requirement Met: ✗
# XGB (Err):   P1 Win: 73.24% | P2 Win: 26.76% | Pred: P1 ✓ | Strat1: 31.0 | Strat2: 0 | Strat2 Distance: -0.013681 | Requirement Met: ✗
# MLP (LL):    P1 Win: 71.08% | P2 Win: 28.92% | Pred: P1 ✓ | Strat1: 31.0 | Strat2: 0 | Strat2 Distance: -0.035341 | Requirement Met: ✗
# MLP (Err):   P1 Win: 74.16% | P2 Win: 25.84% | Pred: P1 ✓ | Strat1: 31.0 | Strat2: 0 | Strat2 Distance: -0.004557 | Requirement Met: ✗
#
# === Match 20 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.076873 | Winner odds: 2.35 | Loser odds: 1.67 | Margin: 0.024334 | P1 Prob: 0.598802 | P2 Prob: 0.425532
# LogReg:      P1 Win: 50.20% | P2 Win: 49.80% | Pred: P1 ✗ | Strat1: -100 | Strat2: 17.04 | Strat2 Distance: -0.082623 | Requirement Met: ✓
# XGB (LL):    P1 Win: 50.71% | P2 Win: 49.29% | Pred: P1 ✗ | Strat1: -100 | Strat2: 15.83 | Strat2 Distance: -0.077463 | Requirement Met: ✓
# XGB (Err):   P1 Win: 47.21% | P2 Win: 52.79% | Pred: P2 ✓ | Strat1: 135.0 | Strat2: 24.04 | Strat2 Distance: -0.112427 | Requirement Met: ✓
# MLP (LL):    P1 Win: 44.29% | P2 Win: 55.71% | Pred: P2 ✓ | Strat1: 135.0 | Strat2: 30.91 | Strat2 Distance: -0.141653 | Requirement Met: ✓
# MLP (Err):   P1 Win: 50.17% | P2 Win: 49.83% | Pred: P1 ✗ | Strat1: -100 | Strat2: 17.11 | Strat2 Distance: -0.082926 | Requirement Met: ✓
#
# === Match 21 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.070054 | Winner odds: 3.66 | Loser odds: 1.33 | Margin: 0.025104 | P1 Prob: 0.273224 | P2 Prob: 0.751880
# LogReg:      P1 Win: 33.05% | P2 Win: 66.95% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.063927 | Requirement Met: ✗
# XGB (LL):    P1 Win: 33.39% | P2 Win: 66.61% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.067349 | Requirement Met: ✗
# XGB (Err):   P1 Win: 33.42% | P2 Win: 66.58% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.067643 | Requirement Met: ✗
# MLP (LL):    P1 Win: 37.10% | P2 Win: 62.90% | Pred: P2 ✗ | Strat1: -100 | Strat2: 35.78 | Strat2 Distance: 0.104453 | Requirement Met: ✓
# MLP (Err):   P1 Win: 31.20% | P2 Win: 68.80% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.045479 | Requirement Met: ✗
#
# === Match 22 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.067096 | Winner odds: 1.24 | Loser odds: 4.54 | Margin: 0.026716 | P1 Prob: 0.220264 | P2 Prob: 0.806452
# LogReg:      P1 Win: 35.34% | P2 Win: 64.66% | Pred: P2 ✓ | Strat1: 24.0 | Strat2: -19.83 | Strat2 Distance: 0.138904 | Requirement Met: ✓
# XGB (LL):    P1 Win: 37.08% | P2 Win: 62.92% | Pred: P2 ✓ | Strat1: 24.0 | Strat2: -21.98 | Strat2 Distance: 0.156265 | Requirement Met: ✓
# XGB (Err):   P1 Win: 39.11% | P2 Win: 60.89% | Pred: P2 ✓ | Strat1: 24.0 | Strat2: -24.5 | Strat2 Distance: 0.176592 | Requirement Met: ✓
# MLP (LL):    P1 Win: 38.72% | P2 Win: 61.28% | Pred: P2 ✓ | Strat1: 24.0 | Strat2: -24.02 | Strat2 Distance: 0.172688 | Requirement Met: ✓
# MLP (Err):   P1 Win: 38.38% | P2 Win: 61.62% | Pred: P2 ✓ | Strat1: 24.0 | Strat2: -23.6 | Strat2 Distance: 0.169309 | Requirement Met: ✓
#
# === Match 23 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.062630 | Winner odds: 1.23 | Loser odds: 4.74 | Margin: 0.023979 | P1 Prob: 0.210970 | P2 Prob: 0.813008
# LogReg:      P1 Win: 27.45% | P2 Win: 72.55% | Pred: P2 ✓ | Strat1: 23.0 | Strat2: -10.76 | Strat2 Distance: 0.068458 | Requirement Met: ✓
# XGB (LL):    P1 Win: 21.46% | P2 Win: 78.54% | Pred: P2 ✓ | Strat1: 23.0 | Strat2: 0 | Strat2 Distance: 0.008549 | Requirement Met: ✗
# XGB (Err):   P1 Win: 20.94% | P2 Win: 79.06% | Pred: P2 ✓ | Strat1: 23.0 | Strat2: 0 | Strat2 Distance: 0.003373 | Requirement Met: ✗
# MLP (LL):    P1 Win: 25.45% | P2 Win: 74.55% | Pred: P2 ✓ | Strat1: 23.0 | Strat2: 0 | Strat2 Distance: 0.048503 | Requirement Met: ✗
# MLP (Err):   P1 Win: 24.02% | P2 Win: 75.98% | Pred: P2 ✓ | Strat1: 23.0 | Strat2: 0 | Strat2 Distance: 0.034127 | Requirement Met: ✗
#
# === Match 24 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.064780 | Winner odds: 1.26 | Loser odds: 4.34 | Margin: 0.024066 | P1 Prob: 0.230415 | P2 Prob: 0.793651
# LogReg:      P1 Win: 18.15% | P2 Win: 81.85% | Pred: P2 ✓ | Strat1: 26.0 | Strat2: 0 | Strat2 Distance: -0.043525 | Requirement Met: ✗
# XGB (LL):    P1 Win: 12.46% | P2 Win: 87.54% | Pred: P2 ✓ | Strat1: 26.0 | Strat2: 10.3 | Strat2 Distance: -0.100361 | Requirement Met: ✓
# XGB (Err):   P1 Win: 14.03% | P2 Win: 85.97% | Pred: P2 ✓ | Strat1: 26.0 | Strat2: 8.32 | Strat2 Distance: -0.084664 | Requirement Met: ✓
# MLP (LL):    P1 Win: 20.29% | P2 Win: 79.71% | Pred: P2 ✓ | Strat1: 26.0 | Strat2: 0 | Strat2 Distance: -0.022133 | Requirement Met: ✗
# MLP (Err):   P1 Win: 15.83% | P2 Win: 84.17% | Pred: P2 ✓ | Strat1: 26.0 | Strat2: 6.05 | Strat2 Distance: -0.066702 | Requirement Met: ✓
#
# === Match 25 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.081033 | Winner odds: 2.11 | Loser odds: 1.81 | Margin: 0.026420 | P1 Prob: 0.473934 | P2 Prob: 0.552486
# LogReg:      P1 Win: 54.39% | P2 Win: 45.61% | Pred: P1 ✓ | Strat1: 111.0 | Strat2: 14.77 | Strat2 Distance: 0.082208 | Requirement Met: ✓
# XGB (LL):    P1 Win: 58.40% | P2 Win: 41.60% | Pred: P1 ✓ | Strat1: 111.0 | Strat2: 23.23 | Strat2 Distance: 0.122284 | Requirement Met: ✓
# XGB (Err):   P1 Win: 57.44% | P2 Win: 42.56% | Pred: P1 ✓ | Strat1: 111.0 | Strat2: 21.19 | Strat2 Distance: 0.112635 | Requirement Met: ✓
# MLP (LL):    P1 Win: 60.05% | P2 Win: 39.95% | Pred: P1 ✓ | Strat1: 111.0 | Strat2: 26.7 | Strat2 Distance: 0.138741 | Requirement Met: ✓
# MLP (Err):   P1 Win: 64.28% | P2 Win: 35.72% | Pred: P1 ✓ | Strat1: 111.0 | Strat2: 35.63 | Strat2 Distance: 0.181043 | Requirement Met: ✓
#
# === Match 26 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.074128 | Winner odds: 2.34 | Loser odds: 1.68 | Margin: 0.022589 | P1 Prob: 0.595238 | P2 Prob: 0.427350
# LogReg:      P1 Win: 50.98% | P2 Win: 49.02% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.072264 | Requirement Met: ✗
# XGB (LL):    P1 Win: 47.45% | P2 Win: 52.55% | Pred: P2 ✓ | Strat1: 134.0 | Strat2: 22.98 | Strat2 Distance: -0.107626 | Requirement Met: ✓
# XGB (Err):   P1 Win: 45.71% | P2 Win: 54.29% | Pred: P2 ✓ | Strat1: 134.0 | Strat2: 27.05 | Strat2 Distance: -0.125025 | Requirement Met: ✓
# MLP (LL):    P1 Win: 41.54% | P2 Win: 58.46% | Pred: P2 ✓ | Strat1: 134.0 | Strat2: 36.8 | Strat2 Distance: -0.166721 | Requirement Met: ✓
# MLP (Err):   P1 Win: 41.86% | P2 Win: 58.14% | Pred: P2 ✓ | Strat1: 134.0 | Strat2: 36.04 | Strat2 Distance: -0.163452 | Requirement Met: ✓
#
# === Match 27 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.065789 | Winner odds: 4.56 | Loser odds: 1.24 | Margin: 0.025750 | P1 Prob: 0.806452 | P2 Prob: 0.219298
# LogReg:      P1 Win: 77.73% | P2 Win: 22.27% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.008936 | Requirement Met: ✗
# XGB (LL):    P1 Win: 79.66% | P2 Win: 20.34% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.010420 | Requirement Met: ✗
# XGB (Err):   P1 Win: 79.62% | P2 Win: 20.38% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.009970 | Requirement Met: ✗
# MLP (LL):    P1 Win: 84.40% | P2 Win: 15.60% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.057814 | Requirement Met: ✗
# MLP (Err):   P1 Win: 83.33% | P2 Win: 16.67% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.047112 | Requirement Met: ✗
#
# === Match 28 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.071874 | Winner odds: 1.38 | Loser odds: 3.33 | Margin: 0.024938 | P1 Prob: 0.300300 | P2 Prob: 0.724638
# LogReg:      P1 Win: 29.83% | P2 Win: 70.17% | Pred: P2 ✓ | Strat1: 38.0 | Strat2: 0 | Strat2 Distance: 0.005262 | Requirement Met: ✗
# XGB (LL):    P1 Win: 28.78% | P2 Win: 71.22% | Pred: P2 ✓ | Strat1: 38.0 | Strat2: 0 | Strat2 Distance: -0.005166 | Requirement Met: ✗
# XGB (Err):   P1 Win: 29.52% | P2 Win: 70.48% | Pred: P2 ✓ | Strat1: 38.0 | Strat2: 0 | Strat2 Distance: 0.002176 | Requirement Met: ✗
# MLP (LL):    P1 Win: 30.68% | P2 Win: 69.32% | Pred: P2 ✓ | Strat1: 38.0 | Strat2: 0 | Strat2 Distance: 0.013795 | Requirement Met: ✗
# MLP (Err):   P1 Win: 25.61% | P2 Win: 74.39% | Pred: P2 ✓ | Strat1: 38.0 | Strat2: 0 | Strat2 Distance: -0.036859 | Requirement Met: ✗
#
# === Match 29 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.057327 | Winner odds: 1.14 | Loser odds: 6.7 | Margin: 0.026447 | P1 Prob: 0.149254 | P2 Prob: 0.877193
# LogReg:      P1 Win: 27.99% | P2 Win: 72.01% | Pred: P2 ✓ | Strat1: 14.0 | Strat2: -17.9 | Strat2 Distance: 0.134455 | Requirement Met: ✓
# XGB (LL):    P1 Win: 24.23% | P2 Win: 75.77% | Pred: P2 ✓ | Strat1: 14.0 | Strat2: -13.63 | Strat2 Distance: 0.096926 | Requirement Met: ✓
# XGB (Err):   P1 Win: 23.37% | P2 Win: 76.63% | Pred: P2 ✓ | Strat1: 14.0 | Strat2: -12.64 | Strat2 Distance: 0.088307 | Requirement Met: ✓
# MLP (LL):    P1 Win: 24.58% | P2 Win: 75.42% | Pred: P2 ✓ | Strat1: 14.0 | Strat2: -14.03 | Strat2 Distance: 0.100431 | Requirement Met: ✓
# MLP (Err):   P1 Win: 25.49% | P2 Win: 74.51% | Pred: P2 ✓ | Strat1: 14.0 | Strat2: -15.05 | Strat2 Distance: 0.109446 | Requirement Met: ✓
#
# === Match 30 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.053295 | Winner odds: 1.16 | Loser odds: 6.27 | Margin: 0.021559 | P1 Prob: 0.862069 | P2 Prob: 0.159490
# LogReg:      P1 Win: 86.69% | P2 Win: 13.31% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: 0.022976 | Requirement Met: ✗
# XGB (LL):    P1 Win: 91.02% | P2 Win: 8.98% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 5.58 | Strat2 Distance: 0.066318 | Requirement Met: ✓
# XGB (Err):   P1 Win: 83.47% | P2 Win: 16.53% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: -0.009214 | Requirement Met: ✗
# MLP (LL):    P1 Win: 90.32% | P2 Win: 9.68% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 4.77 | Strat2 Distance: 0.059286 | Requirement Met: ✓
# MLP (Err):   P1 Win: 87.21% | P2 Win: 12.79% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: 0.028271 | Requirement Met: ✗
#
# === Match 31 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.064347 | Winner odds: 1.25 | Loser odds: 4.46 | Margin: 0.024215 | P1 Prob: 0.224215 | P2 Prob: 0.800000
# LogReg:      P1 Win: 27.86% | P2 Win: 72.14% | Pred: P2 ✓ | Strat1: 25.0 | Strat2: 0 | Strat2 Distance: 0.059694 | Requirement Met: ✗
# XGB (LL):    P1 Win: 23.76% | P2 Win: 76.24% | Pred: P2 ✓ | Strat1: 25.0 | Strat2: 0 | Strat2 Distance: 0.018705 | Requirement Met: ✗
# XGB (Err):   P1 Win: 26.34% | P2 Win: 73.66% | Pred: P2 ✓ | Strat1: 25.0 | Strat2: 0 | Strat2 Distance: 0.044474 | Requirement Met: ✗
# MLP (LL):    P1 Win: 33.39% | P2 Win: 66.61% | Pred: P2 ✓ | Strat1: 25.0 | Strat2: -16.74 | Strat2 Distance: 0.114993 | Requirement Met: ✓
# MLP (Err):   P1 Win: 26.40% | P2 Win: 73.60% | Pred: P2 ✓ | Strat1: 25.0 | Strat2: 0 | Strat2 Distance: 0.045054 | Requirement Met: ✗
#
# === Match 32 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.063885 | Winner odds: 1.21 | Loser odds: 5.01 | Margin: 0.026047 | P1 Prob: 0.826446 | P2 Prob: 0.199601
# LogReg:      P1 Win: 80.81% | P2 Win: 19.19% | Pred: P1 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: 0.002646 | Requirement Met: ✗
# XGB (LL):    P1 Win: 79.22% | P2 Win: 20.78% | Pred: P1 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: -0.013258 | Requirement Met: ✗
# XGB (Err):   P1 Win: 77.84% | P2 Win: 22.16% | Pred: P1 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: -0.027101 | Requirement Met: ✗
# MLP (LL):    P1 Win: 79.59% | P2 Win: 20.41% | Pred: P1 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: -0.009529 | Requirement Met: ✗
# MLP (Err):   P1 Win: 80.66% | P2 Win: 19.34% | Pred: P1 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: 0.001108 | Requirement Met: ✗
#
# === Match 33 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.076655 | Winner odds: 1.47 | Loser odds: 2.89 | Margin: 0.026293 | P1 Prob: 0.346021 | P2 Prob: 0.680272
# LogReg:      P1 Win: 36.65% | P2 Win: 63.35% | Pred: P2 ✓ | Strat1: 47.0 | Strat2: 0 | Strat2 Distance: 0.029364 | Requirement Met: ✗
# XGB (LL):    P1 Win: 36.35% | P2 Win: 63.65% | Pred: P2 ✓ | Strat1: 47.0 | Strat2: 0 | Strat2 Distance: 0.026301 | Requirement Met: ✗
# XGB (Err):   P1 Win: 36.67% | P2 Win: 63.33% | Pred: P2 ✓ | Strat1: 47.0 | Strat2: 0 | Strat2 Distance: 0.029581 | Requirement Met: ✗
# MLP (LL):    P1 Win: 35.76% | P2 Win: 64.24% | Pred: P2 ✓ | Strat1: 47.0 | Strat2: 0 | Strat2 Distance: 0.020435 | Requirement Met: ✗
# MLP (Err):   P1 Win: 30.20% | P2 Win: 69.80% | Pred: P2 ✓ | Strat1: 47.0 | Strat2: 0 | Strat2 Distance: -0.035144 | Requirement Met: ✗
#
# === Match 34 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.078776 | Winner odds: 1.71 | Loser odds: 2.27 | Margin: 0.025324 | P1 Prob: 0.440529 | P2 Prob: 0.584795
# LogReg:      P1 Win: 49.62% | P2 Win: 50.38% | Pred: P2 ✓ | Strat1: 71.0 | Strat2: 0 | Strat2 Distance: 0.066509 | Requirement Met: ✗
# XGB (LL):    P1 Win: 52.73% | P2 Win: 47.27% | Pred: P1 ✗ | Strat1: -100 | Strat2: -19.17 | Strat2 Distance: 0.097679 | Requirement Met: ✓
# XGB (Err):   P1 Win: 49.49% | P2 Win: 50.51% | Pred: P2 ✓ | Strat1: 71.0 | Strat2: 0 | Strat2 Distance: 0.065252 | Requirement Met: ✗
# MLP (LL):    P1 Win: 49.96% | P2 Win: 50.04% | Pred: P2 ✓ | Strat1: 71.0 | Strat2: 0 | Strat2 Distance: 0.069927 | Requirement Met: ✗
# MLP (Err):   P1 Win: 59.20% | P2 Win: 40.80% | Pred: P1 ✗ | Strat1: -100 | Strat2: -30.24 | Strat2 Distance: 0.162380 | Requirement Met: ✓
#
# === Match 35 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.055041 | Winner odds: 1.13 | Loser odds: 7.11 | Margin: 0.025603 | P1 Prob: 0.140647 | P2 Prob: 0.884956
# LogReg:      P1 Win: 18.66% | P2 Win: 81.34% | Pred: P2 ✓ | Strat1: 13.0 | Strat2: 0 | Strat2 Distance: 0.049475 | Requirement Met: ✗
# XGB (LL):    P1 Win: 19.72% | P2 Win: 80.28% | Pred: P2 ✓ | Strat1: 13.0 | Strat2: -9.29 | Strat2 Distance: 0.060084 | Requirement Met: ✓
# XGB (Err):   P1 Win: 20.38% | P2 Win: 79.62% | Pred: P2 ✓ | Strat1: 13.0 | Strat2: -10.03 | Strat2 Distance: 0.066647 | Requirement Met: ✓
# MLP (LL):    P1 Win: 15.27% | P2 Win: 84.73% | Pred: P2 ✓ | Strat1: 13.0 | Strat2: 0 | Strat2 Distance: 0.015576 | Requirement Met: ✗
# MLP (Err):   P1 Win: 17.22% | P2 Win: 82.78% | Pred: P2 ✓ | Strat1: 13.0 | Strat2: 0 | Strat2 Distance: 0.035031 | Requirement Met: ✗
#
# === Match 36 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.071416 | Winner odds: 3.45 | Loser odds: 1.36 | Margin: 0.025149 | P1 Prob: 0.735294 | P2 Prob: 0.289855
# LogReg:      P1 Win: 57.79% | P2 Win: 42.21% | Pred: P1 ✗ | Strat1: -100 | Strat2: 45.61 | Strat2 Distance: -0.139311 | Requirement Met: ✓
# XGB (LL):    P1 Win: 60.33% | P2 Win: 39.67% | Pred: P1 ✗ | Strat1: -100 | Strat2: 36.87 | Strat2 Distance: -0.113979 | Requirement Met: ✓
# XGB (Err):   P1 Win: 61.26% | P2 Win: 38.74% | Pred: P1 ✗ | Strat1: -100 | Strat2: 33.65 | Strat2 Distance: -0.104647 | Requirement Met: ✓
# MLP (LL):    P1 Win: 65.83% | P2 Win: 34.17% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.058943 | Requirement Met: ✗
# MLP (Err):   P1 Win: 63.43% | P2 Win: 36.57% | Pred: P1 ✗ | Strat1: -100 | Strat2: 26.18 | Strat2 Distance: -0.082997 | Requirement Met: ✓
#
# === Match 37 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.023058 | Winner odds: 1.02 | Loser odds: 28.24 | Margin: 0.015803 | P1 Prob: 0.980392 | P2 Prob: 0.035411
# LogReg:      P1 Win: 88.87% | P2 Win: 11.13% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: -9.35 | Strat2 Distance: -0.076415 | Requirement Met: ✓
# XGB (LL):    P1 Win: 83.33% | P2 Win: 16.67% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: -15.01 | Strat2 Distance: -0.131862 | Requirement Met: ✓
# XGB (Err):   P1 Win: 82.79% | P2 Win: 17.21% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: -15.55 | Strat2 Distance: -0.137228 | Requirement Met: ✓
# MLP (LL):    P1 Win: 89.72% | P2 Win: 10.28% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: -8.48 | Strat2 Distance: -0.067923 | Requirement Met: ✓
# MLP (Err):   P1 Win: 90.93% | P2 Win: 9.07% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: -7.26 | Strat2 Distance: -0.055883 | Requirement Met: ✓
#
# === Match 38 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.014573 | Winner odds: 1.02 | Loser odds: 36.25 | Margin: 0.007978 | P1 Prob: 0.980392 | P2 Prob: 0.027586
# LogReg:      P1 Win: 88.29% | P2 Win: 11.71% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: -9.94 | Strat2 Distance: -0.089737 | Requirement Met: ✓
# XGB (LL):    P1 Win: 89.03% | P2 Win: 10.97% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: -9.19 | Strat2 Distance: -0.082371 | Requirement Met: ✓
# XGB (Err):   P1 Win: 86.77% | P2 Win: 13.23% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: -11.5 | Strat2 Distance: -0.104981 | Requirement Met: ✓
# MLP (LL):    P1 Win: 90.72% | P2 Win: 9.28% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: -7.47 | Strat2 Distance: -0.065449 | Requirement Met: ✓
# MLP (Err):   P1 Win: 87.64% | P2 Win: 12.36% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: -10.61 | Strat2 Distance: -0.096268 | Requirement Met: ✓
#
# === Match 39 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.072414 | Winner odds: 2.65 | Loser odds: 1.55 | Margin: 0.022520 | P1 Prob: 0.645161 | P2 Prob: 0.377358
# LogReg:      P1 Win: 64.67% | P2 Win: 35.33% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.015712 | Requirement Met: ✗
# XGB (LL):    P1 Win: 68.92% | P2 Win: 31.08% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.058277 | Requirement Met: ✗
# XGB (Err):   P1 Win: 69.20% | P2 Win: 30.80% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.061020 | Requirement Met: ✗
# MLP (LL):    P1 Win: 63.07% | P2 Win: 36.93% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.000302 | Requirement Met: ✗
# MLP (Err):   P1 Win: 69.54% | P2 Win: 30.46% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.064468 | Requirement Met: ✗
#
# === Match 40 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.078775 | Winner odds: 2.47 | Loser odds: 1.61 | Margin: 0.025976 | P1 Prob: 0.621118 | P2 Prob: 0.404858
# LogReg:      P1 Win: 60.74% | P2 Win: 39.26% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.002000 | Requirement Met: ✗
# XGB (LL):    P1 Win: 50.74% | P2 Win: 49.26% | Pred: P1 ✗ | Strat1: -100 | Strat2: 21.67 | Strat2 Distance: -0.097994 | Requirement Met: ✓
# XGB (Err):   P1 Win: 58.66% | P2 Win: 41.34% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.018748 | Requirement Met: ✗
# MLP (LL):    P1 Win: 54.68% | P2 Win: 45.32% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.058623 | Requirement Met: ✗
# MLP (Err):   P1 Win: 57.13% | P2 Win: 42.87% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.034135 | Requirement Met: ✗
#
# === Match 41 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.078752 | Winner odds: 2.09 | Loser odds: 1.83 | Margin: 0.024917 | P1 Prob: 0.546448 | P2 Prob: 0.478469
# LogReg:      P1 Win: 46.53% | P2 Win: 53.47% | Pred: P2 ✓ | Strat1: 109.0 | Strat2: 0 | Strat2 Distance: -0.067902 | Requirement Met: ✗
# XGB (LL):    P1 Win: 46.67% | P2 Win: 53.33% | Pred: P2 ✓ | Strat1: 109.0 | Strat2: 0 | Strat2 Distance: -0.066506 | Requirement Met: ✗
# XGB (Err):   P1 Win: 45.98% | P2 Win: 54.02% | Pred: P2 ✓ | Strat1: 109.0 | Strat2: 0 | Strat2 Distance: -0.073362 | Requirement Met: ✗
# MLP (LL):    P1 Win: 41.44% | P2 Win: 58.56% | Pred: P2 ✓ | Strat1: 109.0 | Strat2: 22.4 | Strat2 Distance: -0.118800 | Requirement Met: ✓
# MLP (Err):   P1 Win: 38.66% | P2 Win: 61.34% | Pred: P2 ✓ | Strat1: 109.0 | Strat2: 28.21 | Strat2 Distance: -0.146607 | Requirement Met: ✓
#
# === Match 42 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.072438 | Winner odds: 1.4 | Loser odds: 3.22 | Margin: 0.024845 | P1 Prob: 0.310559 | P2 Prob: 0.714286
# LogReg:      P1 Win: 32.83% | P2 Win: 67.17% | Pred: P2 ✓ | Strat1: 40.0 | Strat2: 0 | Strat2 Distance: 0.025281 | Requirement Met: ✗
# XGB (LL):    P1 Win: 34.38% | P2 Win: 65.62% | Pred: P2 ✓ | Strat1: 40.0 | Strat2: 0 | Strat2 Distance: 0.040764 | Requirement Met: ✗
# XGB (Err):   P1 Win: 36.54% | P2 Win: 63.46% | Pred: P2 ✓ | Strat1: 40.0 | Strat2: 0 | Strat2 Distance: 0.062361 | Requirement Met: ✗
# MLP (LL):    P1 Win: 37.29% | P2 Win: 62.71% | Pred: P2 ✓ | Strat1: 40.0 | Strat2: 0 | Strat2 Distance: 0.069917 | Requirement Met: ✗
# MLP (Err):   P1 Win: 33.90% | P2 Win: 66.10% | Pred: P2 ✓ | Strat1: 40.0 | Strat2: 0 | Strat2 Distance: 0.035955 | Requirement Met: ✗
#
# === Match 43 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.072746 | Winner odds: 1.37 | Loser odds: 3.38 | Margin: 0.025785 | P1 Prob: 0.729927 | P2 Prob: 0.295858
# LogReg:      P1 Win: 51.64% | P2 Win: 48.36% | Pred: P1 ✓ | Strat1: 37.0 | Strat2: -29.25 | Strat2 Distance: -0.195154 | Requirement Met: ✓
# XGB (LL):    P1 Win: 61.83% | P2 Win: 38.17% | Pred: P1 ✓ | Strat1: 37.0 | Strat2: -15.29 | Strat2 Distance: -0.093280 | Requirement Met: ✓
# XGB (Err):   P1 Win: 60.35% | P2 Win: 39.65% | Pred: P1 ✓ | Strat1: 37.0 | Strat2: -17.31 | Strat2 Distance: -0.108033 | Requirement Met: ✓
# MLP (LL):    P1 Win: 52.15% | P2 Win: 47.85% | Pred: P1 ✓ | Strat1: 37.0 | Strat2: -28.55 | Strat2 Distance: -0.190035 | Requirement Met: ✓
# MLP (Err):   P1 Win: 59.91% | P2 Win: 40.09% | Pred: P1 ✓ | Strat1: 37.0 | Strat2: -17.92 | Strat2 Distance: -0.112482 | Requirement Met: ✓
#
# === Match 44 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.079637 | Winner odds: 1.65 | Loser odds: 2.38 | Margin: 0.026229 | P1 Prob: 0.420168 | P2 Prob: 0.606061
# LogReg:      P1 Win: 52.32% | P2 Win: 47.68% | Pred: P1 ✗ | Strat1: -100 | Strat2: -21.33 | Strat2 Distance: 0.113790 | Requirement Met: ✓
# XGB (LL):    P1 Win: 49.86% | P2 Win: 50.14% | Pred: P2 ✓ | Strat1: 65.0 | Strat2: -17.27 | Strat2 Distance: 0.089197 | Requirement Met: ✓
# XGB (Err):   P1 Win: 48.61% | P2 Win: 51.39% | Pred: P2 ✓ | Strat1: 65.0 | Strat2: 0 | Strat2 Distance: 0.076715 | Requirement Met: ✗
# MLP (LL):    P1 Win: 54.80% | P2 Win: 45.20% | Pred: P1 ✗ | Strat1: -100 | Strat2: -25.42 | Strat2 Distance: 0.138586 | Requirement Met: ✓
# MLP (Err):   P1 Win: 58.62% | P2 Win: 41.38% | Pred: P1 ✗ | Strat1: -100 | Strat2: -31.72 | Strat2 Distance: 0.176723 | Requirement Met: ✓
#
# === Match 45 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.073024 | Winner odds: 1.47 | Loser odds: 2.91 | Margin: 0.023915 | P1 Prob: 0.680272 | P2 Prob: 0.343643
# LogReg:      P1 Win: 57.67% | P2 Win: 42.33% | Pred: P1 ✓ | Strat1: 47.0 | Strat2: -15.23 | Strat2 Distance: -0.087699 | Requirement Met: ✓
# XGB (LL):    P1 Win: 61.39% | P2 Win: 38.61% | Pred: P1 ✓ | Strat1: 47.0 | Strat2: 0 | Strat2 Distance: -0.050511 | Requirement Met: ✗
# XGB (Err):   P1 Win: 61.22% | P2 Win: 38.78% | Pred: P1 ✓ | Strat1: 47.0 | Strat2: 0 | Strat2 Distance: -0.052212 | Requirement Met: ✗
# MLP (LL):    P1 Win: 52.86% | P2 Win: 47.14% | Pred: P1 ✓ | Strat1: 47.0 | Strat2: -22.3 | Strat2 Distance: -0.135809 | Requirement Met: ✓
# MLP (Err):   P1 Win: 61.89% | P2 Win: 38.11% | Pred: P1 ✓ | Strat1: 47.0 | Strat2: 0 | Strat2 Distance: -0.045482 | Requirement Met: ✗
#
# === Match 46 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.023742 | Winner odds: 1.02 | Loser odds: 27.72 | Margin: 0.016467 | P1 Prob: 0.980392 | P2 Prob: 0.036075
# LogReg:      P1 Win: 97.26% | P2 Win: 2.74% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: 0 | Strat2 Distance: 0.008128 | Requirement Met: ✗
# XGB (LL):    P1 Win: 96.63% | P2 Win: 3.37% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: 0 | Strat2 Distance: 0.001809 | Requirement Met: ✗
# XGB (Err):   P1 Win: 94.97% | P2 Win: 5.03% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: 0 | Strat2 Distance: -0.014827 | Requirement Met: ✗
# MLP (LL):    P1 Win: 97.23% | P2 Win: 2.77% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: 0 | Strat2 Distance: 0.007811 | Requirement Met: ✗
# MLP (Err):   P1 Win: 96.95% | P2 Win: 3.05% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: 0 | Strat2 Distance: 0.005015 | Requirement Met: ✗
#
# === Match 47 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.049877 | Winner odds: 1.1 | Loser odds: 8.64 | Margin: 0.024832 | P1 Prob: 0.909091 | P2 Prob: 0.115741
# LogReg:      P1 Win: 90.83% | P2 Win: 9.17% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: 0.021197 | Requirement Met: ✗
# XGB (LL):    P1 Win: 91.29% | P2 Win: 8.71% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: 0.025870 | Requirement Met: ✗
# XGB (Err):   P1 Win: 89.91% | P2 Win: 10.09% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: 0.012016 | Requirement Met: ✗
# MLP (LL):    P1 Win: 91.69% | P2 Win: 8.31% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: 0.029868 | Requirement Met: ✗
# MLP (Err):   P1 Win: 89.96% | P2 Win: 10.04% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: 0.012535 | Requirement Met: ✗
#
# === Match 48 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.076873 | Winner odds: 1.67 | Loser odds: 2.35 | Margin: 0.024334 | P1 Prob: 0.598802 | P2 Prob: 0.425532
# LogReg:      P1 Win: 64.33% | P2 Win: 35.67% | Pred: P1 ✓ | Strat1: 67.0 | Strat2: 0 | Strat2 Distance: 0.058730 | Requirement Met: ✗
# XGB (LL):    P1 Win: 65.79% | P2 Win: 34.21% | Pred: P1 ✓ | Strat1: 67.0 | Strat2: 0 | Strat2 Distance: 0.073338 | Requirement Met: ✗
# XGB (Err):   P1 Win: 65.66% | P2 Win: 34.34% | Pred: P1 ✓ | Strat1: 67.0 | Strat2: 0 | Strat2 Distance: 0.072059 | Requirement Met: ✗
# MLP (LL):    P1 Win: 65.92% | P2 Win: 34.08% | Pred: P1 ✓ | Strat1: 67.0 | Strat2: 0 | Strat2 Distance: 0.074609 | Requirement Met: ✗
# MLP (Err):   P1 Win: 68.56% | P2 Win: 31.44% | Pred: P1 ✓ | Strat1: 67.0 | Strat2: 14.5 | Strat2 Distance: 0.101070 | Requirement Met: ✓
#
# === Match 49 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.074323 | Winner odds: 1.73 | Loser odds: 2.25 | Margin: 0.022479 | P1 Prob: 0.444444 | P2 Prob: 0.578035
# LogReg:      P1 Win: 44.57% | P2 Win: 55.43% | Pred: P2 ✓ | Strat1: 73.0 | Strat2: 0 | Strat2 Distance: 0.011000 | Requirement Met: ✗
# XGB (LL):    P1 Win: 42.57% | P2 Win: 57.43% | Pred: P2 ✓ | Strat1: 73.0 | Strat2: 0 | Strat2 Distance: -0.008997 | Requirement Met: ✗
# XGB (Err):   P1 Win: 43.05% | P2 Win: 56.95% | Pred: P2 ✓ | Strat1: 73.0 | Strat2: 0 | Strat2 Distance: -0.004134 | Requirement Met: ✗
# MLP (LL):    P1 Win: 39.77% | P2 Win: 60.23% | Pred: P2 ✓ | Strat1: 73.0 | Strat2: 0 | Strat2 Distance: -0.036953 | Requirement Met: ✗
# MLP (Err):   P1 Win: 48.21% | P2 Win: 51.79% | Pred: P2 ✓ | Strat1: 73.0 | Strat2: 0 | Strat2 Distance: 0.047419 | Requirement Met: ✗
#
# === Match 50 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.072428 | Winner odds: 1.52 | Loser odds: 2.74 | Margin: 0.022858 | P1 Prob: 0.657895 | P2 Prob: 0.364964
# LogReg:      P1 Win: 63.83% | P2 Win: 36.17% | Pred: P1 ✓ | Strat1: 52.0 | Strat2: 0 | Strat2 Distance: -0.004905 | Requirement Met: ✗
# XGB (LL):    P1 Win: 66.15% | P2 Win: 33.85% | Pred: P1 ✓ | Strat1: 52.0 | Strat2: 0 | Strat2 Distance: 0.018339 | Requirement Met: ✗
# XGB (Err):   P1 Win: 66.10% | P2 Win: 33.90% | Pred: P1 ✓ | Strat1: 52.0 | Strat2: 0 | Strat2 Distance: 0.017855 | Requirement Met: ✗
# MLP (LL):    P1 Win: 70.94% | P2 Win: 29.06% | Pred: P1 ✓ | Strat1: 52.0 | Strat2: 0 | Strat2 Distance: 0.066186 | Requirement Met: ✗
# MLP (Err):   P1 Win: 75.22% | P2 Win: 24.78% | Pred: P1 ✓ | Strat1: 52.0 | Strat2: 14.34 | Strat2 Distance: 0.109037 | Requirement Met: ✓
#
# === Match 51 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.078776 | Winner odds: 1.71 | Loser odds: 2.27 | Margin: 0.025324 | P1 Prob: 0.584795 | P2 Prob: 0.440529
# LogReg:      P1 Win: 48.72% | P2 Win: 51.28% | Pred: P2 ✗ | Strat1: -100 | Strat2: -16.69 | Strat2 Distance: -0.083131 | Requirement Met: ✓
# XGB (LL):    P1 Win: 51.59% | P2 Win: 48.41% | Pred: P1 ✓ | Strat1: 71.0 | Strat2: 0 | Strat2 Distance: -0.054464 | Requirement Met: ✗
# XGB (Err):   P1 Win: 52.58% | P2 Win: 47.42% | Pred: P1 ✓ | Strat1: 71.0 | Strat2: 0 | Strat2 Distance: -0.044567 | Requirement Met: ✗
# MLP (LL):    P1 Win: 46.78% | P2 Win: 53.22% | Pred: P2 ✗ | Strat1: -100 | Strat2: -20.01 | Strat2 Distance: -0.102595 | Requirement Met: ✓
# MLP (Err):   P1 Win: 53.56% | P2 Win: 46.44% | Pred: P1 ✓ | Strat1: 71.0 | Strat2: 0 | Strat2 Distance: -0.034759 | Requirement Met: ✗
#
# === Match 52 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.059500 | Winner odds: 1.23 | Loser odds: 4.79 | Margin: 0.021776 | P1 Prob: 0.208768 | P2 Prob: 0.813008
# LogReg:      P1 Win: 36.45% | P2 Win: 63.55% | Pred: P2 ✓ | Strat1: 23.0 | Strat2: -21.83 | Strat2 Distance: 0.160154 | Requirement Met: ✓
# XGB (LL):    P1 Win: 31.04% | P2 Win: 68.96% | Pred: P2 ✓ | Strat1: 23.0 | Strat2: -15.17 | Strat2 Distance: 0.106045 | Requirement Met: ✓
# XGB (Err):   P1 Win: 34.66% | P2 Win: 65.34% | Pred: P2 ✓ | Strat1: 23.0 | Strat2: -19.64 | Strat2 Distance: 0.142316 | Requirement Met: ✓
# MLP (LL):    P1 Win: 35.88% | P2 Win: 64.12% | Pred: P2 ✓ | Strat1: 23.0 | Strat2: -21.13 | Strat2 Distance: 0.154444 | Requirement Met: ✓
# MLP (Err):   P1 Win: 31.32% | P2 Win: 68.68% | Pred: P2 ✓ | Strat1: 23.0 | Strat2: -15.52 | Strat2 Distance: 0.108891 | Requirement Met: ✓
#
# === Match 53 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.073870 | Winner odds: 3.43 | Loser odds: 1.36 | Margin: 0.026839 | P1 Prob: 0.735294 | P2 Prob: 0.291545
# LogReg:      P1 Win: 61.81% | P2 Win: 38.19% | Pred: P1 ✗ | Strat1: -100 | Strat2: 30.99 | Strat2 Distance: -0.097960 | Requirement Met: ✓
# XGB (LL):    P1 Win: 59.91% | P2 Win: 40.09% | Pred: P1 ✗ | Strat1: -100 | Strat2: 37.5 | Strat2 Distance: -0.116951 | Requirement Met: ✓
# XGB (Err):   P1 Win: 61.10% | P2 Win: 38.90% | Pred: P1 ✗ | Strat1: -100 | Strat2: 33.44 | Strat2 Distance: -0.105105 | Requirement Met: ✓
# MLP (LL):    P1 Win: 60.97% | P2 Win: 39.03% | Pred: P1 ✗ | Strat1: -100 | Strat2: 33.88 | Strat2 Distance: -0.106397 | Requirement Met: ✓
# MLP (Err):   P1 Win: 65.39% | P2 Win: 34.61% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.062160 | Requirement Met: ✗
#
# === Match 54 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.034857 | Winner odds: 1.07 | Loser odds: 12.22 | Margin: 0.016412 | P1 Prob: 0.081833 | P2 Prob: 0.934579
# LogReg:      P1 Win: 6.99% | P2 Win: 93.01% | Pred: P2 ✓ | Strat1: 7.0 | Strat2: 0 | Strat2 Distance: -0.010650 | Requirement Met: ✗
# XGB (LL):    P1 Win: 12.60% | P2 Win: 87.40% | Pred: P2 ✓ | Strat1: 7.0 | Strat2: -6.48 | Strat2 Distance: 0.045512 | Requirement Met: ✓
# XGB (Err):   P1 Win: 20.81% | P2 Win: 79.19% | Pred: P2 ✓ | Strat1: 7.0 | Strat2: -15.27 | Strat2 Distance: 0.127600 | Requirement Met: ✓
# MLP (LL):    P1 Win: 12.93% | P2 Win: 87.07% | Pred: P2 ✓ | Strat1: 7.0 | Strat2: -6.83 | Strat2 Distance: 0.048746 | Requirement Met: ✓
# MLP (Err):   P1 Win: 12.95% | P2 Win: 87.05% | Pred: P2 ✓ | Strat1: 7.0 | Strat2: -6.85 | Strat2 Distance: 0.048964 | Requirement Met: ✓
#
# === Match 55 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.034857 | Winner odds: 1.07 | Loser odds: 12.22 | Margin: 0.016412 | P1 Prob: 0.934579 | P2 Prob: 0.081833
# LogReg:      P1 Win: 73.54% | P2 Win: 26.46% | Pred: P1 ✓ | Strat1: 7.0 | Strat2: -21.32 | Strat2 Distance: -0.184124 | Requirement Met: ✓
# XGB (LL):    P1 Win: 76.81% | P2 Win: 23.19% | Pred: P1 ✓ | Strat1: 7.0 | Strat2: -17.81 | Strat2 Distance: -0.151350 | Requirement Met: ✓
# XGB (Err):   P1 Win: 76.99% | P2 Win: 23.01% | Pred: P1 ✓ | Strat1: 7.0 | Strat2: -17.63 | Strat2 Distance: -0.149634 | Requirement Met: ✓
# MLP (LL):    P1 Win: 83.99% | P2 Win: 16.01% | Pred: P1 ✓ | Strat1: 7.0 | Strat2: -10.13 | Strat2 Distance: -0.079554 | Requirement Met: ✓
# MLP (Err):   P1 Win: 86.09% | P2 Win: 13.91% | Pred: P1 ✓ | Strat1: 7.0 | Strat2: -7.89 | Strat2 Distance: -0.058625 | Requirement Met: ✓
#
# === Match 56 | Actual: P1 Win ===
# ...
# LogReg:      P1 Win: 73.36% | P2 Win: 26.64% | Pred: P1 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: 0.011944 | Requirement Met: ✗
# XGB (LL):    P1 Win: 75.77% | P2 Win: 24.23% | Pred: P1 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: 0.036055 | Requirement Met: ✗
# XGB (Err):   P1 Win: 74.61% | P2 Win: 25.39% | Pred: P1 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: 0.024420 | Requirement Met: ✗
# MLP (LL):    P1 Win: 74.18% | P2 Win: 25.82% | Pred: P1 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: 0.020192 | Requirement Met: ✗
# MLP (Err):   P1 Win: 73.16% | P2 Win: 26.84% | Pred: P1 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: 0.009964 | Requirement Met: ✗
#
# === Match 108 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.061766 | Winner odds: 1.21 | Loser odds: 5.05 | Margin: 0.024466 | P1 Prob: 0.826446 | P2 Prob: 0.198020
# LogReg:      P1 Win: 81.60% | P2 Win: 18.40% | Pred: P1 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: 0.009267 | Requirement Met: ✗
# XGB (LL):    P1 Win: 83.36% | P2 Win: 16.64% | Pred: P1 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: 0.026866 | Requirement Met: ✗
# XGB (Err):   P1 Win: 83.22% | P2 Win: 16.78% | Pred: P1 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: 0.025481 | Requirement Met: ✗
# MLP (LL):    P1 Win: 84.31% | P2 Win: 15.69% | Pred: P1 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: 0.036411 | Requirement Met: ✗
# MLP (Err):   P1 Win: 84.20% | P2 Win: 15.80% | Pred: P1 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: 0.035248 | Requirement Met: ✗
#
# === Match 109 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.078085 | Winner odds: 2.45 | Loser odds: 1.62 | Margin: 0.025447 | P1 Prob: 0.408163 | P2 Prob: 0.617284
# LogReg:      P1 Win: 37.97% | P2 Win: 62.03% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.018361 | Requirement Met: ✗
# XGB (LL):    P1 Win: 33.22% | P2 Win: 66.78% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.065857 | Requirement Met: ✗
# XGB (Err):   P1 Win: 34.96% | P2 Win: 65.04% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.048426 | Requirement Met: ✗
# MLP (LL):    P1 Win: 32.90% | P2 Win: 67.10% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.068999 | Requirement Met: ✗
# MLP (Err):   P1 Win: 29.50% | P2 Win: 70.50% | Pred: P2 ✗ | Strat1: -100 | Strat2: -27.71 | Strat2 Distance: -0.102986 | Requirement Met: ✓
#
# === Match 110 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.053981 | Winner odds: 6.25 | Loser odds: 1.16 | Margin: 0.022069 | P1 Prob: 0.862069 | P2 Prob: 0.160000
# LogReg:      P1 Win: 85.56% | P2 Win: 14.44% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.012101 | Requirement Met: ✗
# XGB (LL):    P1 Win: 87.44% | P2 Win: 12.56% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.030906 | Requirement Met: ✗
# XGB (Err):   P1 Win: 87.91% | P2 Win: 12.09% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.035600 | Requirement Met: ✗
# MLP (LL):    P1 Win: 91.01% | P2 Win: 8.99% | Pred: P1 ✗ | Strat1: -100 | Strat2: -43.8 | Strat2 Distance: 0.066631 | Requirement Met: ✓
# MLP (Err):   P1 Win: 91.21% | P2 Win: 8.79% | Pred: P1 ✗ | Strat1: -100 | Strat2: -45.08 | Strat2 Distance: 0.068669 | Requirement Met: ✓
#
# === Match 111 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.052537 | Winner odds: 1.15 | Loser odds: 6.57 | Margin: 0.021772 | P1 Prob: 0.869565 | P2 Prob: 0.152207
# LogReg:      P1 Win: 87.02% | P2 Win: 12.98% | Pred: P1 ✓ | Strat1: 15.0 | Strat2: 0 | Strat2 Distance: 0.019126 | Requirement Met: ✗
# XGB (LL):    P1 Win: 88.34% | P2 Win: 11.66% | Pred: P1 ✓ | Strat1: 15.0 | Strat2: 0 | Strat2 Distance: 0.032380 | Requirement Met: ✗
# XGB (Err):   P1 Win: 88.14% | P2 Win: 11.86% | Pred: P1 ✓ | Strat1: 15.0 | Strat2: 0 | Strat2 Distance: 0.030410 | Requirement Met: ✗
# MLP (LL):    P1 Win: 91.10% | P2 Win: 8.90% | Pred: P1 ✓ | Strat1: 15.0 | Strat2: 4.77 | Strat2 Distance: 0.060005 | Requirement Met: ✓
# MLP (Err):   P1 Win: 88.99% | P2 Win: 11.01% | Pred: P1 ✓ | Strat1: 15.0 | Strat2: 0 | Strat2 Distance: 0.038906 | Requirement Met: ✗
#
# === Match 112 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.045826 | Winner odds: 1.1 | Loser odds: 8.9 | Margin: 0.021450 | P1 Prob: 0.112360 | P2 Prob: 0.909091
# LogReg:      P1 Win: 13.17% | P2 Win: 86.83% | Pred: P2 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: 0.021678 | Requirement Met: ✗
# XGB (LL):    P1 Win: 13.47% | P2 Win: 86.53% | Pred: P2 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: 0.024669 | Requirement Met: ✗
# XGB (Err):   P1 Win: 15.47% | P2 Win: 84.53% | Pred: P2 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: 0.044733 | Requirement Met: ✗
# MLP (LL):    P1 Win: 15.95% | P2 Win: 84.05% | Pred: P2 ✓ | Strat1: 10.0 | Strat2: -7.54 | Strat2 Distance: 0.049477 | Requirement Met: ✓
# MLP (Err):   P1 Win: 14.60% | P2 Win: 85.40% | Pred: P2 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: 0.036044 | Requirement Met: ✗
#
# === Match 113 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.074526 | Winner odds: 1.45 | Loser odds: 2.98 | Margin: 0.025226 | P1 Prob: 0.689655 | P2 Prob: 0.335570
# LogReg:      P1 Win: 69.87% | P2 Win: 30.13% | Pred: P1 ✓ | Strat1: 45.0 | Strat2: 0 | Strat2 Distance: 0.026060 | Requirement Met: ✗
# XGB (LL):    P1 Win: 70.48% | P2 Win: 29.52% | Pred: P1 ✓ | Strat1: 45.0 | Strat2: 0 | Strat2 Distance: 0.032131 | Requirement Met: ✗
# XGB (Err):   P1 Win: 69.56% | P2 Win: 30.44% | Pred: P1 ✓ | Strat1: 45.0 | Strat2: 0 | Strat2 Distance: 0.022944 | Requirement Met: ✗
# MLP (LL):    P1 Win: 71.36% | P2 Win: 28.64% | Pred: P1 ✓ | Strat1: 45.0 | Strat2: 0 | Strat2 Distance: 0.040962 | Requirement Met: ✗
# MLP (Err):   P1 Win: 73.62% | P2 Win: 26.38% | Pred: P1 ✓ | Strat1: 45.0 | Strat2: 0 | Strat2 Distance: 0.063547 | Requirement Met: ✗
#
# === Match 114 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.065826 | Winner odds: 1.27 | Loser odds: 4.22 | Margin: 0.024368 | P1 Prob: 0.236967 | P2 Prob: 0.787402
# LogReg:      P1 Win: 27.57% | P2 Win: 72.43% | Pred: P2 ✓ | Strat1: 27.0 | Strat2: 0 | Strat2 Distance: 0.044369 | Requirement Met: ✗
# XGB (LL):    P1 Win: 23.90% | P2 Win: 76.10% | Pred: P2 ✓ | Strat1: 27.0 | Strat2: 0 | Strat2 Distance: 0.007673 | Requirement Met: ✗
# XGB (Err):   P1 Win: 24.19% | P2 Win: 75.81% | Pred: P2 ✓ | Strat1: 27.0 | Strat2: 0 | Strat2 Distance: 0.010586 | Requirement Met: ✗
# MLP (LL):    P1 Win: 29.27% | P2 Win: 70.73% | Pred: P2 ✓ | Strat1: 27.0 | Strat2: 0 | Strat2 Distance: 0.061377 | Requirement Met: ✗
# MLP (Err):   P1 Win: 23.95% | P2 Win: 76.05% | Pred: P2 ✓ | Strat1: 27.0 | Strat2: 0 | Strat2 Distance: 0.008146 | Requirement Met: ✗
#
# === Match 115 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.070536 | Winner odds: 1.35 | Loser odds: 3.52 | Margin: 0.024832 | P1 Prob: 0.740741 | P2 Prob: 0.284091
# LogReg:      P1 Win: 66.19% | P2 Win: 33.81% | Pred: P1 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: -0.060918 | Requirement Met: ✗
# XGB (LL):    P1 Win: 58.36% | P2 Win: 41.64% | Pred: P1 ✓ | Strat1: 35.0 | Strat2: -21.21 | Strat2 Distance: -0.139146 | Requirement Met: ✓
# XGB (Err):   P1 Win: 59.89% | P2 Win: 40.11% | Pred: P1 ✓ | Strat1: 35.0 | Strat2: -19.15 | Strat2 Distance: -0.123886 | Requirement Met: ✓
# MLP (LL):    P1 Win: 64.30% | P2 Win: 35.70% | Pred: P1 ✓ | Strat1: 35.0 | Strat2: -13.19 | Strat2 Distance: -0.079767 | Requirement Met: ✓
# MLP (Err):   P1 Win: 65.89% | P2 Win: 34.11% | Pred: P1 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: -0.063875 | Requirement Met: ✗
#
# === Match 116 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.061727 | Winner odds: 1.26 | Loser odds: 4.38 | Margin: 0.021961 | P1 Prob: 0.793651 | P2 Prob: 0.228311
# LogReg:      P1 Win: 85.24% | P2 Win: 14.76% | Pred: P1 ✓ | Strat1: 26.0 | Strat2: 7.41 | Strat2 Distance: 0.075840 | Requirement Met: ✓
# XGB (LL):    P1 Win: 83.41% | P2 Win: 16.59% | Pred: P1 ✓ | Strat1: 26.0 | Strat2: 0 | Strat2 Distance: 0.057509 | Requirement Met: ✗
# XGB (Err):   P1 Win: 79.91% | P2 Win: 20.09% | Pred: P1 ✓ | Strat1: 26.0 | Strat2: 0 | Strat2 Distance: 0.022499 | Requirement Met: ✗
# MLP (LL):    P1 Win: 86.46% | P2 Win: 13.54% | Pred: P1 ✓ | Strat1: 26.0 | Strat2: 8.94 | Strat2 Distance: 0.088021 | Requirement Met: ✓
# MLP (Err):   P1 Win: 88.33% | P2 Win: 11.67% | Pred: P1 ✓ | Strat1: 26.0 | Strat2: 11.3 | Strat2 Distance: 0.106749 | Requirement Met: ✓
#
# === Match 117 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.078246 | Winner odds: 2.03 | Loser odds: 1.88 | Margin: 0.024526 | P1 Prob: 0.531915 | P2 Prob: 0.492611
# LogReg:      P1 Win: 56.23% | P2 Win: 43.77% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.043080 | Requirement Met: ✗
# XGB (LL):    P1 Win: 54.36% | P2 Win: 45.64% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.024433 | Requirement Met: ✗
# XGB (Err):   P1 Win: 53.02% | P2 Win: 46.98% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.010986 | Requirement Met: ✗
# MLP (LL):    P1 Win: 54.43% | P2 Win: 45.57% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.025137 | Requirement Met: ✗
# MLP (Err):   P1 Win: 49.93% | P2 Win: 50.07% | Pred: P2 ✓ | Strat1: 103.0 | Strat2: 0 | Strat2 Distance: -0.019901 | Requirement Met: ✗
#
# === Match 118 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.081529 | Winner odds: 2.01 | Loser odds: 1.89 | Margin: 0.026613 | P1 Prob: 0.529101 | P2 Prob: 0.497512
# LogReg:      P1 Win: 45.31% | P2 Win: 54.69% | Pred: P2 ✓ | Strat1: 101.0 | Strat2: 0 | Strat2 Distance: -0.062279 | Requirement Met: ✗
# XGB (LL):    P1 Win: 48.40% | P2 Win: 51.60% | Pred: P2 ✓ | Strat1: 101.0 | Strat2: 0 | Strat2 Distance: -0.031358 | Requirement Met: ✗
# XGB (Err):   P1 Win: 47.65% | P2 Win: 52.35% | Pred: P2 ✓ | Strat1: 101.0 | Strat2: 0 | Strat2 Distance: -0.038901 | Requirement Met: ✗
# MLP (LL):    P1 Win: 43.03% | P2 Win: 56.97% | Pred: P2 ✓ | Strat1: 101.0 | Strat2: 14.5 | Strat2 Distance: -0.085035 | Requirement Met: ✓
# MLP (Err):   P1 Win: 52.16% | P2 Win: 47.84% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.006234 | Requirement Met: ✗
#
# === Match 119 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.072648 | Winner odds: 1.36 | Loser odds: 3.44 | Margin: 0.025992 | P1 Prob: 0.290698 | P2 Prob: 0.735294
# LogReg:      P1 Win: 28.38% | P2 Win: 71.62% | Pred: P2 ✓ | Strat1: 36.0 | Strat2: 0 | Strat2 Distance: 0.000467 | Requirement Met: ✗
# XGB (LL):    P1 Win: 27.78% | P2 Win: 72.22% | Pred: P2 ✓ | Strat1: 36.0 | Strat2: 0 | Strat2 Distance: -0.005533 | Requirement Met: ✗
# XGB (Err):   P1 Win: 30.59% | P2 Win: 69.41% | Pred: P2 ✓ | Strat1: 36.0 | Strat2: 0 | Strat2 Distance: 0.022526 | Requirement Met: ✗
# MLP (LL):    P1 Win: 24.51% | P2 Win: 75.49% | Pred: P2 ✓ | Strat1: 36.0 | Strat2: 0 | Strat2 Distance: -0.038194 | Requirement Met: ✗
# MLP (Err):   P1 Win: 26.82% | P2 Win: 73.18% | Pred: P2 ✓ | Strat1: 36.0 | Strat2: 0 | Strat2 Distance: -0.015093 | Requirement Met: ✗
#
# === Match 120 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.077105 | Winner odds: 2.33 | Loser odds: 1.68 | Margin: 0.024423 | P1 Prob: 0.429185 | P2 Prob: 0.595238
# LogReg:      P1 Win: 40.25% | P2 Win: 59.75% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.016450 | Requirement Met: ✗
# XGB (LL):    P1 Win: 40.14% | P2 Win: 59.86% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.017601 | Requirement Met: ✗
# XGB (Err):   P1 Win: 41.48% | P2 Win: 58.52% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.004111 | Requirement Met: ✗
# MLP (LL):    P1 Win: 40.25% | P2 Win: 59.75% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.016431 | Requirement Met: ✗
# MLP (Err):   P1 Win: 36.78% | P2 Win: 63.22% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.051190 | Requirement Met: ✗
#
# === Match 121 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.073617 | Winner odds: 2.49 | Loser odds: 1.61 | Margin: 0.022724 | P1 Prob: 0.621118 | P2 Prob: 0.401606
# LogReg:      P1 Win: 67.97% | P2 Win: 32.03% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.072394 | Requirement Met: ✗
# XGB (LL):    P1 Win: 67.49% | P2 Win: 32.51% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.067617 | Requirement Met: ✗
# XGB (Err):   P1 Win: 65.39% | P2 Win: 34.61% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.046610 | Requirement Met: ✗
# MLP (LL):    P1 Win: 64.46% | P2 Win: 35.54% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.037323 | Requirement Met: ✗
# MLP (Err):   P1 Win: 72.67% | P2 Win: 27.33% | Pred: P1 ✗ | Strat1: -100 | Strat2: -31.96 | Strat2 Distance: 0.119422 | Requirement Met: ✓
#
# === Match 122 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.074848 | Winner odds: 2.44 | Loser odds: 1.63 | Margin: 0.023333 | P1 Prob: 0.409836 | P2 Prob: 0.613497
# LogReg:      P1 Win: 34.68% | P2 Win: 65.32% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.053656 | Requirement Met: ✗
# XGB (LL):    P1 Win: 24.99% | P2 Win: 75.01% | Pred: P2 ✗ | Strat1: -100 | Strat2: -39.02 | Strat2 Distance: -0.150589 | Requirement Met: ✓
# XGB (Err):   P1 Win: 25.60% | P2 Win: 74.40% | Pred: P2 ✗ | Strat1: -100 | Strat2: -37.53 | Strat2 Distance: -0.144481 | Requirement Met: ✓
# MLP (LL):    P1 Win: 28.54% | P2 Win: 71.46% | Pred: P2 ✗ | Strat1: -100 | Strat2: -30.37 | Strat2 Distance: -0.115131 | Requirement Met: ✓
# MLP (Err):   P1 Win: 24.84% | P2 Win: 75.16% | Pred: P2 ✗ | Strat1: -100 | Strat2: -39.4 | Strat2 Distance: -0.152140 | Requirement Met: ✓
#
# === Match 123 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.055690 | Winner odds: 1.16 | Loser odds: 6.2 | Margin: 0.023359 | P1 Prob: 0.862069 | P2 Prob: 0.161290
# LogReg:      P1 Win: 84.22% | P2 Win: 15.78% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: -0.000143 | Requirement Met: ✗
# XGB (LL):    P1 Win: 82.93% | P2 Win: 17.07% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: -0.013103 | Requirement Met: ✗
# XGB (Err):   P1 Win: 81.76% | P2 Win: 18.24% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: -0.024752 | Requirement Met: ✗
# MLP (LL):    P1 Win: 89.08% | P2 Win: 10.92% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: 0.048372 | Requirement Met: ✗
# MLP (Err):   P1 Win: 87.64% | P2 Win: 12.36% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: 0.033979 | Requirement Met: ✗
#
# === Match 124 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.068945 | Winner odds: 1.34 | Loser odds: 3.6 | Margin: 0.024046 | P1 Prob: 0.746269 | P2 Prob: 0.277778
# LogReg:      P1 Win: 72.84% | P2 Win: 27.16% | Pred: P1 ✓ | Strat1: 34.0 | Strat2: 0 | Strat2 Distance: -0.000318 | Requirement Met: ✗
# XGB (LL):    P1 Win: 68.60% | P2 Win: 31.40% | Pred: P1 ✓ | Strat1: 34.0 | Strat2: 0 | Strat2 Distance: -0.042728 | Requirement Met: ✗
# XGB (Err):   P1 Win: 68.62% | P2 Win: 31.38% | Pred: P1 ✓ | Strat1: 34.0 | Strat2: 0 | Strat2 Distance: -0.042520 | Requirement Met: ✗
# MLP (LL):    P1 Win: 73.55% | P2 Win: 26.45% | Pred: P1 ✓ | Strat1: 34.0 | Strat2: 0 | Strat2 Distance: 0.006723 | Requirement Met: ✗
# MLP (Err):   P1 Win: 77.85% | P2 Win: 22.15% | Pred: P1 ✓ | Strat1: 34.0 | Strat2: 0 | Strat2 Distance: 0.049752 | Requirement Met: ✗
#
# === Match 125 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.062496 | Winner odds: 1.26 | Loser odds: 4.37 | Margin: 0.022484 | P1 Prob: 0.793651 | P2 Prob: 0.228833
# LogReg:      P1 Win: 79.06% | P2 Win: 20.94% | Pred: P1 ✓ | Strat1: 26.0 | Strat2: 0 | Strat2 Distance: 0.014425 | Requirement Met: ✗
# XGB (LL):    P1 Win: 81.67% | P2 Win: 18.33% | Pred: P1 ✓ | Strat1: 26.0 | Strat2: 0 | Strat2 Distance: 0.040508 | Requirement Met: ✗
# XGB (Err):   P1 Win: 81.57% | P2 Win: 18.43% | Pred: P1 ✓ | Strat1: 26.0 | Strat2: 0 | Strat2 Distance: 0.039547 | Requirement Met: ✗
# MLP (LL):    P1 Win: 85.02% | P2 Win: 14.98% | Pred: P1 ✓ | Strat1: 26.0 | Strat2: 7.13 | Strat2 Distance: 0.074021 | Requirement Met: ✓
# MLP (Err):   P1 Win: 84.44% | P2 Win: 15.56% | Pred: P1 ✓ | Strat1: 26.0 | Strat2: 6.39 | Strat2 Distance: 0.068171 | Requirement Met: ✓

# %% [markdown]
# Evaluation criteria for the models and strategies

# %%
results = [] #empty df to hold results in nice format
cum_profs=[] #cumulative profit lists for each model/strategy

#compute metrics for each model/strategy
for i in [log_reg_cum, xgb_ll_cum, xgb_err_cum, mlp_ll_cum, mlp_err_cum, log_reg_cum2, xgb_ll_cum2, xgb_err_cum2, mlp_ll_cum2, mlp_err_cum2]:
    prof_lst=[i['Winnings'][j]-i['Staked'][j] for j in range(len(i['Winnings'])) if i['Staked'][j]>0] #profit list for each game where we placed a bet
    wins_sum=sum([j for j in prof_lst if j>0])
    lose_sum=sum([j for j in prof_lst if j<=0])*-1 #amount lost in total (positive)
    MACE=(sum([abs(i['Prob'][k]-i['Act'][k]) for k in range(len(i['Prob']))]))/len(i['Prob']) #mean absolute calibration error
    cum_prof_lst=[]
    cum_prof=0
    for p in prof_lst: #compute cumulative profit for each model/strategy
        cum_prof+=p
        cum_prof_lst.append(cum_prof)
    cum_profs.append(cum_prof_lst) #store for later
    #max drawdown
    max_drawdown = 0
    peak = cum_prof_lst[0]
    for x in cum_prof_lst:
        if x > peak:
            peak = x
        drawdown = peak - x
        if drawdown > max_drawdown:
            max_drawdown = drawdown
    prof=sum(prof_lst)
    staked=sum(i['Staked'])
    n_bets=len(prof_lst)
    n_wins=len([j for j in prof_lst if j>0])
    avg_prof=prof/n_bets
    volatility=((1/(n_bets-1))*sum([(prof_lst[j]-avg_prof)**2 for j in range(n_bets)]))**0.5
    results.append({
    'Bets': n_bets,
    'Win Rate': n_wins/n_bets * 100,
    'ROI': prof/staked * 100,
    'Avg Profit': avg_prof,
    'Sharpe': avg_prof/volatility,
    'Max Drawdown': max_drawdown,
    'Profit Factor': wins_sum/lose_sum,
    'MACE': MACE*100,
    'Volatility': volatility
    })

model_names = ['LogReg_S1', 'XGB_LL_S1', 'XGB_Err_S1', 'MLP_LL_S1', 'MLP_Err_S1',
               'LogReg_S2', 'XGB_LL_S2', 'XGB_Err_S2', 'MLP_LL_S2', 'MLP_Err_S2']
df_results = pd.DataFrame(results, index=model_names).T
df_results = df_results.round(2) #print results nicely
df_results
# Out:
#                LogReg_S1  XGB_LL_S1  XGB_Err_S1  MLP_LL_S1  MLP_Err_S1  \
# Bets              126.00     126.00      126.00     126.00      126.00
# Win Rate           70.63      72.22       74.60      72.22       70.63
# ROI                -5.57      -2.59        1.97      -2.12       -5.08
# Avg Profit         -5.57      -2.59        1.97      -2.12       -5.08
# Sharpe             -0.08      -0.04        0.03      -0.03       -0.08
# Max Drawdown      821.00     714.00      574.00     647.00      742.00
# Profit Factor       0.81       0.91        1.08       0.92        0.83
# MACE               37.03      36.48       37.10      36.58       36.47
# Volatility         66.88      66.86       66.76      67.63       67.69
#
#                LogReg_S2  XGB_LL_S2  XGB_Err_S2  MLP_LL_S2  MLP_Err_S2
# Bets               47.00      53.00       55.00      59.00       52.00
# Win Rate           31.91      30.19       27.27      32.20       36.54
# ROI                -2.05      -3.86       -3.42      -3.88       -3.54
# Avg Profit         -2.05      -3.86       -3.42      -3.88       -3.54
# Sharpe             -0.07      -0.18       -0.14      -0.15       -0.12
# Max Drawdown      174.32     254.20      275.96     354.55      318.70
# Profit Factor       0.84       0.66        0.71       0.70        0.75
# MACE               41.63      35.69       35.18      38.43       42.39
# Volatility         29.09      22.03       23.61      25.89       29.11

# %% [markdown]
# While our models mainly did not achieve profitability against Pinnacle's efficient market, a profit factor of over 1.0 for the strongest strategy 1 model (XGB with error based calibration achieving 1.08) demonstrates meaningful predictive power. The models successfully learned patterns that closely approximate professional bookmaker odds using only publicly available data. Closing the remaining gap to sustained profitability would likely require proprietary data sources or real-time market information.

# %% [markdown]
# # PLOTS

# %% [markdown]
# Equity curve

# %%
#Strategy 1 equity curves
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

strat1_data = [log_reg_cum, xgb_ll_cum, xgb_err_cum, mlp_ll_cum, mlp_err_cum]
strat1_models = ['LogReg_S1', 'XGB_LL_S1', 'XGB_Err_S1', 'MLP_LL_S1', 'MLP_Err_S1']

for i, name in enumerate(strat1_models):
    axes[0].plot(cum_profs[i], label=name, linewidth=1.5)

axes[0].axhline(y=0, color='black', linewidth=0.8)
axes[0].set_xlabel('Match Number')
axes[0].set_ylabel('Cumulative Profit (£)')
axes[0].set_title('Strategy 1: Equity Curves')
axes[0].legend(loc='lower left')
axes[0].grid(True, alpha=0.3)

# Strategy 2 equity curves
strat2_data = [log_reg_cum2, xgb_ll_cum2, xgb_err_cum2, mlp_ll_cum2, mlp_err_cum2]
strat2_models = ['LogReg_S2', 'XGB_LL_S2', 'XGB_Err_S2', 'MLP_LL_S2', 'MLP_Err_S2']

for i, name in enumerate(strat2_models):
    axes[1].plot(cum_profs[i+5], label=name, linewidth=1.5)

axes[1].axhline(y=0, color='black', linewidth=0.8)
axes[1].set_xlabel('Bet Number')
axes[1].set_ylabel('Cumulative Profit (£)')
axes[1].set_title('Strategy 2: Equity Curves')
axes[1].legend(loc='lower left')
axes[1].grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# Key metrics

# %%
# Metrics to include, we invert MACE since lower is better
metrics = ['ROI', 'Sharpe', 'Win Rate', 'Profit Factor', 'MACE']

fig, axes = plt.subplots(1, 2, figsize=(14, 6), subplot_kw=dict(polar=True))

# Number of metrics
num_metrics = len(metrics)
angles = np.linspace(0, 2 * np.pi, num_metrics, endpoint=False).tolist()
angles += angles[:1]  # Close the loop

# Normalise function (min-max scaling)
def normalise(values, invert=False):
    min_v, max_v = min(values), max(values)
    if max_v == min_v:
        return [0.5] * len(values)
    norm = [(v - min_v) / (max_v - min_v) for v in values]
    if invert:
        norm = [1 - n for n in norm]
    return norm

# Normalise within Strategy 1 only
roi_norm_s1 = normalise(df_results.loc['ROI', strat1_models].values)
sharpe_norm_s1 = normalise(df_results.loc['Sharpe', strat1_models].values)
wr_norm_s1 = normalise(df_results.loc['Win Rate', strat1_models].values)
pf_norm_s1 = normalise(df_results.loc['Profit Factor', strat1_models].values)
mace_norm_s1 = normalise(df_results.loc['MACE', strat1_models].values, invert=True)

# Normalise within Strategy 2 only
roi_norm_s2 = normalise(df_results.loc['ROI', strat2_models].values)
sharpe_norm_s2 = normalise(df_results.loc['Sharpe', strat2_models].values)
wr_norm_s2 = normalise(df_results.loc['Win Rate', strat2_models].values)
pf_norm_s2 = normalise(df_results.loc['Profit Factor', strat2_models].values)
mace_norm_s2 = normalise(df_results.loc['MACE', strat2_models].values, invert=True)

# Strategy 1
for i, model in enumerate(strat1_models):
    values = [roi_norm_s1[i], sharpe_norm_s1[i], wr_norm_s1[i], pf_norm_s1[i], mace_norm_s1[i]]
    values += values[:1]
    axes[0].plot(angles, values, 'o-', label=model)
    axes[0].fill(angles, values, alpha=0.1)

axes[0].set_xticks(angles[:-1])
axes[0].set_xticklabels(metrics)
axes[0].set_title('Strategy 1: Model Comparison')
axes[0].legend(loc='lower right', bbox_to_anchor=(1.25, 0))

# Strategy 2
for i, model in enumerate(strat2_models):
    values = [roi_norm_s2[i], sharpe_norm_s2[i], wr_norm_s2[i], pf_norm_s2[i], mace_norm_s2[i]]
    values += values[:1]
    axes[1].plot(angles, values, 'o-', label=model)
    axes[1].fill(angles, values, alpha=0.1)

axes[1].set_xticks(angles[:-1])
axes[1].set_xticklabels(metrics)
axes[1].set_title('Strategy 2: Model Comparison')
axes[1].legend(loc='upper right', bbox_to_anchor=(1.3, 1))

plt.tight_layout()
plt.show()

# %% [markdown]
# Calib curve

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Strategy 1
for data, name in zip(strat1_data, strat1_models):
    prob_true, prob_pred = calibration_curve(data['Act'], data['Prob'], n_bins=10)
    axes[0].plot(prob_pred, prob_true, label=name, linewidth=1.5, marker='o')

axes[0].plot([0,1], [0,1], 'k--')
axes[0].set_xlabel('Predicted Probability')
axes[0].set_ylabel('Actual Win Rate')
axes[0].set_title('Strategy 1: Calibration Plot')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Strategy 2
for data, name in zip(strat2_data, strat2_models):
    prob_true, prob_pred = calibration_curve(data['Act'], data['Prob'], n_bins=10)
    axes[1].plot(prob_pred, prob_true, label=name, linewidth=1.5, marker='o')

axes[1].plot([0,1], [0,1], 'k--')
axes[1].set_xlabel('Predicted Probability')
axes[1].set_ylabel('Actual Win Rate')
axes[1].set_title('Strategy 2: Calibration Plot')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# Threshold Distances for strategy 2
# Model mostly agrees with Pinnacle, lack of edge due to small differences and it being wrong more than right on these ones. Few high conviction bets.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Threshold vs Distance scatter
for data, name in zip(strat2_data, strat2_models):
    axes[0].scatter(data['Thresh'], data['Dist'], label=name)
    max_thresh = max(data['Thresh'])

axes[0].plot([0, max_thresh], [0, max_thresh], 'k--', label='Threshold line')
axes[0].set_xlabel('Required Threshold')
axes[0].set_ylabel('Actual Distance |p - q̂|')
axes[0].set_title('Strategy 2: Threshold vs Distance')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Plot 2: Histogram of distances with threshold overlay
for data, name in zip(strat2_data, strat2_models):
    axes[1].hist(data['Dist'], bins=15, alpha=0.4, label=name)

avg_thresh = sum(strat2_data[0]['Thresh']) / len(strat2_data[0]['Thresh'])
axes[1].axvline(x=avg_thresh, color='black', label=f'Avg Threshold ({avg_thresh:.3f})')
axes[1].set_xlabel('Distance |p - q̂|')
axes[1].set_ylabel('Frequency')
axes[1].set_title('Strategy 2: Distribution of Model Distances')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# Confusion matrices

# %%
fig, axes = plt.subplots(2, 5, figsize=(20, 8))

# Strategy 1
for i, (data, name) in enumerate(zip(strat1_data, strat1_models)):
    preds = [1 if p >= 0.5 else 0 for p in data['Prob']]
    cm = confusion_matrix(data['Act'], preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[0, i], cbar=False)
    axes[0, i].set_ylabel('Actual')
    axes[0, i].set_title(f'S1: {name}')

# Strategy 2
for i, (data, name) in enumerate(zip(strat2_data, strat2_models)):
    preds = [1 if p >= 0.5 else 0 for p in data['Prob']]
    cm = confusion_matrix(data['Act'], preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges', ax=axes[1, i], cbar=False)
    axes[1, i].set_xlabel('Predicted')
    axes[1, i].set_ylabel('Actual')
    axes[1, i].set_title(f'S2: {name}')


plt.show()

# %% [markdown]
# Profit distribution

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Strategy 1
for data, name in zip(strat1_data, strat1_models):
    profits = [data['Winnings'][i] - data['Staked'][i] for i in range(len(data['Winnings']))]
    axes[0].hist(profits, bins=20, alpha=0.4, label=name)

axes[0].axvline(x=0, color='black')
axes[0].set_xlabel('Profit (£)')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Strategy 1: Profit Distribution')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Strategy 2
for data, name in zip(strat2_data, strat2_models):
    profits = [data['Winnings'][i] - data['Staked'][i] for i in range(len(data['Winnings'])) if data['Staked'][i] > 0] #only look at when we placed a bet
    axes[1].hist(profits, bins=20, alpha=0.4, label=name)

axes[1].axvline(x=0, color='black')
axes[1].set_xlabel('Profit (£)')
axes[1].set_ylabel('Frequency')
axes[1].set_title('Strategy 2: Profit Distribution')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.show()
