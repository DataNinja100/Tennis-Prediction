# %% [markdown]
# # IMPORTING AND CLEANING BETTING DATASET (PINNACLE SPORTS)

# %% [markdown]
# imports and setup

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, brier_score_loss, accuracy_score, roc_auc_score
import torch
import torch.nn as nn
import torch.optim as optim
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
from sklearn.calibration import calibration_curve
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np

# %%
betting_df=pd.read_csv("Final/usopen.csv")
betting_df=betting_df[['Date', 'Winner', 'Loser', 'WRank', 'LRank', 'Wsets', 'Lsets', 'Comment', 'PSW', 'PSL']]
betting_df = betting_df[betting_df['Loser'] != "Forbes M."] #we have to drop this row as there was missing data for this game in the original dataset so it's not present in the testset
betting_df
# Out:
#            Date            Winner         Loser  WRank  LRank  Wsets  Lsets  \
# 0    26/08/2024         Zverev A.   Marterer M.      4    100      3      1
# 1    26/08/2024  Bautista Agut R.      Nardi L.     67     90      3      0
# 2    26/08/2024       Comesana F.   Stricker D.    108    169      3      1
# 3    26/08/2024        Humbert U.   Monteiro T.     17     75      3      0
# 4    26/08/2024        Krueger M.    Grenier H.    179    173      3      1
# ..          ...               ...           ...    ...    ...    ...    ...
# 122  04/09/2024         Draper J.  De Minaur A.     25     10      3      0
# 123  05/09/2024         Sinner J.   Medvedev D.      1      5      3      1
# 124  06/09/2024         Sinner J.     Draper J.      1     25      3      0
# 125  07/09/2024          Fritz T.     Tiafoe F.     12     20      3      2
# 126  08/09/2024         Sinner J.      Fritz T.      1     12      3      0
#
#        Comment   PSW    PSL
# 0    Completed  1.02  27.72
# 1    Completed  1.28   4.10
# 2    Completed  3.45   1.36
# 3    Completed  1.13   7.11
# 4    Completed  1.73   2.25
# ..         ...   ...    ...
# 122  Completed  2.33   1.68
# 123  Completed  1.36   3.44
# 124  Completed  1.16   6.20
# 125  Completed  1.34   3.60
# 126  Completed  1.26   4.37
#
# [126 rows x 10 columns]

# %% [markdown]
# computing Pinnacle implied probabilities, and margin

# %%
betting_df['winner_prob'], betting_df['loser_prob'] = 1/betting_df['PSW'], 1/betting_df['PSL']
betting_df['margin'] = betting_df['winner_prob'] + betting_df['loser_prob'] - 1
betting_df
# Out:
#            Date            Winner         Loser  WRank  LRank  Wsets  Lsets  \
# 0    26/08/2024         Zverev A.   Marterer M.      4    100      3      1
# 1    26/08/2024  Bautista Agut R.      Nardi L.     67     90      3      0
# 2    26/08/2024       Comesana F.   Stricker D.    108    169      3      1
# 3    26/08/2024        Humbert U.   Monteiro T.     17     75      3      0
# 4    26/08/2024        Krueger M.    Grenier H.    179    173      3      1
# ..          ...               ...           ...    ...    ...    ...    ...
# 122  04/09/2024         Draper J.  De Minaur A.     25     10      3      0
# 123  05/09/2024         Sinner J.   Medvedev D.      1      5      3      1
# 124  06/09/2024         Sinner J.     Draper J.      1     25      3      0
# 125  07/09/2024          Fritz T.     Tiafoe F.     12     20      3      2
# 126  08/09/2024         Sinner J.      Fritz T.      1     12      3      0
#
#        Comment   PSW    PSL  winner_prob  loser_prob    margin
# 0    Completed  1.02  27.72     0.980392    0.036075  0.016467
# 1    Completed  1.28   4.10     0.781250    0.243902  0.025152
# 2    Completed  3.45   1.36     0.289855    0.735294  0.025149
# 3    Completed  1.13   7.11     0.884956    0.140647  0.025603
# 4    Completed  1.73   2.25     0.578035    0.444444  0.022479
# ..         ...   ...    ...          ...         ...       ...
# 122  Completed  2.33   1.68     0.429185    0.595238  0.024423
# 123  Completed  1.36   3.44     0.735294    0.290698  0.025992
# 124  Completed  1.16   6.20     0.862069    0.161290  0.023359
# 125  Completed  1.34   3.60     0.746269    0.277778  0.024046
# 126  Completed  1.26   4.37     0.793651    0.228833  0.022484
#
# [126 rows x 13 columns]

# %% [markdown]
# # TRAINING 5 MODELS FROM PREVIOUS PART WITH OPTIMAL HYPERPARAMS FROM TEST DATA ONLY

# %% [markdown]
# Load train and test - valid not needed as validation & hyperparam tuning already done

# %%
# Load train and test data
train_data = pd.read_csv("Final/train.csv")
test_data = pd.read_csv("Final/test.csv")  

X_train = train_data.drop(columns=["result"])
y_train = train_data["result"]

X_test = test_data.drop(columns=["result"])
y_test = test_data["result"]

print(f"Training samples: {len(X_train)}")
print(f"Test samples: {len(X_test)}") #test on grand slam+rest of 2024 after it
# Out:
# Training samples: 58128
# Test samples: 705

# %% [markdown]
# Log model

# %%
# Pipeline from log model
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("logit", LogisticRegression(
        penalty="l2",
        C=1.0,
        solver="lbfgs",
        max_iter=2000,
        random_state=42
    ))
])

# Train on ALL training data
pipe.fit(X_train, y_train)

# Predict on test set
y_prob = pipe.predict_proba(X_test)[:, 1]
y_pred = (y_prob >= 0.5).astype(int)

# Evaluate
print("\n=== Logistic Regression Test Results ===")
print(f"Log Loss:  {log_loss(y_test, y_prob):.6f}")
print(f"Brier:     {brier_score_loss(y_test, y_prob):.6f}")
print(f"AUC:       {roc_auc_score(y_test, y_prob):.6f}")
print(f"Accuracy:  {accuracy_score(y_test, y_pred):.6f}")
# Out:
# === Logistic Regression Test Results ===
# Log Loss:  0.612055
# Brier:     0.212644
# AUC:       0.722440
# Accuracy:  0.653901

# %% [markdown]
# XGB

# %%
# Best hyperparameters from tuning
best_params_ll = {
    'max_depth': 5,
    'learning_rate': 0.010944546677551579,
    'subsample': 0.9076971864318132,
    'colsample_bytree': 0.847899424542148,
    'min_child_weight': 4.697047917427967,
    'n_estimators': 642
}

best_params_err = {
    'max_depth': 4,
    'learning_rate': 0.0041203103322660735,
    'subsample': 0.6888651281360453,
    'colsample_bytree': 0.8960845657731566,
    'min_child_weight': 7.161503421193317,
    'n_estimators': 1017
}

# XGBoost Log Loss Optimized
model_ll = XGBClassifier(
    **best_params_ll,
    objective="binary:logistic",
    eval_metric="logloss",
    tree_method="hist",
    random_state=42,
    n_jobs=-1
)

model_ll.fit(X_train, y_train)
y_prob_ll = model_ll.predict_proba(X_test)[:, 1]
y_pred_ll = (y_prob_ll >= 0.5)

print("=== XGBoost (Log Loss Tuned) ===")
print(f"Log Loss:  {log_loss(y_test, y_prob_ll):.6f}")
print(f"Brier:     {brier_score_loss(y_test, y_prob_ll):.6f}")
print(f"AUC:       {roc_auc_score(y_test, y_prob_ll):.6f}")
print(f"Accuracy:  {accuracy_score(y_test, y_pred_ll):.6f}")

# XGBoost Error Rate Optimized
model_err = XGBClassifier(
    **best_params_err,
    objective="binary:logistic",
    eval_metric="logloss",
    tree_method="hist",
    random_state=42,
    n_jobs=-1
)

model_err.fit(X_train, y_train)
y_prob_err = model_err.predict_proba(X_test)[:, 1]
y_pred_err = (y_prob_err >= 0.5)

print("\n=== XGBoost (Error Tuned) ===")
print(f"Log Loss:  {log_loss(y_test, y_prob_err):.6f}")
print(f"Brier:     {brier_score_loss(y_test, y_prob_err):.6f}")
print(f"AUC:       {roc_auc_score(y_test, y_prob_err):.6f}")
print(f"Accuracy:  {accuracy_score(y_test, y_pred_err):.6f}")
# Out:
# === XGBoost (Log Loss Tuned) ===
# Log Loss:  0.607812
# Brier:     0.210400
# AUC:       0.728653
# Accuracy:  0.669504
#
# === XGBoost (Error Tuned) ===
# Log Loss:  0.606809
# Brier:     0.210177
# AUC:       0.728113
# Accuracy:  0.663830

# %% [markdown]
# MLP

# %%
def test_mlp(X_train, y_train, X_test, y_test, params, name):
    torch.manual_seed(42)
    
    # Scale
    scaler = StandardScaler()
    X_tr = torch.tensor(scaler.fit_transform(X_train), dtype=torch.float32)
    X_te = torch.tensor(scaler.transform(X_test), dtype=torch.float32)
    y_tr = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)
    
    # Model
    d = params['dropout']
    model = nn.Sequential(
        nn.Linear(X_tr.shape[1], 256), nn.ReLU(), nn.Dropout(d),
        nn.Linear(256, 256), nn.ReLU(), nn.Dropout(d),
        nn.Linear(256, 256), nn.ReLU(), nn.Dropout(d),
        nn.Linear(256, 256), nn.ReLU(), nn.Dropout(d),
        nn.Linear(256, 1)
    )
    
    # Train
    optimizer = optim.Adam(model.parameters(), lr=params['lr'], weight_decay=params['weight_decay'])
    loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(X_tr, y_tr), 
        batch_size=params['batch_size'], shuffle=True
    )
    
    model.train()
    for _ in range(params['n_epochs']):
        for xb, yb in loader:
            optimizer.zero_grad()
            loss = nn.BCEWithLogitsLoss()(model(xb), yb)
            loss.backward()
            optimizer.step()
    
    # Predict
    model.eval()
    with torch.no_grad():
        y_prob = torch.sigmoid(model(X_te)).squeeze().numpy()
    y_pred = (y_prob >= 0.5).astype(int)
    
    # Results
    print(f"\n=== {name} ===")
    print(f"Log Loss:  {log_loss(y_test, y_prob):.6f}")
    print(f"Brier:     {brier_score_loss(y_test, y_prob):.6f}")
    print(f"AUC:       {roc_auc_score(y_test, y_prob):.6f}")
    print(f"Accuracy:  {accuracy_score(y_test, y_pred):.6f}")

    return model, scaler

# Run both with best hyperparams found previously
best_ll = {'lr': 0.000533853641534584, 'weight_decay': 4.398017180584654e-06, 'dropout': 0.42515080111029613, 'batch_size': 256, 'n_epochs': 8}
best_err = {'lr': 0.00018232149103426372, 'weight_decay': 2.5161801333744398e-06, 'dropout': 0.45477228794276553, 'batch_size': 256, 'n_epochs': 13}

mlp_ll_model, mlp_ll_scaler = test_mlp(X_train, y_train, X_test, y_test, best_ll, "MLP (Log Loss Tuned)")
mlp_err_model, mlp_err_scaler = test_mlp(X_train, y_train, X_test, y_test, best_err, "MLP (Error Tuned)")
# Out:
# === MLP (Log Loss Tuned) ===
# Log Loss:  0.610961
# Brier:     0.212011
# AUC:       0.723228
# Accuracy:  0.660993
#
# === MLP (Error Tuned) ===
# Log Loss:  0.609444
# Brier:     0.211326
# AUC:       0.725594
# Accuracy:  0.658156

# %% [markdown]
# # STRATEGY

# %% [markdown]
# align both datasets

# %%
order=pd.read_csv("Final/order.csv") #we need to align games of betting df to our test set
order_l=list(zip(order['winner_rank'], order['loser_rank']))
s=0
rows = []
for i in order_l:
    row = betting_df[(betting_df['WRank'] == i[0]) & (betting_df['LRank'] == i[1])] #unique
    rows.append(row.iloc[0])
    s+=len(row)
print(s) #126 as needed (remember 1 missing row, so no other missing or duplicate matches!)
betting_df_ordered = pd.DataFrame(rows).reset_index(drop=True)
# Out:
# 126

# %%
betting_df_ordered
# Out:
#            Date        Winner         Loser  WRank  LRank  Wsets  Lsets  \
# 0    27/08/2024     Sinner J.   Mcdonald M.      1    140      3      1
# 1    27/08/2024  Michelsen A.  Spizzirri E.     49    341      3      0
# 2    28/08/2024   Bellucci M.   Wawrinka S.    101    176      3      0
# 3    27/08/2024  O Connell C.      Jarry N.     87     26      3      1
# 4    27/08/2024       Fils A.       Tien L.     24    191      3      1
# ..          ...           ...           ...    ...    ...    ...    ...
# 121  03/09/2024      Fritz T.     Zverev A.     12      4      3      1
# 122  04/09/2024     Tiafoe F.   Dimitrov G.     20      9      2      1
# 123  06/09/2024     Sinner J.     Draper J.      1     25      3      0
# 124  07/09/2024      Fritz T.     Tiafoe F.     12     20      3      2
# 125  08/09/2024     Sinner J.      Fritz T.      1     12      3      0
#
#        Comment   PSW    PSL  winner_prob  loser_prob    margin
# 0    Completed  1.02  28.96     0.980392    0.034530  0.014923
# 1    Completed  1.24   4.63     0.806452    0.215983  0.022434
# 2    Completed  1.40   3.20     0.714286    0.312500  0.026786
# 3    Completed  2.84   1.49     0.352113    0.671141  0.023254
# 4    Completed  1.35   3.50     0.740741    0.285714  0.026455
# ..         ...   ...    ...          ...         ...       ...
# 121  Completed  2.49   1.61     0.401606    0.621118  0.022724
# 122    Retired  2.44   1.63     0.409836    0.613497  0.023333
# 123  Completed  1.16   6.20     0.862069    0.161290  0.023359
# 124  Completed  1.34   3.60     0.746269    0.277778  0.024046
# 125  Completed  1.26   4.37     0.793651    0.228833  0.022484
#
# [126 rows x 13 columns]

# %%
test_slam=test_data.iloc[0:126] #testing strategy only on last grand slam
test_slam
# Out:
#      draw_size  best_of  ATP_Point_Diff  Rank_Diff  Height_Diff  Age_Diff  \
# 0          128        5         -8938.0      139.0        -13.0       6.3
# 1          128        5          -970.0      292.0        -10.0       2.6
# 2          128        5          -222.0       75.0          8.0      16.2
# 3          128        5         -1004.0       61.0        -18.0       1.4
# 4          128        5          1461.0     -167.0          5.0       1.5
# ..         ...      ...             ...        ...          ...       ...
# 121        128        5          3915.0       -8.0          2.0       0.5
# 122        128        5          1535.0      -11.0          3.0       6.7
# 123        128        5          7665.0      -24.0         -2.0       0.4
# 124        128        5         -1000.0        8.0         -8.0      -0.3
# 125        128        5         -6240.0       11.0          5.0       3.8
#
#      H2H_Diff  H2H_Surface_Diff  N_Games_Diff  Win_Rate_3_Diff  ...  \
# 0        -2.0              -1.0         -90.0        -1.000000  ...
# 1        -0.0              -0.0         -59.0        -0.166667  ...
# 2        -0.0              -0.0         882.0        -0.000000  ...
# 3         0.0               0.0        -104.0         0.333333  ...
# 4         0.0               0.0          80.0        -0.333333  ...
# ..        ...               ...           ...              ...  ...
# 121       1.0              -1.0         181.0        -0.000000  ...
# 122       1.0              -0.0         343.0        -0.000000  ...
# 123      -1.0               0.0         203.0         0.000000  ...
# 124      -5.0              -5.0         -65.0        -0.000000  ...
# 125      -0.0              -0.0         128.0        -0.000000  ...
#
#      p_1stIn_diff_last_2000  p_1stWon_diff_last_2000  p_2ndWon_diff_last_2000  \
# 0                  0.040335                -0.060441                -0.039738
# 1                 -0.053786                 0.050586                 0.006958
# 2                 -0.052375                -0.007273                 0.034970
# 3                 -0.016709                -0.015879                -0.002571
# 4                 -0.073136                 0.124586                 0.033377
# ..                      ...                      ...                      ...
# 121                0.067369                -0.019160                -0.041751
# 122                0.011319                 0.025198                -0.007661
# 123                0.001621                -0.027807                 0.012493
# 124                0.010726                -0.038313                -0.007366
# 125               -0.001945                 0.015381                -0.009432
#
#      p_bpSaved_diff_last_2000  p_bpConv_diff_last_2000  p_rpw_diff_last_2000  \
# 0                   -0.059859                -0.037054             -0.032386
# 1                    0.043966                 0.032540             -0.018582
# 2                    0.002619                 0.134458              0.037642
# 3                   -0.010613                -0.073161             -0.002004
# 4                   -0.019507                 0.043978             -0.019707
# ..                        ...                      ...                   ...
# 121                 -0.005328                 0.038992              0.023424
# 122                  0.001766                 0.021651              0.020461
# 123                  0.010717                 0.015970              0.023377
# 124                 -0.002622                -0.008596             -0.009168
# 125                 -0.038950                -0.065060             -0.041738
#
#      p_acedAgainst_diff_last_2000  p_totalPtsWon_diff_last_2000  \
# 0                        0.009722                     -0.037964
# 1                       -0.044996                     -0.006011
# 2                       -0.068101                      0.020022
# 3                        0.031055                     -0.011350
# 4                       -0.008924                      0.023871
# ..                            ...                           ...
# 121                     -0.022903                      0.007721
# 122                     -0.042903                      0.016559
# 123                     -0.011594                      0.009174
# 124                      0.032897                     -0.015363
# 125                      0.012143                     -0.018756
#
#      p_dominanceRatio_diff_last_2000  result
# 0                          -0.280750     0.0
# 1                          -0.029277     0.0
# 2                           0.153696     0.0
# 3                          -0.103109     1.0
# 4                           0.157248     1.0
# ..                               ...     ...
# 121                         0.083079     0.0
# 122                         0.158489     0.0
# 123                         0.016856     1.0
# 124                        -0.141133     0.0
# 125                        -0.143180     0.0
#
# [126 rows x 124 columns]

# %% [markdown]
# Strategy 1 (all in on predicted winner) & strategy 2 (hedge bets if higher than a certain threshold)

# %%
#tracking strat 1
log_reg_cum, xgb_ll_cum, xgb_err_cum, mlp_ll_cum, mlp_err_cum={'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[]}, {'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[]}, {'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[]}, {'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[]}, {'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[]}
#tracking strat 2
log_reg_cum2, xgb_ll_cum2, xgb_err_cum2, mlp_ll_cum2, mlp_err_cum2={'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[], 'Thresh':[], 'Dist':[]},{'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[], 'Thresh':[], 'Dist':[]},{'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[], 'Thresh':[], 'Dist':[]},{'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[], 'Thresh':[], 'Dist':[]},{'Staked':[], 'Winnings':[], 'Prob':[], 'Act':[], 'Thresh':[], 'Dist':[]}
bet_size=100 #100 per bet

# function to update betting stats
def update_betting_stats(dic, winnings, staked, prob, outcome, thresh=None, dist=None):
    dic['Winnings'].append(winnings)
    dic['Staked'].append(staked)
    if staked>0: #only add probabilities when we placed a bet
        dic['Prob'].append(prob)
        dic['Act'].append(outcome)
    if thresh is not None: #for strat 2
        dic['Thresh'].append(thresh)
        dic['Dist'].append(dist)
    return dic

# %% [markdown]
# Run betting simulation

# %%
for idx, match in test_slam.iterrows(): #run through all games in grand slam
    w_odds = betting_df_ordered.iloc[idx]['PSW']
    win_ret = w_odds*bet_size
    row = match.drop('result').to_frame().T  # Keeps column names
    actual = match['result']
    p1_prob=betting_df_ordered.iloc[idx]['winner_prob'] if actual==1 else betting_df_ordered.iloc[idx]['loser_prob']
    p2_prob=betting_df_ordered.iloc[idx]['winner_prob'] if actual==0 else betting_df_ordered.iloc[idx]['loser_prob']
    margin=betting_df_ordered.iloc[idx]['margin']
    required_dist=((margin*p1_prob*p2_prob)**0.5)/(1+margin) #for strategy 2, our model's predicted probability-implied probability needs to exceed this margin
    
    # Logistic Regression
    prob_lr = pipe.predict_proba(row)[:, 1][0]
    
    # XGBoost
    prob_xgb_ll = model_ll.predict_proba(row)[:, 1][0]
    prob_xgb_err = model_err.predict_proba(row)[:, 1][0]
    
    # MLP Log Loss
    row_scaled_ll = torch.tensor(mlp_ll_scaler.transform(row), dtype=torch.float32)
    mlp_ll_model.eval()
    with torch.no_grad():
        prob_mlp_ll = torch.sigmoid(mlp_ll_model(row_scaled_ll)).item()
    
    # MLP Error
    row_scaled_err = torch.tensor(mlp_err_scaler.transform(row), dtype=torch.float32)
    mlp_err_model.eval()
    with torch.no_grad():
        prob_mlp_err = torch.sigmoid(mlp_err_model(row_scaled_err)).item()

    # Compute if distance is far enough for strategy 2
    log_dist, xgb_ll_dist, xgb_err_dist, mlp_ll_dist, mlp_err_dist = prob_lr-(p1_prob/(1+margin)), prob_xgb_ll-(p1_prob/(1+margin)), prob_xgb_err-(p1_prob/(1+margin)), prob_mlp_ll-(p1_prob/(1+margin)), prob_mlp_err-(p1_prob/(1+margin))
    ev_log, ev_xgb_ll, ev_xgb_err, ev_mlp_ll, ev_mlp_err=abs(log_dist)>required_dist, abs(xgb_ll_dist)>required_dist, abs(xgb_err_dist)>required_dist, abs(mlp_ll_dist)>required_dist, abs(mlp_err_dist)>required_dist
    
    strat1=[win_ret if (prob_lr >= 0.5) == actual else 0,
            win_ret if (prob_xgb_ll >= 0.5) == actual else 0,
            win_ret if (prob_xgb_err >= 0.5) == actual else 0,
            win_ret if (prob_mlp_ll >= 0.5) == actual else 0,
            win_ret if (prob_mlp_err >= 0.5) == actual else 0] #winning return if we predicted on the right player to win (act=1 means p1 win, act=0 means p2 win)
    
    strat2=[0 if not ev_log else (win_ret * (1-prob_lr) if actual==0 else win_ret*prob_lr),
            0 if not ev_xgb_ll else (win_ret * (1-prob_xgb_ll) if actual==0 else win_ret*prob_xgb_ll),
            0 if not ev_xgb_err else (win_ret * (1-prob_xgb_err) if actual==0 else win_ret*prob_xgb_err),
            0 if not ev_mlp_ll else (win_ret * (1-prob_mlp_ll) if actual==0 else win_ret*prob_mlp_ll),
            0 if not ev_mlp_err else (win_ret * (1-prob_mlp_err) if actual==0 else win_ret*prob_mlp_err)] #winning return * predicted win probability (hedged) if we met strat 2 requirement else 0 (we don't bet otherwise)
    
    print(f"\n=== Match {idx} | Actual: {'P1 Win' if actual == 1 else 'P2 Win'} ===") #match by match breakdown per model per strategy
    print(f"Strat 2 requirement threshold: {required_dist:.6f} | Winner odds: {w_odds} | Loser odds: {betting_df_ordered.iloc[idx]['PSL']} | Margin: {margin:.6f} | P1 Prob: {p1_prob:.6f} | P2 Prob: {p2_prob:.6f}")
    print(f"LogReg:      P1 Win: {prob_lr:.2%} | P2 Win: {1-prob_lr:.2%} | Pred: {'P1' if prob_lr >= 0.5 else 'P2'} {'✓' if (prob_lr >= 0.5) == actual else '✗'} | Strat1: {round(strat1[0]-bet_size,2)} | Strat2: {round(strat2[0]-(bet_size if ev_log else 0),2)} | Strat2 Distance: {log_dist:.6f} | Requirement Met: {'✓' if ev_log else '✗'}")
    print(f"XGB (LL):    P1 Win: {prob_xgb_ll:.2%} | P2 Win: {1-prob_xgb_ll:.2%} | Pred: {'P1' if prob_xgb_ll >= 0.5 else 'P2'} {'✓' if (prob_xgb_ll >= 0.5) == actual else '✗'} | Strat1: {round(strat1[1]-bet_size,2)} | Strat2: {round(strat2[1]-(bet_size if ev_xgb_ll else 0),2)} | Strat2 Distance: {xgb_ll_dist:.6f} | Requirement Met: {'✓' if ev_xgb_ll else '✗'}")
    print(f"XGB (Err):   P1 Win: {prob_xgb_err:.2%} | P2 Win: {1-prob_xgb_err:.2%} | Pred: {'P1' if prob_xgb_err >= 0.5 else 'P2'} {'✓' if (prob_xgb_err >= 0.5) == actual else '✗'} | Strat1: {round(strat1[2]-bet_size,2)} | Strat2: {round(strat2[2]-(bet_size if ev_xgb_err else 0),2)} | Strat2 Distance: {xgb_err_dist:.6f} | Requirement Met: {'✓' if ev_xgb_err else '✗'}")
    print(f"MLP (LL):    P1 Win: {prob_mlp_ll:.2%} | P2 Win: {1-prob_mlp_ll:.2%} | Pred: {'P1' if prob_mlp_ll >= 0.5 else 'P2'} {'✓' if (prob_mlp_ll >= 0.5) == actual else '✗'} | Strat1: {round(strat1[3]-bet_size,2)} | Strat2: {round(strat2[3]-(bet_size if ev_mlp_ll else 0),2)} | Strat2 Distance: {mlp_ll_dist:.6f} | Requirement Met: {'✓' if ev_mlp_ll else '✗'}")
    print(f"MLP (Err):   P1 Win: {prob_mlp_err:.2%} | P2 Win: {1-prob_mlp_err:.2%} | Pred: {'P1' if prob_mlp_err >= 0.5 else 'P2'} {'✓' if (prob_mlp_err >= 0.5) == actual else '✗'} | Strat1: {round(strat1[4]-bet_size,2)} | Strat2: {round(strat2[4]-(bet_size if ev_mlp_err else 0),2)} | Strat2 Distance: {mlp_err_dist:.6f} | Requirement Met: {'✓' if ev_mlp_err else '✗'}")
    
    # update strat 1
    update_betting_stats(log_reg_cum, strat1[0], bet_size, prob_lr, actual)
    update_betting_stats(xgb_ll_cum, strat1[1], bet_size, prob_xgb_ll, actual)
    update_betting_stats(xgb_err_cum, strat1[2], bet_size, prob_xgb_err, actual)
    update_betting_stats(mlp_ll_cum, strat1[3], bet_size, prob_mlp_ll, actual)
    update_betting_stats(mlp_err_cum, strat1[4], bet_size, prob_mlp_err, actual)
    # update strat 2
    update_betting_stats(log_reg_cum2, strat2[0], bet_size if ev_log else 0, prob_lr, actual, required_dist, abs(log_dist))
    update_betting_stats(xgb_ll_cum2, strat2[1], bet_size if ev_xgb_ll else 0, prob_xgb_ll, actual, required_dist, abs(xgb_ll_dist))
    update_betting_stats(xgb_err_cum2, strat2[2], bet_size if ev_xgb_err else 0, prob_xgb_err, actual, required_dist, abs(xgb_err_dist))
    update_betting_stats(mlp_ll_cum2, strat2[3], bet_size if ev_mlp_ll else 0, prob_mlp_ll, actual, required_dist, abs(mlp_ll_dist))
    update_betting_stats(mlp_err_cum2, strat2[4], bet_size if ev_mlp_err else 0, prob_mlp_err, actual, required_dist, abs(mlp_err_dist))
# Out:
# === Match 0 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.022146 | Winner odds: 1.02 | Loser odds: 28.96 | Margin: 0.014923 | P1 Prob: 0.034530 | P2 Prob: 0.980392
# LogReg:      P1 Win: 3.91% | P2 Win: 96.09% | Pred: P2 ✓ | Strat1: 2.0 | Strat2: 0 | Strat2 Distance: 0.005071 | Requirement Met: ✗
# XGB (LL):    P1 Win: 6.38% | P2 Win: 93.62% | Pred: P2 ✓ | Strat1: 2.0 | Strat2: -4.51 | Strat2 Distance: 0.029758 | Requirement Met: ✓
# XGB (Err):   P1 Win: 7.34% | P2 Win: 92.66% | Pred: P2 ✓ | Strat1: 2.0 | Strat2: -5.48 | Strat2 Distance: 0.039329 | Requirement Met: ✓
# MLP (LL):    P1 Win: 3.47% | P2 Win: 96.53% | Pred: P2 ✓ | Strat1: 2.0 | Strat2: 0 | Strat2 Distance: 0.000643 | Requirement Met: ✗
# MLP (Err):   P1 Win: 2.45% | P2 Win: 97.55% | Pred: P2 ✓ | Strat1: 2.0 | Strat2: 0 | Strat2 Distance: -0.009543 | Requirement Met: ✗
#
# === Match 1 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.061139 | Winner odds: 1.24 | Loser odds: 4.63 | Margin: 0.022434 | P1 Prob: 0.215983 | P2 Prob: 0.806452
# LogReg:      P1 Win: 23.83% | P2 Win: 76.17% | Pred: P2 ✓ | Strat1: 24.0 | Strat2: 0 | Strat2 Distance: 0.027100 | Requirement Met: ✗
# XGB (LL):    P1 Win: 24.24% | P2 Win: 75.76% | Pred: P2 ✓ | Strat1: 24.0 | Strat2: 0 | Strat2 Distance: 0.031160 | Requirement Met: ✗
# XGB (Err):   P1 Win: 28.20% | P2 Win: 71.80% | Pred: P2 ✓ | Strat1: 24.0 | Strat2: -10.97 | Strat2 Distance: 0.070762 | Requirement Met: ✓
# MLP (LL):    P1 Win: 21.73% | P2 Win: 78.27% | Pred: P2 ✓ | Strat1: 24.0 | Strat2: 0 | Strat2 Distance: 0.006020 | Requirement Met: ✗
# MLP (Err):   P1 Win: 19.27% | P2 Win: 80.73% | Pred: P2 ✓ | Strat1: 24.0 | Strat2: 0 | Strat2 Distance: -0.018513 | Requirement Met: ✗
#
# === Match 2 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.075307 | Winner odds: 1.4 | Loser odds: 3.2 | Margin: 0.026786 | P1 Prob: 0.312500 | P2 Prob: 0.714286
# LogReg:      P1 Win: 60.65% | P2 Win: 39.35% | Pred: P1 ✗ | Strat1: -100 | Strat2: -44.91 | Strat2 Distance: 0.302160 | Requirement Met: ✓
# XGB (LL):    P1 Win: 52.12% | P2 Win: 47.88% | Pred: P1 ✗ | Strat1: -100 | Strat2: -32.97 | Strat2 Distance: 0.216861 | Requirement Met: ✓
# XGB (Err):   P1 Win: 56.59% | P2 Win: 43.41% | Pred: P1 ✗ | Strat1: -100 | Strat2: -39.23 | Strat2 Distance: 0.261576 | Requirement Met: ✓
# MLP (LL):    P1 Win: 62.36% | P2 Win: 37.64% | Pred: P1 ✗ | Strat1: -100 | Strat2: -47.3 | Strat2 Distance: 0.319219 | Requirement Met: ✓
# MLP (Err):   P1 Win: 61.27% | P2 Win: 38.73% | Pred: P1 ✗ | Strat1: -100 | Strat2: -45.78 | Strat2 Distance: 0.308394 | Requirement Met: ✓
#
# === Match 3 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.072445 | Winner odds: 2.84 | Loser odds: 1.49 | Margin: 0.023254 | P1 Prob: 0.352113 | P2 Prob: 0.671141
# LogReg:      P1 Win: 33.87% | P2 Win: 66.13% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.005436 | Requirement Met: ✗
# XGB (LL):    P1 Win: 34.27% | P2 Win: 65.73% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.001442 | Requirement Met: ✗
# XGB (Err):   P1 Win: 36.56% | P2 Win: 63.44% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.021443 | Requirement Met: ✗
# MLP (LL):    P1 Win: 27.63% | P2 Win: 72.37% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.067851 | Requirement Met: ✗
# MLP (Err):   P1 Win: 26.78% | P2 Win: 73.22% | Pred: P2 ✗ | Strat1: -100 | Strat2: -23.95 | Strat2 Distance: -0.076342 | Requirement Met: ✓
#
# === Match 4 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.072898 | Winner odds: 1.35 | Loser odds: 3.5 | Margin: 0.026455 | P1 Prob: 0.740741 | P2 Prob: 0.285714
# LogReg:      P1 Win: 70.47% | P2 Win: 29.53% | Pred: P1 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: -0.016964 | Requirement Met: ✗
# XGB (LL):    P1 Win: 73.91% | P2 Win: 26.09% | Pred: P1 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: 0.017488 | Requirement Met: ✗
# XGB (Err):   P1 Win: 72.05% | P2 Win: 27.95% | Pred: P1 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: -0.001166 | Requirement Met: ✗
# MLP (LL):    P1 Win: 72.89% | P2 Win: 27.11% | Pred: P1 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: 0.007252 | Requirement Met: ✗
# MLP (Err):   P1 Win: 69.78% | P2 Win: 30.22% | Pred: P1 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: -0.023826 | Requirement Met: ✗
#
# === Match 5 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.076127 | Winner odds: 1.98 | Loser odds: 1.93 | Margin: 0.023185 | P1 Prob: 0.518135 | P2 Prob: 0.505051
# LogReg:      P1 Win: 37.20% | P2 Win: 62.80% | Pred: P2 ✓ | Strat1: 98.0 | Strat2: 24.34 | Strat2 Distance: -0.134382 | Requirement Met: ✓
# XGB (LL):    P1 Win: 40.92% | P2 Win: 59.08% | Pred: P2 ✓ | Strat1: 98.0 | Strat2: 16.99 | Strat2 Distance: -0.097231 | Requirement Met: ✓
# XGB (Err):   P1 Win: 43.17% | P2 Win: 56.83% | Pred: P2 ✓ | Strat1: 98.0 | Strat2: 0 | Strat2 Distance: -0.074665 | Requirement Met: ✗
# MLP (LL):    P1 Win: 33.71% | P2 Win: 66.29% | Pred: P2 ✓ | Strat1: 98.0 | Strat2: 31.26 | Strat2 Distance: -0.169314 | Requirement Met: ✓
# MLP (Err):   P1 Win: 34.86% | P2 Win: 65.14% | Pred: P2 ✓ | Strat1: 98.0 | Strat2: 28.98 | Strat2 Distance: -0.157813 | Requirement Met: ✓
#
# === Match 6 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.078277 | Winner odds: 2.19 | Loser odds: 1.76 | Margin: 0.024803 | P1 Prob: 0.568182 | P2 Prob: 0.456621
# LogReg:      P1 Win: 53.60% | P2 Win: 46.40% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.018400 | Requirement Met: ✗
# XGB (LL):    P1 Win: 60.36% | P2 Win: 39.64% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.049143 | Requirement Met: ✗
# XGB (Err):   P1 Win: 59.78% | P2 Win: 40.22% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.043418 | Requirement Met: ✗
# MLP (LL):    P1 Win: 59.61% | P2 Win: 40.39% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.041682 | Requirement Met: ✗
# MLP (Err):   P1 Win: 57.79% | P2 Win: 42.21% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.023421 | Requirement Met: ✗
#
# === Match 7 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.059785 | Winner odds: 1.24 | Loser odds: 4.65 | Margin: 0.021505 | P1 Prob: 0.806452 | P2 Prob: 0.215054
# LogReg:      P1 Win: 66.41% | P2 Win: 33.59% | Pred: P1 ✓ | Strat1: 24.0 | Strat2: -17.66 | Strat2 Distance: -0.125410 | Requirement Met: ✓
# XGB (LL):    P1 Win: 71.75% | P2 Win: 28.25% | Pred: P1 ✓ | Strat1: 24.0 | Strat2: -11.03 | Strat2 Distance: -0.071974 | Requirement Met: ✓
# XGB (Err):   P1 Win: 71.37% | P2 Win: 28.63% | Pred: P1 ✓ | Strat1: 24.0 | Strat2: -11.5 | Strat2 Distance: -0.075728 | Requirement Met: ✓
# MLP (LL):    P1 Win: 72.12% | P2 Win: 27.88% | Pred: P1 ✓ | Strat1: 24.0 | Strat2: -10.58 | Strat2 Distance: -0.068313 | Requirement Met: ✓
# MLP (Err):   P1 Win: 68.66% | P2 Win: 31.34% | Pred: P1 ✓ | Strat1: 24.0 | Strat2: -14.86 | Strat2 Distance: -0.102879 | Requirement Met: ✓
#
# === Match 8 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.059994 | Winner odds: 3.15 | Loser odds: 1.43 | Margin: 0.016761 | P1 Prob: 0.317460 | P2 Prob: 0.699301
# LogReg:      P1 Win: 20.92% | P2 Win: 79.08% | Pred: P2 ✗ | Strat1: -100 | Strat2: -34.09 | Strat2 Distance: -0.102984 | Requirement Met: ✓
# XGB (LL):    P1 Win: 14.69% | P2 Win: 85.31% | Pred: P2 ✗ | Strat1: -100 | Strat2: -53.73 | Strat2 Distance: -0.165331 | Requirement Met: ✓
# XGB (Err):   P1 Win: 18.01% | P2 Win: 81.99% | Pred: P2 ✗ | Strat1: -100 | Strat2: -43.27 | Strat2 Distance: -0.132132 | Requirement Met: ✓
# MLP (LL):    P1 Win: 18.26% | P2 Win: 81.74% | Pred: P2 ✗ | Strat1: -100 | Strat2: -42.47 | Strat2 Distance: -0.129606 | Requirement Met: ✓
# MLP (Err):   P1 Win: 15.53% | P2 Win: 84.47% | Pred: P2 ✗ | Strat1: -100 | Strat2: -51.09 | Strat2 Distance: -0.156970 | Requirement Met: ✓
#
# === Match 9 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.048468 | Winner odds: 1.1 | Loser odds: 8.73 | Margin: 0.023638 | P1 Prob: 0.909091 | P2 Prob: 0.114548
# LogReg:      P1 Win: 72.79% | P2 Win: 27.21% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: -19.93 | Strat2 Distance: -0.160195 | Requirement Met: ✓
# XGB (LL):    P1 Win: 76.57% | P2 Win: 23.43% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: -15.78 | Strat2 Distance: -0.122438 | Requirement Met: ✓
# XGB (Err):   P1 Win: 74.91% | P2 Win: 25.09% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: -17.6 | Strat2 Distance: -0.138995 | Requirement Met: ✓
# MLP (LL):    P1 Win: 77.31% | P2 Win: 22.69% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: -14.96 | Strat2 Distance: -0.115009 | Requirement Met: ✓
# MLP (Err):   P1 Win: 73.06% | P2 Win: 26.94% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: -19.64 | Strat2 Distance: -0.157538 | Requirement Met: ✓
#
# === Match 10 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.075711 | Winner odds: 2.53 | Loser odds: 1.59 | Margin: 0.024188 | P1 Prob: 0.395257 | P2 Prob: 0.628931
# LogReg:      P1 Win: 58.44% | P2 Win: 41.56% | Pred: P1 ✓ | Strat1: 153.0 | Strat2: 47.84 | Strat2 Distance: 0.198444 | Requirement Met: ✓
# XGB (LL):    P1 Win: 46.02% | P2 Win: 53.98% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.074251 | Requirement Met: ✗
# XGB (Err):   P1 Win: 45.09% | P2 Win: 54.91% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.064942 | Requirement Met: ✗
# MLP (LL):    P1 Win: 55.25% | P2 Win: 44.75% | Pred: P1 ✓ | Strat1: 153.0 | Strat2: 39.79 | Strat2 Distance: 0.166599 | Requirement Met: ✓
# MLP (Err):   P1 Win: 51.46% | P2 Win: 48.54% | Pred: P1 ✓ | Strat1: 153.0 | Strat2: 30.2 | Strat2 Distance: 0.128701 | Requirement Met: ✓
#
# === Match 11 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.064126 | Winner odds: 4.14 | Loser odds: 1.28 | Margin: 0.022796 | P1 Prob: 0.781250 | P2 Prob: 0.241546
# LogReg:      P1 Win: 70.01% | P2 Win: 29.99% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.063749 | Requirement Met: ✗
# XGB (LL):    P1 Win: 74.02% | P2 Win: 25.98% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.023613 | Requirement Met: ✗
# XGB (Err):   P1 Win: 71.28% | P2 Win: 28.72% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.051072 | Requirement Met: ✗
# MLP (LL):    P1 Win: 71.18% | P2 Win: 28.82% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.052082 | Requirement Met: ✗
# MLP (Err):   P1 Win: 68.46% | P2 Win: 31.54% | Pred: P1 ✗ | Strat1: -100 | Strat2: 30.58 | Strat2 Distance: -0.079237 | Requirement Met: ✓
#
# === Match 12 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.068325 | Winner odds: 1.32 | Loser odds: 3.75 | Margin: 0.024242 | P1 Prob: 0.266667 | P2 Prob: 0.757576
# LogReg:      P1 Win: 28.66% | P2 Win: 71.34% | Pred: P2 ✓ | Strat1: 32.0 | Strat2: 0 | Strat2 Distance: 0.026212 | Requirement Met: ✗
# XGB (LL):    P1 Win: 27.09% | P2 Win: 72.91% | Pred: P2 ✓ | Strat1: 32.0 | Strat2: 0 | Strat2 Distance: 0.010553 | Requirement Met: ✗
# XGB (Err):   P1 Win: 29.44% | P2 Win: 70.56% | Pred: P2 ✓ | Strat1: 32.0 | Strat2: 0 | Strat2 Distance: 0.034079 | Requirement Met: ✗
# MLP (LL):    P1 Win: 22.57% | P2 Win: 77.43% | Pred: P2 ✓ | Strat1: 32.0 | Strat2: 0 | Strat2 Distance: -0.034657 | Requirement Met: ✗
# MLP (Err):   P1 Win: 20.17% | P2 Win: 79.83% | Pred: P2 ✓ | Strat1: 32.0 | Strat2: 0 | Strat2 Distance: -0.058673 | Requirement Met: ✗
#
# === Match 13 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.076803 | Winner odds: 1.75 | Loser odds: 2.21 | Margin: 0.023917 | P1 Prob: 0.571429 | P2 Prob: 0.452489
# LogReg:      P1 Win: 41.35% | P2 Win: 58.65% | Pred: P2 ✗ | Strat1: -100 | Strat2: -27.64 | Strat2 Distance: -0.144578 | Requirement Met: ✓
# XGB (LL):    P1 Win: 43.84% | P2 Win: 56.16% | Pred: P2 ✗ | Strat1: -100 | Strat2: -23.29 | Strat2 Distance: -0.119715 | Requirement Met: ✓
# XGB (Err):   P1 Win: 43.46% | P2 Win: 56.54% | Pred: P2 ✗ | Strat1: -100 | Strat2: -23.94 | Strat2 Distance: -0.123468 | Requirement Met: ✓
# MLP (LL):    P1 Win: 37.78% | P2 Win: 62.22% | Pred: P2 ✗ | Strat1: -100 | Strat2: -33.89 | Strat2 Distance: -0.180293 | Requirement Met: ✓
# MLP (Err):   P1 Win: 39.19% | P2 Win: 60.81% | Pred: P2 ✗ | Strat1: -100 | Strat2: -31.41 | Strat2 Distance: -0.166152 | Requirement Met: ✓
#
# === Match 14 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.080223 | Winner odds: 1.79 | Loser odds: 2.14 | Margin: 0.025949 | P1 Prob: 0.467290 | P2 Prob: 0.558659
# LogReg:      P1 Win: 51.51% | P2 Win: 48.49% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.059642 | Requirement Met: ✗
# XGB (LL):    P1 Win: 54.45% | P2 Win: 45.55% | Pred: P1 ✗ | Strat1: -100 | Strat2: -18.47 | Strat2 Distance: 0.089041 | Requirement Met: ✓
# XGB (Err):   P1 Win: 52.96% | P2 Win: 47.04% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.074125 | Requirement Met: ✗
# MLP (LL):    P1 Win: 56.07% | P2 Win: 43.93% | Pred: P1 ✗ | Strat1: -100 | Strat2: -21.37 | Strat2 Distance: 0.105264 | Requirement Met: ✓
# MLP (Err):   P1 Win: 52.61% | P2 Win: 47.39% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.070626 | Requirement Met: ✗
#
# === Match 15 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.030452 | Winner odds: 1.06 | Loser odds: 14.11 | Margin: 0.014268 | P1 Prob: 0.070872 | P2 Prob: 0.943396
# LogReg:      P1 Win: 8.22% | P2 Win: 91.78% | Pred: P2 ✓ | Strat1: 6.0 | Strat2: 0 | Strat2 Distance: 0.012277 | Requirement Met: ✗
# XGB (LL):    P1 Win: 7.18% | P2 Win: 92.82% | Pred: P2 ✓ | Strat1: 6.0 | Strat2: 0 | Strat2 Distance: 0.001906 | Requirement Met: ✗
# XGB (Err):   P1 Win: 8.88% | P2 Win: 91.12% | Pred: P2 ✓ | Strat1: 6.0 | Strat2: 0 | Strat2 Distance: 0.018965 | Requirement Met: ✗
# MLP (LL):    P1 Win: 6.84% | P2 Win: 93.16% | Pred: P2 ✓ | Strat1: 6.0 | Strat2: 0 | Strat2 Distance: -0.001496 | Requirement Met: ✗
# MLP (Err):   P1 Win: 5.01% | P2 Win: 94.99% | Pred: P2 ✓ | Strat1: 6.0 | Strat2: 0 | Strat2 Distance: -0.019774 | Requirement Met: ✗
#
# === Match 16 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.015182 | Winner odds: 1.01 | Loser odds: 47.27 | Margin: 0.011254 | P1 Prob: 0.990099 | P2 Prob: 0.021155
# LogReg:      P1 Win: 96.09% | P2 Win: 3.91% | Pred: P1 ✓ | Strat1: 1.0 | Strat2: -2.95 | Strat2 Distance: -0.018212 | Requirement Met: ✓
# XGB (LL):    P1 Win: 97.09% | P2 Win: 2.91% | Pred: P1 ✓ | Strat1: 1.0 | Strat2: 0 | Strat2 Distance: -0.008168 | Requirement Met: ✗
# XGB (Err):   P1 Win: 94.29% | P2 Win: 5.71% | Pred: P1 ✓ | Strat1: 1.0 | Strat2: -4.77 | Strat2 Distance: -0.036207 | Requirement Met: ✓
# MLP (LL):    P1 Win: 96.94% | P2 Win: 3.06% | Pred: P1 ✓ | Strat1: 1.0 | Strat2: 0 | Strat2 Distance: -0.009713 | Requirement Met: ✗
# MLP (Err):   P1 Win: 95.87% | P2 Win: 4.13% | Pred: P1 ✓ | Strat1: 1.0 | Strat2: -3.17 | Strat2 Distance: -0.020407 | Requirement Met: ✓
#
# === Match 17 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.065150 | Winner odds: 3.78 | Loser odds: 1.32 | Margin: 0.022126 | P1 Prob: 0.757576 | P2 Prob: 0.264550
# LogReg:      P1 Win: 65.86% | P2 Win: 34.14% | Pred: P1 ✗ | Strat1: -100 | Strat2: 29.03 | Strat2 Distance: -0.082537 | Requirement Met: ✓
# XGB (LL):    P1 Win: 65.81% | P2 Win: 34.19% | Pred: P1 ✗ | Strat1: -100 | Strat2: 29.24 | Strat2 Distance: -0.083084 | Requirement Met: ✓
# XGB (Err):   P1 Win: 62.53% | P2 Win: 37.47% | Pred: P1 ✗ | Strat1: -100 | Strat2: 41.65 | Strat2 Distance: -0.115918 | Requirement Met: ✓
# MLP (LL):    P1 Win: 66.56% | P2 Win: 33.44% | Pred: P1 ✗ | Strat1: -100 | Strat2: 26.4 | Strat2 Distance: -0.075564 | Requirement Met: ✓
# MLP (Err):   P1 Win: 64.92% | P2 Win: 35.08% | Pred: P1 ✗ | Strat1: -100 | Strat2: 32.6 | Strat2 Distance: -0.091960 | Requirement Met: ✓
#
# === Match 18 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.077105 | Winner odds: 2.33 | Loser odds: 1.68 | Margin: 0.024423 | P1 Prob: 0.595238 | P2 Prob: 0.429185
# LogReg:      P1 Win: 67.19% | P2 Win: 32.81% | Pred: P1 ✗ | Strat1: -100 | Strat2: -23.55 | Strat2 Distance: 0.090840 | Requirement Met: ✓
# XGB (LL):    P1 Win: 58.99% | P2 Win: 41.01% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.008899 | Requirement Met: ✗
# XGB (Err):   P1 Win: 57.44% | P2 Win: 42.56% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.006643 | Requirement Met: ✗
# MLP (LL):    P1 Win: 64.46% | P2 Win: 35.54% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.063530 | Requirement Met: ✗
# MLP (Err):   P1 Win: 63.17% | P2 Win: 36.83% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.050671 | Requirement Met: ✗
#
# === Match 19 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.066147 | Winner odds: 1.31 | Loser odds: 3.85 | Margin: 0.023099 | P1 Prob: 0.763359 | P2 Prob: 0.259740
# LogReg:      P1 Win: 69.39% | P2 Win: 30.61% | Pred: P1 ✓ | Strat1: 31.0 | Strat2: 0 | Strat2 Distance: -0.052196 | Requirement Met: ✗
# XGB (LL):    P1 Win: 69.39% | P2 Win: 30.61% | Pred: P1 ✓ | Strat1: 31.0 | Strat2: 0 | Strat2 Distance: -0.052222 | Requirement Met: ✗
# XGB (Err):   P1 Win: 68.09% | P2 Win: 31.91% | Pred: P1 ✓ | Strat1: 31.0 | Strat2: 0 | Strat2 Distance: -0.065237 | Requirement Met: ✗
# MLP (LL):    P1 Win: 71.02% | P2 Win: 28.98% | Pred: P1 ✓ | Strat1: 31.0 | Strat2: 0 | Strat2 Distance: -0.035913 | Requirement Met: ✗
# MLP (Err):   P1 Win: 69.28% | P2 Win: 30.72% | Pred: P1 ✓ | Strat1: 31.0 | Strat2: 0 | Strat2 Distance: -0.053329 | Requirement Met: ✗
#
# === Match 20 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.076873 | Winner odds: 2.35 | Loser odds: 1.67 | Margin: 0.024334 | P1 Prob: 0.598802 | P2 Prob: 0.425532
# LogReg:      P1 Win: 49.43% | P2 Win: 50.57% | Pred: P2 ✓ | Strat1: 135.0 | Strat2: 18.85 | Strat2 Distance: -0.090306 | Requirement Met: ✓
# XGB (LL):    P1 Win: 54.37% | P2 Win: 45.63% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.040843 | Requirement Met: ✗
# XGB (Err):   P1 Win: 55.10% | P2 Win: 44.90% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.033564 | Requirement Met: ✗
# MLP (LL):    P1 Win: 51.28% | P2 Win: 48.72% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.071805 | Requirement Met: ✗
# MLP (Err):   P1 Win: 43.72% | P2 Win: 56.28% | Pred: P2 ✓ | Strat1: 135.0 | Strat2: 32.27 | Strat2 Distance: -0.147423 | Requirement Met: ✓
#
# === Match 21 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.070054 | Winner odds: 3.66 | Loser odds: 1.33 | Margin: 0.025104 | P1 Prob: 0.751880 | P2 Prob: 0.273224
# LogReg:      P1 Win: 67.06% | P2 Win: 32.94% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.062908 | Requirement Met: ✗
# XGB (LL):    P1 Win: 65.73% | P2 Win: 34.27% | Pred: P1 ✗ | Strat1: -100 | Strat2: 25.42 | Strat2 Distance: -0.076146 | Requirement Met: ✓
# XGB (Err):   P1 Win: 64.40% | P2 Win: 35.60% | Pred: P1 ✗ | Strat1: -100 | Strat2: 30.3 | Strat2 Distance: -0.089479 | Requirement Met: ✓
# MLP (LL):    P1 Win: 66.98% | P2 Win: 33.02% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.063659 | Requirement Met: ✗
# MLP (Err):   P1 Win: 63.68% | P2 Win: 36.32% | Pred: P1 ✗ | Strat1: -100 | Strat2: 32.91 | Strat2 Distance: -0.096618 | Requirement Met: ✓
#
# === Match 22 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.067096 | Winner odds: 1.24 | Loser odds: 4.54 | Margin: 0.026716 | P1 Prob: 0.806452 | P2 Prob: 0.220264
# LogReg:      P1 Win: 65.21% | P2 Win: 34.79% | Pred: P1 ✓ | Strat1: 24.0 | Strat2: -19.14 | Strat2 Distance: -0.133337 | Requirement Met: ✓
# XGB (LL):    P1 Win: 61.68% | P2 Win: 38.32% | Pred: P1 ✓ | Strat1: 24.0 | Strat2: -23.51 | Strat2 Distance: -0.168626 | Requirement Met: ✓
# XGB (Err):   P1 Win: 60.35% | P2 Win: 39.65% | Pred: P1 ✓ | Strat1: 24.0 | Strat2: -25.17 | Strat2 Distance: -0.182012 | Requirement Met: ✓
# MLP (LL):    P1 Win: 64.00% | P2 Win: 36.00% | Pred: P1 ✓ | Strat1: 24.0 | Strat2: -20.64 | Strat2 Distance: -0.145431 | Requirement Met: ✓
# MLP (Err):   P1 Win: 59.85% | P2 Win: 40.15% | Pred: P1 ✓ | Strat1: 24.0 | Strat2: -25.79 | Strat2 Distance: -0.186992 | Requirement Met: ✓
#
# === Match 23 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.062630 | Winner odds: 1.23 | Loser odds: 4.74 | Margin: 0.023979 | P1 Prob: 0.813008 | P2 Prob: 0.210970
# LogReg:      P1 Win: 72.52% | P2 Win: 27.48% | Pred: P1 ✓ | Strat1: 23.0 | Strat2: -10.8 | Strat2 Distance: -0.068796 | Requirement Met: ✓
# XGB (LL):    P1 Win: 76.95% | P2 Win: 23.05% | Pred: P1 ✓ | Strat1: 23.0 | Strat2: 0 | Strat2 Distance: -0.024447 | Requirement Met: ✗
# XGB (Err):   P1 Win: 77.14% | P2 Win: 22.86% | Pred: P1 ✓ | Strat1: 23.0 | Strat2: 0 | Strat2 Distance: -0.022577 | Requirement Met: ✗
# MLP (LL):    P1 Win: 78.03% | P2 Win: 21.97% | Pred: P1 ✓ | Strat1: 23.0 | Strat2: 0 | Strat2 Distance: -0.013620 | Requirement Met: ✗
# MLP (Err):   P1 Win: 74.89% | P2 Win: 25.11% | Pred: P1 ✓ | Strat1: 23.0 | Strat2: 0 | Strat2 Distance: -0.045086 | Requirement Met: ✗
#
# === Match 24 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.064780 | Winner odds: 1.26 | Loser odds: 4.34 | Margin: 0.024066 | P1 Prob: 0.793651 | P2 Prob: 0.230415
# LogReg:      P1 Win: 81.73% | P2 Win: 18.27% | Pred: P1 ✓ | Strat1: 26.0 | Strat2: 0 | Strat2 Distance: 0.042261 | Requirement Met: ✗
# XGB (LL):    P1 Win: 87.05% | P2 Win: 12.95% | Pred: P1 ✓ | Strat1: 26.0 | Strat2: 9.68 | Strat2 Distance: 0.095496 | Requirement Met: ✓
# XGB (Err):   P1 Win: 84.14% | P2 Win: 15.86% | Pred: P1 ✓ | Strat1: 26.0 | Strat2: 6.02 | Strat2 Distance: 0.066417 | Requirement Met: ✓
# MLP (LL):    P1 Win: 84.00% | P2 Win: 16.00% | Pred: P1 ✓ | Strat1: 26.0 | Strat2: 5.84 | Strat2 Distance: 0.064969 | Requirement Met: ✓
# MLP (Err):   P1 Win: 81.67% | P2 Win: 18.33% | Pred: P1 ✓ | Strat1: 26.0 | Strat2: 0 | Strat2 Distance: 0.041712 | Requirement Met: ✗
#
# === Match 25 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.081033 | Winner odds: 2.11 | Loser odds: 1.81 | Margin: 0.026420 | P1 Prob: 0.473934 | P2 Prob: 0.552486
# LogReg:      P1 Win: 54.71% | P2 Win: 45.29% | Pred: P1 ✓ | Strat1: 111.0 | Strat2: 15.43 | Strat2 Distance: 0.085347 | Requirement Met: ✓
# XGB (LL):    P1 Win: 57.95% | P2 Win: 42.05% | Pred: P1 ✓ | Strat1: 111.0 | Strat2: 22.27 | Strat2 Distance: 0.117759 | Requirement Met: ✓
# XGB (Err):   P1 Win: 57.13% | P2 Win: 42.87% | Pred: P1 ✓ | Strat1: 111.0 | Strat2: 20.55 | Strat2 Distance: 0.109575 | Requirement Met: ✓
# MLP (LL):    P1 Win: 64.61% | P2 Win: 35.39% | Pred: P1 ✓ | Strat1: 111.0 | Strat2: 36.32 | Strat2 Distance: 0.184347 | Requirement Met: ✓
# MLP (Err):   P1 Win: 61.41% | P2 Win: 38.59% | Pred: P1 ✓ | Strat1: 111.0 | Strat2: 29.58 | Strat2 Distance: 0.152403 | Requirement Met: ✓
#
# === Match 26 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.074128 | Winner odds: 2.34 | Loser odds: 1.68 | Margin: 0.022589 | P1 Prob: 0.427350 | P2 Prob: 0.595238
# LogReg:      P1 Win: 50.75% | P2 Win: 49.25% | Pred: P1 ✓ | Strat1: 134.0 | Strat2: 18.76 | Strat2 Distance: 0.089627 | Requirement Met: ✓
# XGB (LL):    P1 Win: 51.78% | P2 Win: 48.22% | Pred: P1 ✓ | Strat1: 134.0 | Strat2: 21.16 | Strat2 Distance: 0.099864 | Requirement Met: ✓
# XGB (Err):   P1 Win: 54.75% | P2 Win: 45.25% | Pred: P1 ✓ | Strat1: 134.0 | Strat2: 28.12 | Strat2 Distance: 0.129617 | Requirement Met: ✓
# MLP (LL):    P1 Win: 58.95% | P2 Win: 41.05% | Pred: P1 ✓ | Strat1: 134.0 | Strat2: 37.95 | Strat2 Distance: 0.171627 | Requirement Met: ✓
# MLP (Err):   P1 Win: 57.22% | P2 Win: 42.78% | Pred: P1 ✓ | Strat1: 134.0 | Strat2: 33.89 | Strat2 Distance: 0.154284 | Requirement Met: ✓
#
# === Match 27 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.065789 | Winner odds: 4.56 | Loser odds: 1.24 | Margin: 0.025750 | P1 Prob: 0.219298 | P2 Prob: 0.806452
# LogReg:      P1 Win: 21.95% | P2 Win: 78.05% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.005660 | Requirement Met: ✗
# XGB (LL):    P1 Win: 21.72% | P2 Win: 78.28% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.003393 | Requirement Met: ✗
# XGB (Err):   P1 Win: 21.61% | P2 Win: 78.39% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.002263 | Requirement Met: ✗
# MLP (LL):    P1 Win: 15.77% | P2 Win: 84.23% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.056095 | Requirement Met: ✗
# MLP (Err):   P1 Win: 17.07% | P2 Win: 82.93% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.043070 | Requirement Met: ✗
#
# === Match 28 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.071874 | Winner odds: 1.38 | Loser odds: 3.33 | Margin: 0.024938 | P1 Prob: 0.724638 | P2 Prob: 0.300300
# LogReg:      P1 Win: 68.24% | P2 Win: 31.76% | Pred: P1 ✓ | Strat1: 38.0 | Strat2: 0 | Strat2 Distance: -0.024644 | Requirement Met: ✗
# XGB (LL):    P1 Win: 69.36% | P2 Win: 30.64% | Pred: P1 ✓ | Strat1: 38.0 | Strat2: 0 | Strat2 Distance: -0.013445 | Requirement Met: ✗
# XGB (Err):   P1 Win: 70.63% | P2 Win: 29.37% | Pred: P1 ✓ | Strat1: 38.0 | Strat2: 0 | Strat2 Distance: -0.000687 | Requirement Met: ✗
# MLP (LL):    P1 Win: 70.38% | P2 Win: 29.62% | Pred: P1 ✓ | Strat1: 38.0 | Strat2: 0 | Strat2 Distance: -0.003232 | Requirement Met: ✗
# MLP (Err):   P1 Win: 69.00% | P2 Win: 31.00% | Pred: P1 ✓ | Strat1: 38.0 | Strat2: 0 | Strat2 Distance: -0.017025 | Requirement Met: ✗
#
# === Match 29 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.057327 | Winner odds: 1.14 | Loser odds: 6.7 | Margin: 0.026447 | P1 Prob: 0.877193 | P2 Prob: 0.149254
# LogReg:      P1 Win: 73.00% | P2 Win: 27.00% | Pred: P1 ✓ | Strat1: 14.0 | Strat2: -16.78 | Strat2 Distance: -0.124613 | Requirement Met: ✓
# XGB (LL):    P1 Win: 77.52% | P2 Win: 22.48% | Pred: P1 ✓ | Strat1: 14.0 | Strat2: -11.63 | Strat2 Distance: -0.079441 | Requirement Met: ✓
# XGB (Err):   P1 Win: 76.30% | P2 Win: 23.70% | Pred: P1 ✓ | Strat1: 14.0 | Strat2: -13.01 | Strat2 Distance: -0.091554 | Requirement Met: ✓
# MLP (LL):    P1 Win: 74.96% | P2 Win: 25.04% | Pred: P1 ✓ | Strat1: 14.0 | Strat2: -14.55 | Strat2 Distance: -0.105017 | Requirement Met: ✓
# MLP (Err):   P1 Win: 71.55% | P2 Win: 28.45% | Pred: P1 ✓ | Strat1: 14.0 | Strat2: -18.44 | Strat2 Distance: -0.139119 | Requirement Met: ✓
#
# === Match 30 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.053295 | Winner odds: 1.16 | Loser odds: 6.27 | Margin: 0.021559 | P1 Prob: 0.862069 | P2 Prob: 0.159490
# LogReg:      P1 Win: 86.39% | P2 Win: 13.61% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: 0.020057 | Requirement Met: ✗
# XGB (LL):    P1 Win: 88.78% | P2 Win: 11.22% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: 0.043898 | Requirement Met: ✗
# XGB (Err):   P1 Win: 87.41% | P2 Win: 12.59% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: 0.030201 | Requirement Met: ✗
# MLP (LL):    P1 Win: 88.67% | P2 Win: 11.33% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: 0.042836 | Requirement Met: ✗
# MLP (Err):   P1 Win: 84.81% | P2 Win: 15.19% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: 0.004255 | Requirement Met: ✗
#
# === Match 31 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.064347 | Winner odds: 1.25 | Loser odds: 4.46 | Margin: 0.024215 | P1 Prob: 0.800000 | P2 Prob: 0.224215
# LogReg:      P1 Win: 71.48% | P2 Win: 28.52% | Pred: P1 ✓ | Strat1: 25.0 | Strat2: -10.65 | Strat2 Distance: -0.066325 | Requirement Met: ✓
# XGB (LL):    P1 Win: 79.16% | P2 Win: 20.84% | Pred: P1 ✓ | Strat1: 25.0 | Strat2: 0 | Strat2 Distance: 0.010508 | Requirement Met: ✗
# XGB (Err):   P1 Win: 76.34% | P2 Win: 23.66% | Pred: P1 ✓ | Strat1: 25.0 | Strat2: 0 | Strat2 Distance: -0.017667 | Requirement Met: ✗
# MLP (LL):    P1 Win: 73.21% | P2 Win: 26.79% | Pred: P1 ✓ | Strat1: 25.0 | Strat2: 0 | Strat2 Distance: -0.049017 | Requirement Met: ✗
# MLP (Err):   P1 Win: 71.93% | P2 Win: 28.07% | Pred: P1 ✓ | Strat1: 25.0 | Strat2: 0 | Strat2 Distance: -0.061828 | Requirement Met: ✗
#
# === Match 32 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.063885 | Winner odds: 1.21 | Loser odds: 5.01 | Margin: 0.026047 | P1 Prob: 0.826446 | P2 Prob: 0.199601
# LogReg:      P1 Win: 79.80% | P2 Win: 20.20% | Pred: P1 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: -0.007468 | Requirement Met: ✗
# XGB (LL):    P1 Win: 79.36% | P2 Win: 20.64% | Pred: P1 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: -0.011890 | Requirement Met: ✗
# XGB (Err):   P1 Win: 77.07% | P2 Win: 22.93% | Pred: P1 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: -0.034814 | Requirement Met: ✗
# MLP (LL):    P1 Win: 79.02% | P2 Win: 20.98% | Pred: P1 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: -0.015257 | Requirement Met: ✗
# MLP (Err):   P1 Win: 74.20% | P2 Win: 25.80% | Pred: P1 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: -0.063487 | Requirement Met: ✗
#
# === Match 33 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.076655 | Winner odds: 1.47 | Loser odds: 2.89 | Margin: 0.026293 | P1 Prob: 0.346021 | P2 Prob: 0.680272
# LogReg:      P1 Win: 37.39% | P2 Win: 62.61% | Pred: P2 ✓ | Strat1: 47.0 | Strat2: 0 | Strat2 Distance: 0.036714 | Requirement Met: ✗
# XGB (LL):    P1 Win: 35.11% | P2 Win: 64.89% | Pred: P2 ✓ | Strat1: 47.0 | Strat2: 0 | Strat2 Distance: 0.013933 | Requirement Met: ✗
# XGB (Err):   P1 Win: 32.42% | P2 Win: 67.58% | Pred: P2 ✓ | Strat1: 47.0 | Strat2: 0 | Strat2 Distance: -0.012917 | Requirement Met: ✗
# MLP (LL):    P1 Win: 34.83% | P2 Win: 65.17% | Pred: P2 ✓ | Strat1: 47.0 | Strat2: 0 | Strat2 Distance: 0.011129 | Requirement Met: ✗
# MLP (Err):   P1 Win: 31.13% | P2 Win: 68.87% | Pred: P2 ✓ | Strat1: 47.0 | Strat2: 0 | Strat2 Distance: -0.025831 | Requirement Met: ✗
#
# === Match 34 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.078776 | Winner odds: 1.71 | Loser odds: 2.27 | Margin: 0.025324 | P1 Prob: 0.584795 | P2 Prob: 0.440529
# LogReg:      P1 Win: 48.71% | P2 Win: 51.29% | Pred: P2 ✗ | Strat1: -100 | Strat2: -16.71 | Strat2 Distance: -0.083261 | Requirement Met: ✓
# XGB (LL):    P1 Win: 44.55% | P2 Win: 55.45% | Pred: P2 ✗ | Strat1: -100 | Strat2: -23.82 | Strat2 Distance: -0.124837 | Requirement Met: ✓
# XGB (Err):   P1 Win: 47.29% | P2 Win: 52.71% | Pred: P2 ✗ | Strat1: -100 | Strat2: -19.13 | Strat2 Distance: -0.097452 | Requirement Met: ✓
# MLP (LL):    P1 Win: 45.37% | P2 Win: 54.63% | Pred: P2 ✗ | Strat1: -100 | Strat2: -22.41 | Strat2 Distance: -0.116602 | Requirement Met: ✓
# MLP (Err):   P1 Win: 48.87% | P2 Win: 51.13% | Pred: P2 ✗ | Strat1: -100 | Strat2: -16.44 | Strat2 Distance: -0.081677 | Requirement Met: ✓
#
# === Match 35 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.055041 | Winner odds: 1.13 | Loser odds: 7.11 | Margin: 0.025603 | P1 Prob: 0.140647 | P2 Prob: 0.884956
# LogReg:      P1 Win: 18.12% | P2 Win: 81.88% | Pred: P2 ✓ | Strat1: 13.0 | Strat2: 0 | Strat2 Distance: 0.044030 | Requirement Met: ✗
# XGB (LL):    P1 Win: 15.42% | P2 Win: 84.58% | Pred: P2 ✓ | Strat1: 13.0 | Strat2: 0 | Strat2 Distance: 0.017094 | Requirement Met: ✗
# XGB (Err):   P1 Win: 17.00% | P2 Win: 83.00% | Pred: P2 ✓ | Strat1: 13.0 | Strat2: 0 | Strat2 Distance: 0.032840 | Requirement Met: ✗
# MLP (LL):    P1 Win: 12.51% | P2 Win: 87.49% | Pred: P2 ✓ | Strat1: 13.0 | Strat2: 0 | Strat2 Distance: -0.012066 | Requirement Met: ✗
# MLP (Err):   P1 Win: 12.06% | P2 Win: 87.94% | Pred: P2 ✓ | Strat1: 13.0 | Strat2: 0 | Strat2 Distance: -0.016548 | Requirement Met: ✗
#
# === Match 36 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.071416 | Winner odds: 3.45 | Loser odds: 1.36 | Margin: 0.025149 | P1 Prob: 0.735294 | P2 Prob: 0.289855
# LogReg:      P1 Win: 57.03% | P2 Win: 42.97% | Pred: P1 ✗ | Strat1: -100 | Strat2: 48.24 | Strat2 Distance: -0.146937 | Requirement Met: ✓
# XGB (LL):    P1 Win: 65.63% | P2 Win: 34.37% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.060907 | Requirement Met: ✗
# XGB (Err):   P1 Win: 63.95% | P2 Win: 36.05% | Pred: P1 ✗ | Strat1: -100 | Strat2: 24.38 | Strat2 Distance: -0.077783 | Requirement Met: ✓
# MLP (LL):    P1 Win: 59.95% | P2 Win: 40.05% | Pred: P1 ✗ | Strat1: -100 | Strat2: 38.17 | Strat2 Distance: -0.117756 | Requirement Met: ✓
# MLP (Err):   P1 Win: 59.35% | P2 Win: 40.65% | Pred: P1 ✗ | Strat1: -100 | Strat2: 40.24 | Strat2 Distance: -0.123749 | Requirement Met: ✓
#
# === Match 37 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.023058 | Winner odds: 1.02 | Loser odds: 28.24 | Margin: 0.015803 | P1 Prob: 0.980392 | P2 Prob: 0.035411
# LogReg:      P1 Win: 89.23% | P2 Win: 10.77% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: -8.99 | Strat2 Distance: -0.072865 | Requirement Met: ✓
# XGB (LL):    P1 Win: 85.11% | P2 Win: 14.89% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: -13.18 | Strat2 Distance: -0.113998 | Requirement Met: ✓
# XGB (Err):   P1 Win: 82.39% | P2 Win: 17.61% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: -15.97 | Strat2 Distance: -0.141273 | Requirement Met: ✓
# MLP (LL):    P1 Win: 91.59% | P2 Win: 8.41% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: -6.57 | Strat2 Distance: -0.049193 | Requirement Met: ✓
# MLP (Err):   P1 Win: 87.04% | P2 Win: 12.96% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: -11.22 | Strat2 Distance: -0.094763 | Requirement Met: ✓
#
# === Match 38 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.014573 | Winner odds: 1.02 | Loser odds: 36.25 | Margin: 0.007978 | P1 Prob: 0.027586 | P2 Prob: 0.980392
# LogReg:      P1 Win: 12.44% | P2 Win: 87.56% | Pred: P2 ✓ | Strat1: 2.0 | Strat2: -10.69 | Strat2 Distance: 0.097001 | Requirement Met: ✓
# XGB (LL):    P1 Win: 9.34% | P2 Win: 90.66% | Pred: P2 ✓ | Strat1: 2.0 | Strat2: -7.52 | Strat2 Distance: 0.066012 | Requirement Met: ✓
# XGB (Err):   P1 Win: 9.93% | P2 Win: 90.07% | Pred: P2 ✓ | Strat1: 2.0 | Strat2: -8.13 | Strat2 Distance: 0.071901 | Requirement Met: ✓
# MLP (LL):    P1 Win: 13.11% | P2 Win: 86.89% | Pred: P2 ✓ | Strat1: 2.0 | Strat2: -11.37 | Strat2 Distance: 0.103747 | Requirement Met: ✓
# MLP (Err):   P1 Win: 10.74% | P2 Win: 89.26% | Pred: P2 ✓ | Strat1: 2.0 | Strat2: -8.96 | Strat2 Distance: 0.080051 | Requirement Met: ✓
#
# === Match 39 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.072414 | Winner odds: 2.65 | Loser odds: 1.55 | Margin: 0.022520 | P1 Prob: 0.377358 | P2 Prob: 0.645161
# LogReg:      P1 Win: 33.20% | P2 Win: 66.80% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.037027 | Requirement Met: ✗
# XGB (LL):    P1 Win: 34.13% | P2 Win: 65.87% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.027750 | Requirement Met: ✗
# XGB (Err):   P1 Win: 33.64% | P2 Win: 66.36% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.032684 | Requirement Met: ✗
# MLP (LL):    P1 Win: 35.88% | P2 Win: 64.12% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.010291 | Requirement Met: ✗
# MLP (Err):   P1 Win: 29.90% | P2 Win: 70.10% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.070087 | Requirement Met: ✗
#
# === Match 40 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.078775 | Winner odds: 2.47 | Loser odds: 1.61 | Margin: 0.025976 | P1 Prob: 0.404858 | P2 Prob: 0.621118
# LogReg:      P1 Win: 37.65% | P2 Win: 62.35% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.018135 | Requirement Met: ✗
# XGB (LL):    P1 Win: 43.62% | P2 Win: 56.38% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.041604 | Requirement Met: ✗
# XGB (Err):   P1 Win: 43.39% | P2 Win: 56.61% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.039300 | Requirement Met: ✗
# MLP (LL):    P1 Win: 43.87% | P2 Win: 56.13% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.044106 | Requirement Met: ✗
# MLP (Err):   P1 Win: 43.79% | P2 Win: 56.21% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.043280 | Requirement Met: ✗
#
# === Match 41 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.078752 | Winner odds: 2.09 | Loser odds: 1.83 | Margin: 0.024917 | P1 Prob: 0.478469 | P2 Prob: 0.546448
# LogReg:      P1 Win: 52.39% | P2 Win: 47.61% | Pred: P1 ✓ | Strat1: 109.0 | Strat2: 0 | Strat2 Distance: 0.057110 | Requirement Met: ✗
# XGB (LL):    P1 Win: 50.13% | P2 Win: 49.87% | Pred: P1 ✓ | Strat1: 109.0 | Strat2: 0 | Strat2 Distance: 0.034439 | Requirement Met: ✗
# XGB (Err):   P1 Win: 50.39% | P2 Win: 49.61% | Pred: P1 ✓ | Strat1: 109.0 | Strat2: 0 | Strat2 Distance: 0.037025 | Requirement Met: ✗
# MLP (LL):    P1 Win: 56.77% | P2 Win: 43.23% | Pred: P1 ✓ | Strat1: 109.0 | Strat2: 18.64 | Strat2 Distance: 0.100823 | Requirement Met: ✓
# MLP (Err):   P1 Win: 56.28% | P2 Win: 43.72% | Pred: P1 ✓ | Strat1: 109.0 | Strat2: 17.64 | Strat2 Distance: 0.096010 | Requirement Met: ✓
#
# === Match 42 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.072438 | Winner odds: 1.4 | Loser odds: 3.22 | Margin: 0.024845 | P1 Prob: 0.310559 | P2 Prob: 0.714286
# LogReg:      P1 Win: 32.95% | P2 Win: 67.05% | Pred: P2 ✓ | Strat1: 40.0 | Strat2: 0 | Strat2 Distance: 0.026463 | Requirement Met: ✗
# XGB (LL):    P1 Win: 36.43% | P2 Win: 63.57% | Pred: P2 ✓ | Strat1: 40.0 | Strat2: 0 | Strat2 Distance: 0.061268 | Requirement Met: ✗
# XGB (Err):   P1 Win: 35.49% | P2 Win: 64.51% | Pred: P2 ✓ | Strat1: 40.0 | Strat2: 0 | Strat2 Distance: 0.051885 | Requirement Met: ✗
# MLP (LL):    P1 Win: 28.52% | P2 Win: 71.48% | Pred: P2 ✓ | Strat1: 40.0 | Strat2: 0 | Strat2 Distance: -0.017833 | Requirement Met: ✗
# MLP (Err):   P1 Win: 28.12% | P2 Win: 71.88% | Pred: P2 ✓ | Strat1: 40.0 | Strat2: 0 | Strat2 Distance: -0.021848 | Requirement Met: ✗
#
# === Match 43 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.072746 | Winner odds: 1.37 | Loser odds: 3.38 | Margin: 0.025785 | P1 Prob: 0.295858 | P2 Prob: 0.729927
# LogReg:      P1 Win: 46.66% | P2 Win: 53.34% | Pred: P2 ✓ | Strat1: 37.0 | Strat2: -26.92 | Strat2 Distance: 0.178156 | Requirement Met: ✓
# XGB (LL):    P1 Win: 39.03% | P2 Win: 60.97% | Pred: P2 ✓ | Strat1: 37.0 | Strat2: -16.47 | Strat2 Distance: 0.101860 | Requirement Met: ✓
# XGB (Err):   P1 Win: 39.77% | P2 Win: 60.23% | Pred: P2 ✓ | Strat1: 37.0 | Strat2: -17.48 | Strat2 Distance: 0.109269 | Requirement Met: ✓
# MLP (LL):    P1 Win: 42.31% | P2 Win: 57.69% | Pred: P2 ✓ | Strat1: 37.0 | Strat2: -20.96 | Strat2 Distance: 0.134658 | Requirement Met: ✓
# MLP (Err):   P1 Win: 42.60% | P2 Win: 57.40% | Pred: P2 ✓ | Strat1: 37.0 | Strat2: -21.36 | Strat2 Distance: 0.137576 | Requirement Met: ✓
#
# === Match 44 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.079637 | Winner odds: 1.65 | Loser odds: 2.38 | Margin: 0.026229 | P1 Prob: 0.420168 | P2 Prob: 0.606061
# LogReg:      P1 Win: 51.19% | P2 Win: 48.81% | Pred: P1 ✗ | Strat1: -100 | Strat2: -19.46 | Strat2 Distance: 0.102425 | Requirement Met: ✓
# XGB (LL):    P1 Win: 45.43% | P2 Win: 54.57% | Pred: P2 ✓ | Strat1: 65.0 | Strat2: 0 | Strat2 Distance: 0.044825 | Requirement Met: ✗
# XGB (Err):   P1 Win: 47.39% | P2 Win: 52.61% | Pred: P2 ✓ | Strat1: 65.0 | Strat2: 0 | Strat2 Distance: 0.064487 | Requirement Met: ✗
# MLP (LL):    P1 Win: 53.58% | P2 Win: 46.42% | Pred: P1 ✗ | Strat1: -100 | Strat2: -23.4 | Strat2 Distance: 0.126340 | Requirement Met: ✓
# MLP (Err):   P1 Win: 45.75% | P2 Win: 54.25% | Pred: P2 ✓ | Strat1: 65.0 | Strat2: 0 | Strat2 Distance: 0.048103 | Requirement Met: ✗
#
# === Match 45 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.073024 | Winner odds: 1.47 | Loser odds: 2.91 | Margin: 0.023915 | P1 Prob: 0.680272 | P2 Prob: 0.343643
# LogReg:      P1 Win: 55.68% | P2 Win: 44.32% | Pred: P1 ✓ | Strat1: 47.0 | Strat2: -18.15 | Strat2 Distance: -0.107561 | Requirement Met: ✓
# XGB (LL):    P1 Win: 60.07% | P2 Win: 39.93% | Pred: P1 ✓ | Strat1: 47.0 | Strat2: 0 | Strat2 Distance: -0.063690 | Requirement Met: ✗
# XGB (Err):   P1 Win: 60.59% | P2 Win: 39.41% | Pred: P1 ✓ | Strat1: 47.0 | Strat2: 0 | Strat2 Distance: -0.058489 | Requirement Met: ✗
# MLP (LL):    P1 Win: 61.18% | P2 Win: 38.82% | Pred: P1 ✓ | Strat1: 47.0 | Strat2: 0 | Strat2 Distance: -0.052548 | Requirement Met: ✗
# MLP (Err):   P1 Win: 60.90% | P2 Win: 39.10% | Pred: P1 ✓ | Strat1: 47.0 | Strat2: 0 | Strat2 Distance: -0.055346 | Requirement Met: ✗
#
# === Match 46 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.023742 | Winner odds: 1.02 | Loser odds: 27.72 | Margin: 0.016467 | P1 Prob: 0.980392 | P2 Prob: 0.036075
# LogReg:      P1 Win: 96.98% | P2 Win: 3.02% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: 0 | Strat2 Distance: 0.005325 | Requirement Met: ✗
# XGB (LL):    P1 Win: 96.79% | P2 Win: 3.21% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: 0 | Strat2 Distance: 0.003426 | Requirement Met: ✗
# XGB (Err):   P1 Win: 94.57% | P2 Win: 5.43% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: 0 | Strat2 Distance: -0.018790 | Requirement Met: ✗
# MLP (LL):    P1 Win: 96.20% | P2 Win: 3.80% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: 0 | Strat2 Distance: -0.002462 | Requirement Met: ✗
# MLP (Err):   P1 Win: 94.98% | P2 Win: 5.02% | Pred: P1 ✓ | Strat1: 2.0 | Strat2: 0 | Strat2 Distance: -0.014661 | Requirement Met: ✗
#
# === Match 47 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.049877 | Winner odds: 1.1 | Loser odds: 8.64 | Margin: 0.024832 | P1 Prob: 0.909091 | P2 Prob: 0.115741
# LogReg:      P1 Win: 90.20% | P2 Win: 9.80% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: 0.014925 | Requirement Met: ✗
# XGB (LL):    P1 Win: 90.04% | P2 Win: 9.96% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: 0.013371 | Requirement Met: ✗
# XGB (Err):   P1 Win: 89.20% | P2 Win: 10.80% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: 0.004923 | Requirement Met: ✗
# MLP (LL):    P1 Win: 89.59% | P2 Win: 10.41% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: 0.008793 | Requirement Met: ✗
# MLP (Err):   P1 Win: 87.85% | P2 Win: 12.15% | Pred: P1 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: -0.008602 | Requirement Met: ✗
#
# === Match 48 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.076873 | Winner odds: 1.67 | Loser odds: 2.35 | Margin: 0.024334 | P1 Prob: 0.598802 | P2 Prob: 0.425532
# LogReg:      P1 Win: 62.33% | P2 Win: 37.67% | Pred: P1 ✓ | Strat1: 67.0 | Strat2: 0 | Strat2 Distance: 0.038711 | Requirement Met: ✗
# XGB (LL):    P1 Win: 65.50% | P2 Win: 34.50% | Pred: P1 ✓ | Strat1: 67.0 | Strat2: 0 | Strat2 Distance: 0.070380 | Requirement Met: ✗
# XGB (Err):   P1 Win: 65.52% | P2 Win: 34.48% | Pred: P1 ✓ | Strat1: 67.0 | Strat2: 0 | Strat2 Distance: 0.070648 | Requirement Met: ✗
# MLP (LL):    P1 Win: 61.62% | P2 Win: 38.38% | Pred: P1 ✓ | Strat1: 67.0 | Strat2: 0 | Strat2 Distance: 0.031646 | Requirement Met: ✗
# MLP (Err):   P1 Win: 60.61% | P2 Win: 39.39% | Pred: P1 ✓ | Strat1: 67.0 | Strat2: 0 | Strat2 Distance: 0.021553 | Requirement Met: ✗
#
# === Match 49 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.074323 | Winner odds: 1.73 | Loser odds: 2.25 | Margin: 0.022479 | P1 Prob: 0.578035 | P2 Prob: 0.444444
# LogReg:      P1 Win: 55.57% | P2 Win: 44.43% | Pred: P1 ✓ | Strat1: 73.0 | Strat2: 0 | Strat2 Distance: -0.009660 | Requirement Met: ✗
# XGB (LL):    P1 Win: 55.22% | P2 Win: 44.78% | Pred: P1 ✓ | Strat1: 73.0 | Strat2: 0 | Strat2 Distance: -0.013102 | Requirement Met: ✗
# XGB (Err):   P1 Win: 55.02% | P2 Win: 44.98% | Pred: P1 ✓ | Strat1: 73.0 | Strat2: 0 | Strat2 Distance: -0.015176 | Requirement Met: ✗
# MLP (LL):    P1 Win: 58.43% | P2 Win: 41.57% | Pred: P1 ✓ | Strat1: 73.0 | Strat2: 0 | Strat2 Distance: 0.018943 | Requirement Met: ✗
# MLP (Err):   P1 Win: 56.93% | P2 Win: 43.07% | Pred: P1 ✓ | Strat1: 73.0 | Strat2: 0 | Strat2 Distance: 0.004019 | Requirement Met: ✗
#
# === Match 50 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.072428 | Winner odds: 1.52 | Loser odds: 2.74 | Margin: 0.022858 | P1 Prob: 0.657895 | P2 Prob: 0.364964
# LogReg:      P1 Win: 64.26% | P2 Win: 35.74% | Pred: P1 ✓ | Strat1: 52.0 | Strat2: 0 | Strat2 Distance: -0.000636 | Requirement Met: ✗
# XGB (LL):    P1 Win: 60.48% | P2 Win: 39.52% | Pred: P1 ✓ | Strat1: 52.0 | Strat2: 0 | Strat2 Distance: -0.038431 | Requirement Met: ✗
# XGB (Err):   P1 Win: 63.41% | P2 Win: 36.59% | Pred: P1 ✓ | Strat1: 52.0 | Strat2: 0 | Strat2 Distance: -0.009074 | Requirement Met: ✗
# MLP (LL):    P1 Win: 69.37% | P2 Win: 30.63% | Pred: P1 ✓ | Strat1: 52.0 | Strat2: 0 | Strat2 Distance: 0.050482 | Requirement Met: ✗
# MLP (Err):   P1 Win: 66.66% | P2 Win: 33.34% | Pred: P1 ✓ | Strat1: 52.0 | Strat2: 0 | Strat2 Distance: 0.023443 | Requirement Met: ✗
#
# === Match 51 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.078776 | Winner odds: 1.71 | Loser odds: 2.27 | Margin: 0.025324 | P1 Prob: 0.440529 | P2 Prob: 0.584795
# LogReg:      P1 Win: 50.96% | P2 Win: 49.04% | Pred: P1 ✗ | Strat1: -100 | Strat2: -16.14 | Strat2 Distance: 0.079947 | Requirement Met: ✓
# XGB (LL):    P1 Win: 52.58% | P2 Win: 47.42% | Pred: P1 ✗ | Strat1: -100 | Strat2: -18.92 | Strat2 Distance: 0.096198 | Requirement Met: ✓
# XGB (Err):   P1 Win: 50.24% | P2 Win: 49.76% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.072773 | Requirement Met: ✗
# MLP (LL):    P1 Win: 55.83% | P2 Win: 44.17% | Pred: P1 ✗ | Strat1: -100 | Strat2: -24.47 | Strat2 Distance: 0.128644 | Requirement Met: ✓
# MLP (Err):   P1 Win: 51.85% | P2 Win: 48.15% | Pred: P1 ✗ | Strat1: -100 | Strat2: -17.67 | Strat2 Distance: 0.088891 | Requirement Met: ✓
#
# === Match 52 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.059500 | Winner odds: 1.23 | Loser odds: 4.79 | Margin: 0.021776 | P1 Prob: 0.208768 | P2 Prob: 0.813008
# LogReg:      P1 Win: 36.86% | P2 Win: 63.14% | Pred: P2 ✓ | Strat1: 23.0 | Strat2: -22.34 | Strat2 Distance: 0.164318 | Requirement Met: ✓
# XGB (LL):    P1 Win: 24.91% | P2 Win: 75.09% | Pred: P2 ✓ | Strat1: 23.0 | Strat2: 0 | Strat2 Distance: 0.044767 | Requirement Met: ✗
# XGB (Err):   P1 Win: 26.39% | P2 Win: 73.61% | Pred: P2 ✓ | Strat1: 23.0 | Strat2: -9.46 | Strat2 Distance: 0.059561 | Requirement Met: ✓
# MLP (LL):    P1 Win: 36.88% | P2 Win: 63.12% | Pred: P2 ✓ | Strat1: 23.0 | Strat2: -22.36 | Strat2 Distance: 0.164460 | Requirement Met: ✓
# MLP (Err):   P1 Win: 35.16% | P2 Win: 64.84% | Pred: P2 ✓ | Strat1: 23.0 | Strat2: -20.25 | Strat2 Distance: 0.147284 | Requirement Met: ✓
#
# === Match 53 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.073870 | Winner odds: 3.43 | Loser odds: 1.36 | Margin: 0.026839 | P1 Prob: 0.735294 | P2 Prob: 0.291545
# LogReg:      P1 Win: 61.75% | P2 Win: 38.25% | Pred: P1 ✗ | Strat1: -100 | Strat2: 31.19 | Strat2 Distance: -0.098553 | Requirement Met: ✓
# XGB (LL):    P1 Win: 63.16% | P2 Win: 36.84% | Pred: P1 ✗ | Strat1: -100 | Strat2: 26.36 | Strat2 Distance: -0.084462 | Requirement Met: ✓
# XGB (Err):   P1 Win: 62.06% | P2 Win: 37.94% | Pred: P1 ✗ | Strat1: -100 | Strat2: 30.15 | Strat2 Distance: -0.095519 | Requirement Met: ✓
# MLP (LL):    P1 Win: 64.03% | P2 Win: 35.97% | Pred: P1 ✗ | Strat1: -100 | Strat2: 23.37 | Strat2 Distance: -0.075752 | Requirement Met: ✓
# MLP (Err):   P1 Win: 61.78% | P2 Win: 38.22% | Pred: P1 ✗ | Strat1: -100 | Strat2: 31.08 | Strat2 Distance: -0.098236 | Requirement Met: ✓
#
# === Match 54 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.034857 | Winner odds: 1.07 | Loser odds: 12.22 | Margin: 0.016412 | P1 Prob: 0.934579 | P2 Prob: 0.081833
# LogReg:      P1 Win: 92.74% | P2 Win: 7.26% | Pred: P1 ✓ | Strat1: 7.0 | Strat2: 0 | Strat2 Distance: 0.007903 | Requirement Met: ✗
# XGB (LL):    P1 Win: 86.57% | P2 Win: 13.43% | Pred: P1 ✓ | Strat1: 7.0 | Strat2: -7.37 | Strat2 Distance: -0.053766 | Requirement Met: ✓
# XGB (Err):   P1 Win: 87.56% | P2 Win: 12.44% | Pred: P1 ✓ | Strat1: 7.0 | Strat2: -6.31 | Strat2 Distance: -0.043911 | Requirement Met: ✓
# MLP (LL):    P1 Win: 81.97% | P2 Win: 18.03% | Pred: P1 ✓ | Strat1: 7.0 | Strat2: -12.29 | Strat2 Distance: -0.099796 | Requirement Met: ✓
# MLP (Err):   P1 Win: 82.49% | P2 Win: 17.51% | Pred: P1 ✓ | Strat1: 7.0 | Strat2: -11.73 | Strat2 Distance: -0.094572 | Requirement Met: ✓
#
# === Match 55 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.034857 | Winner odds: 1.07 | Loser odds: 12.22 | Margin: 0.016412 | P1 Prob: 0.081833 | P2 Prob: 0.934579
# LogReg:      P1 Win: 25.82% | P2 Win: 74.18% | Pred: P2 ✓ | Strat1: 7.0 | Strat2: -20.62 | Strat2 Distance: 0.177641 | Requirement Met: ✓
# XGB (LL):    P1 Win: 22.86% | P2 Win: 77.14% | Pred: P2 ✓ | Strat1: 7.0 | Strat2: -17.46 | Strat2 Distance: 0.148070 | Requirement Met: ✓
# XGB (Err):   P1 Win: 24.29% | P2 Win: 75.71% | Pred: P2 ✓ | Strat1: 7.0 | Strat2: -18.99 | Strat2 Distance: 0.162375 | Requirement Met: ✓
# MLP (LL):    P1 Win: 21.33% | P2 Win: 78.67% | Pred: P2 ✓ | Strat1: 7.0 | Strat2: -15.83 | Strat2 Distance: 0.132835 | Requirement Met: ✓
# MLP (Err):   P1 Win: 21.93% | P2 Win: 78.07% | Pred: P2 ✓ | Strat1: 7.0 | Strat2: -16.46 | Strat2 Distance: 0.138782 | Requirement Met: ✓
#
# === Match 56 | Actual: P2 Win ===
# ...
# LogReg:      P1 Win: 27.33% | P2 Win: 72.67% | Pred: P2 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: -0.005048 | Requirement Met: ✗
# XGB (LL):    P1 Win: 25.89% | P2 Win: 74.11% | Pred: P2 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: -0.019481 | Requirement Met: ✗
# XGB (Err):   P1 Win: 27.17% | P2 Win: 72.83% | Pred: P2 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: -0.006617 | Requirement Met: ✗
# MLP (LL):    P1 Win: 27.57% | P2 Win: 72.43% | Pred: P2 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: -0.002664 | Requirement Met: ✗
# MLP (Err):   P1 Win: 22.78% | P2 Win: 77.22% | Pred: P2 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: -0.050579 | Requirement Met: ✗
#
# === Match 108 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.061766 | Winner odds: 1.21 | Loser odds: 5.05 | Margin: 0.024466 | P1 Prob: 0.198020 | P2 Prob: 0.826446
# LogReg:      P1 Win: 18.68% | P2 Win: 81.32% | Pred: P2 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: -0.006509 | Requirement Met: ✗
# XGB (LL):    P1 Win: 14.48% | P2 Win: 85.52% | Pred: P2 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: -0.048475 | Requirement Met: ✗
# XGB (Err):   P1 Win: 16.28% | P2 Win: 83.72% | Pred: P2 ✓ | Strat1: 21.0 | Strat2: 0 | Strat2 Distance: -0.030515 | Requirement Met: ✗
# MLP (LL):    P1 Win: 12.28% | P2 Win: 87.72% | Pred: P2 ✓ | Strat1: 21.0 | Strat2: 6.14 | Strat2 Distance: -0.070498 | Requirement Met: ✓
# MLP (Err):   P1 Win: 10.70% | P2 Win: 89.30% | Pred: P2 ✓ | Strat1: 21.0 | Strat2: 8.05 | Strat2 Distance: -0.086247 | Requirement Met: ✓
#
# === Match 109 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.078085 | Winner odds: 2.45 | Loser odds: 1.62 | Margin: 0.025447 | P1 Prob: 0.408163 | P2 Prob: 0.617284
# LogReg:      P1 Win: 37.01% | P2 Win: 62.99% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.027903 | Requirement Met: ✗
# XGB (LL):    P1 Win: 31.57% | P2 Win: 68.43% | Pred: P2 ✗ | Strat1: -100 | Strat2: -22.64 | Strat2 Distance: -0.082299 | Requirement Met: ✓
# XGB (Err):   P1 Win: 32.77% | P2 Win: 67.23% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.070309 | Requirement Met: ✗
# MLP (LL):    P1 Win: 25.52% | P2 Win: 74.48% | Pred: P2 ✗ | Strat1: -100 | Strat2: -37.47 | Strat2 Distance: -0.142808 | Requirement Met: ✓
# MLP (Err):   P1 Win: 28.26% | P2 Win: 71.74% | Pred: P2 ✗ | Strat1: -100 | Strat2: -30.76 | Strat2 Distance: -0.115438 | Requirement Met: ✓
#
# === Match 110 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.053981 | Winner odds: 6.25 | Loser odds: 1.16 | Margin: 0.022069 | P1 Prob: 0.160000 | P2 Prob: 0.862069
# LogReg:      P1 Win: 14.12% | P2 Win: 85.88% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.015318 | Requirement Met: ✗
# XGB (LL):    P1 Win: 12.28% | P2 Win: 87.72% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.033707 | Requirement Met: ✗
# XGB (Err):   P1 Win: 16.88% | P2 Win: 83.12% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.012243 | Requirement Met: ✗
# MLP (LL):    P1 Win: 16.51% | P2 Win: 83.49% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.008595 | Requirement Met: ✗
# MLP (Err):   P1 Win: 11.13% | P2 Win: 88.87% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.045277 | Requirement Met: ✗
#
# === Match 111 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.052537 | Winner odds: 1.15 | Loser odds: 6.57 | Margin: 0.021772 | P1 Prob: 0.869565 | P2 Prob: 0.152207
# LogReg:      P1 Win: 86.73% | P2 Win: 13.27% | Pred: P1 ✓ | Strat1: 15.0 | Strat2: 0 | Strat2 Distance: 0.016311 | Requirement Met: ✗
# XGB (LL):    P1 Win: 86.47% | P2 Win: 13.53% | Pred: P1 ✓ | Strat1: 15.0 | Strat2: 0 | Strat2 Distance: 0.013645 | Requirement Met: ✗
# XGB (Err):   P1 Win: 83.52% | P2 Win: 16.48% | Pred: P1 ✓ | Strat1: 15.0 | Strat2: 0 | Strat2 Distance: -0.015809 | Requirement Met: ✗
# MLP (LL):    P1 Win: 89.87% | P2 Win: 10.13% | Pred: P1 ✓ | Strat1: 15.0 | Strat2: 0 | Strat2 Distance: 0.047697 | Requirement Met: ✗
# MLP (Err):   P1 Win: 87.91% | P2 Win: 12.09% | Pred: P1 ✓ | Strat1: 15.0 | Strat2: 0 | Strat2 Distance: 0.028082 | Requirement Met: ✗
#
# === Match 112 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.045826 | Winner odds: 1.1 | Loser odds: 8.9 | Margin: 0.021450 | P1 Prob: 0.112360 | P2 Prob: 0.909091
# LogReg:      P1 Win: 13.00% | P2 Win: 87.00% | Pred: P2 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: 0.020014 | Requirement Met: ✗
# XGB (LL):    P1 Win: 12.84% | P2 Win: 87.16% | Pred: P2 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: 0.018354 | Requirement Met: ✗
# XGB (Err):   P1 Win: 14.63% | P2 Win: 85.37% | Pred: P2 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: 0.036320 | Requirement Met: ✗
# MLP (LL):    P1 Win: 12.28% | P2 Win: 87.72% | Pred: P2 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: 0.012779 | Requirement Met: ✗
# MLP (Err):   P1 Win: 10.36% | P2 Win: 89.64% | Pred: P2 ✓ | Strat1: 10.0 | Strat2: 0 | Strat2 Distance: -0.006418 | Requirement Met: ✗
#
# === Match 113 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.074526 | Winner odds: 1.45 | Loser odds: 2.98 | Margin: 0.025226 | P1 Prob: 0.689655 | P2 Prob: 0.335570
# LogReg:      P1 Win: 67.90% | P2 Win: 32.10% | Pred: P1 ✓ | Strat1: 45.0 | Strat2: 0 | Strat2 Distance: 0.006267 | Requirement Met: ✗
# XGB (LL):    P1 Win: 66.76% | P2 Win: 33.24% | Pred: P1 ✓ | Strat1: 45.0 | Strat2: 0 | Strat2 Distance: -0.005102 | Requirement Met: ✗
# XGB (Err):   P1 Win: 65.95% | P2 Win: 34.05% | Pred: P1 ✓ | Strat1: 45.0 | Strat2: 0 | Strat2 Distance: -0.013171 | Requirement Met: ✗
# MLP (LL):    P1 Win: 66.66% | P2 Win: 33.34% | Pred: P1 ✓ | Strat1: 45.0 | Strat2: 0 | Strat2 Distance: -0.006122 | Requirement Met: ✗
# MLP (Err):   P1 Win: 65.58% | P2 Win: 34.42% | Pred: P1 ✓ | Strat1: 45.0 | Strat2: 0 | Strat2 Distance: -0.016900 | Requirement Met: ✗
#
# === Match 114 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.065826 | Winner odds: 1.27 | Loser odds: 4.22 | Margin: 0.024368 | P1 Prob: 0.236967 | P2 Prob: 0.787402
# LogReg:      P1 Win: 27.02% | P2 Win: 72.98% | Pred: P2 ✓ | Strat1: 27.0 | Strat2: 0 | Strat2 Distance: 0.038913 | Requirement Met: ✗
# XGB (LL):    P1 Win: 20.14% | P2 Win: 79.86% | Pred: P2 ✓ | Strat1: 27.0 | Strat2: 0 | Strat2 Distance: -0.029963 | Requirement Met: ✗
# XGB (Err):   P1 Win: 22.10% | P2 Win: 77.90% | Pred: P2 ✓ | Strat1: 27.0 | Strat2: 0 | Strat2 Distance: -0.010340 | Requirement Met: ✗
# MLP (LL):    P1 Win: 29.62% | P2 Win: 70.38% | Pred: P2 ✓ | Strat1: 27.0 | Strat2: 0 | Strat2 Distance: 0.064830 | Requirement Met: ✗
# MLP (Err):   P1 Win: 24.89% | P2 Win: 75.11% | Pred: P2 ✓ | Strat1: 27.0 | Strat2: 0 | Strat2 Distance: 0.017555 | Requirement Met: ✗
#
# === Match 115 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.070536 | Winner odds: 1.35 | Loser odds: 3.52 | Margin: 0.024832 | P1 Prob: 0.284091 | P2 Prob: 0.740741
# LogReg:      P1 Win: 34.21% | P2 Win: 65.79% | Pred: P2 ✓ | Strat1: 35.0 | Strat2: 0 | Strat2 Distance: 0.064873 | Requirement Met: ✗
# XGB (LL):    P1 Win: 43.59% | P2 Win: 56.41% | Pred: P2 ✓ | Strat1: 35.0 | Strat2: -23.85 | Strat2 Distance: 0.158733 | Requirement Met: ✓
# XGB (Err):   P1 Win: 42.61% | P2 Win: 57.39% | Pred: P2 ✓ | Strat1: 35.0 | Strat2: -22.52 | Strat2 Distance: 0.148856 | Requirement Met: ✓
# MLP (LL):    P1 Win: 37.91% | P2 Win: 62.09% | Pred: P2 ✓ | Strat1: 35.0 | Strat2: -16.18 | Strat2 Distance: 0.101922 | Requirement Met: ✓
# MLP (Err):   P1 Win: 36.02% | P2 Win: 63.98% | Pred: P2 ✓ | Strat1: 35.0 | Strat2: -13.63 | Strat2 Distance: 0.083037 | Requirement Met: ✓
#
# === Match 116 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.061727 | Winner odds: 1.26 | Loser odds: 4.38 | Margin: 0.021961 | P1 Prob: 0.228311 | P2 Prob: 0.793651
# LogReg:      P1 Win: 14.37% | P2 Win: 85.63% | Pred: P2 ✓ | Strat1: 26.0 | Strat2: 7.89 | Strat2 Distance: -0.079681 | Requirement Met: ✓
# XGB (LL):    P1 Win: 16.13% | P2 Win: 83.87% | Pred: P2 ✓ | Strat1: 26.0 | Strat2: 5.68 | Strat2 Distance: -0.062150 | Requirement Met: ✓
# XGB (Err):   P1 Win: 17.25% | P2 Win: 82.75% | Pred: P2 ✓ | Strat1: 26.0 | Strat2: 0 | Strat2 Distance: -0.050898 | Requirement Met: ✗
# MLP (LL):    P1 Win: 9.69% | P2 Win: 90.31% | Pred: P2 ✓ | Strat1: 26.0 | Strat2: 13.8 | Strat2 Distance: -0.126549 | Requirement Met: ✓
# MLP (Err):   P1 Win: 9.85% | P2 Win: 90.15% | Pred: P2 ✓ | Strat1: 26.0 | Strat2: 13.59 | Strat2 Distance: -0.124888 | Requirement Met: ✓
#
# === Match 117 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.078246 | Winner odds: 2.03 | Loser odds: 1.88 | Margin: 0.024526 | P1 Prob: 0.492611 | P2 Prob: 0.531915
# LogReg:      P1 Win: 43.20% | P2 Win: 56.80% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.048864 | Requirement Met: ✗
# XGB (LL):    P1 Win: 48.68% | P2 Win: 51.32% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.006000 | Requirement Met: ✗
# XGB (Err):   P1 Win: 48.28% | P2 Win: 51.72% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.001983 | Requirement Met: ✗
# MLP (LL):    P1 Win: 51.49% | P2 Win: 48.51% | Pred: P1 ✓ | Strat1: 103.0 | Strat2: 0 | Strat2 Distance: 0.034085 | Requirement Met: ✗
# MLP (Err):   P1 Win: 50.63% | P2 Win: 49.37% | Pred: P1 ✓ | Strat1: 103.0 | Strat2: 0 | Strat2 Distance: 0.025453 | Requirement Met: ✗
#
# === Match 118 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.081529 | Winner odds: 2.01 | Loser odds: 1.89 | Margin: 0.026613 | P1 Prob: 0.529101 | P2 Prob: 0.497512
# LogReg:      P1 Win: 44.61% | P2 Win: 55.39% | Pred: P2 ✓ | Strat1: 101.0 | Strat2: 0 | Strat2 Distance: -0.069316 | Requirement Met: ✗
# XGB (LL):    P1 Win: 46.98% | P2 Win: 53.02% | Pred: P2 ✓ | Strat1: 101.0 | Strat2: 0 | Strat2 Distance: -0.045547 | Requirement Met: ✗
# XGB (Err):   P1 Win: 47.66% | P2 Win: 52.34% | Pred: P2 ✓ | Strat1: 101.0 | Strat2: 0 | Strat2 Distance: -0.038822 | Requirement Met: ✗
# MLP (LL):    P1 Win: 52.89% | P2 Win: 47.11% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.013553 | Requirement Met: ✗
# MLP (Err):   P1 Win: 44.42% | P2 Win: 55.58% | Pred: P2 ✓ | Strat1: 101.0 | Strat2: 0 | Strat2 Distance: -0.071173 | Requirement Met: ✗
#
# === Match 119 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.072648 | Winner odds: 1.36 | Loser odds: 3.44 | Margin: 0.025992 | P1 Prob: 0.735294 | P2 Prob: 0.290698
# LogReg:      P1 Win: 71.27% | P2 Win: 28.73% | Pred: P1 ✓ | Strat1: 36.0 | Strat2: 0 | Strat2 Distance: -0.003929 | Requirement Met: ✗
# XGB (LL):    P1 Win: 73.01% | P2 Win: 26.99% | Pred: P1 ✓ | Strat1: 36.0 | Strat2: 0 | Strat2 Distance: 0.013454 | Requirement Met: ✗
# XGB (Err):   P1 Win: 71.61% | P2 Win: 28.39% | Pred: P1 ✓ | Strat1: 36.0 | Strat2: 0 | Strat2 Distance: -0.000583 | Requirement Met: ✗
# MLP (LL):    P1 Win: 75.10% | P2 Win: 24.90% | Pred: P1 ✓ | Strat1: 36.0 | Strat2: 0 | Strat2 Distance: 0.034343 | Requirement Met: ✗
# MLP (Err):   P1 Win: 73.13% | P2 Win: 26.87% | Pred: P1 ✓ | Strat1: 36.0 | Strat2: 0 | Strat2 Distance: 0.014632 | Requirement Met: ✗
#
# === Match 120 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.077105 | Winner odds: 2.33 | Loser odds: 1.68 | Margin: 0.024423 | P1 Prob: 0.429185 | P2 Prob: 0.595238
# LogReg:      P1 Win: 40.16% | P2 Win: 59.84% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.017322 | Requirement Met: ✗
# XGB (LL):    P1 Win: 41.85% | P2 Win: 58.15% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.000478 | Requirement Met: ✗
# XGB (Err):   P1 Win: 40.71% | P2 Win: 59.29% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.011841 | Requirement Met: ✗
# MLP (LL):    P1 Win: 39.20% | P2 Win: 60.80% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.026929 | Requirement Met: ✗
# MLP (Err):   P1 Win: 35.07% | P2 Win: 64.93% | Pred: P2 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: -0.068243 | Requirement Met: ✗
#
# === Match 121 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.073617 | Winner odds: 2.49 | Loser odds: 1.61 | Margin: 0.022724 | P1 Prob: 0.621118 | P2 Prob: 0.401606
# LogReg:      P1 Win: 67.55% | P2 Win: 32.45% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.068175 | Requirement Met: ✗
# XGB (LL):    P1 Win: 71.22% | P2 Win: 28.78% | Pred: P1 ✗ | Strat1: -100 | Strat2: -28.33 | Strat2 Distance: 0.104848 | Requirement Met: ✓
# XGB (Err):   P1 Win: 67.23% | P2 Win: 32.77% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.064968 | Requirement Met: ✗
# MLP (LL):    P1 Win: 70.96% | P2 Win: 29.04% | Pred: P1 ✗ | Strat1: -100 | Strat2: -27.69 | Strat2 Distance: 0.102274 | Requirement Met: ✓
# MLP (Err):   P1 Win: 68.40% | P2 Win: 31.60% | Pred: P1 ✗ | Strat1: -100 | Strat2: -21.33 | Strat2 Distance: 0.076725 | Requirement Met: ✓
#
# === Match 122 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.074848 | Winner odds: 2.44 | Loser odds: 1.63 | Margin: 0.023333 | P1 Prob: 0.613497 | P2 Prob: 0.409836
# LogReg:      P1 Win: 64.46% | P2 Win: 35.54% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.045049 | Requirement Met: ✗
# XGB (LL):    P1 Win: 76.60% | P2 Win: 23.40% | Pred: P1 ✗ | Strat1: -100 | Strat2: -42.9 | Strat2 Distance: 0.166482 | Requirement Met: ✓
# XGB (Err):   P1 Win: 74.92% | P2 Win: 25.08% | Pred: P1 ✗ | Strat1: -100 | Strat2: -38.8 | Strat2 Distance: 0.149672 | Requirement Met: ✓
# MLP (LL):    P1 Win: 64.54% | P2 Win: 35.46% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.045922 | Requirement Met: ✗
# MLP (Err):   P1 Win: 64.36% | P2 Win: 35.64% | Pred: P1 ✗ | Strat1: -100 | Strat2: 0 | Strat2 Distance: 0.044099 | Requirement Met: ✗
#
# === Match 123 | Actual: P1 Win ===
# Strat 2 requirement threshold: 0.055690 | Winner odds: 1.16 | Loser odds: 6.2 | Margin: 0.023359 | P1 Prob: 0.862069 | P2 Prob: 0.161290
# LogReg:      P1 Win: 83.73% | P2 Win: 16.27% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: -0.005102 | Requirement Met: ✗
# XGB (LL):    P1 Win: 81.87% | P2 Win: 18.13% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: -0.023726 | Requirement Met: ✗
# XGB (Err):   P1 Win: 79.48% | P2 Win: 20.52% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: -0.047634 | Requirement Met: ✗
# MLP (LL):    P1 Win: 87.42% | P2 Win: 12.58% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: 0.031816 | Requirement Met: ✗
# MLP (Err):   P1 Win: 85.08% | P2 Win: 14.92% | Pred: P1 ✓ | Strat1: 16.0 | Strat2: 0 | Strat2 Distance: 0.008437 | Requirement Met: ✗
#
# === Match 124 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.068945 | Winner odds: 1.34 | Loser odds: 3.6 | Margin: 0.024046 | P1 Prob: 0.277778 | P2 Prob: 0.746269
# LogReg:      P1 Win: 27.62% | P2 Win: 72.38% | Pred: P2 ✓ | Strat1: 34.0 | Strat2: 0 | Strat2 Distance: 0.004965 | Requirement Met: ✗
# XGB (LL):    P1 Win: 26.28% | P2 Win: 73.72% | Pred: P2 ✓ | Strat1: 34.0 | Strat2: 0 | Strat2 Distance: -0.008437 | Requirement Met: ✗
# XGB (Err):   P1 Win: 28.56% | P2 Win: 71.44% | Pred: P2 ✓ | Strat1: 34.0 | Strat2: 0 | Strat2 Distance: 0.014393 | Requirement Met: ✗
# MLP (LL):    P1 Win: 29.60% | P2 Win: 70.40% | Pred: P2 ✓ | Strat1: 34.0 | Strat2: 0 | Strat2 Distance: 0.024775 | Requirement Met: ✗
# MLP (Err):   P1 Win: 30.12% | P2 Win: 69.88% | Pred: P2 ✓ | Strat1: 34.0 | Strat2: 0 | Strat2 Distance: 0.029915 | Requirement Met: ✗
#
# === Match 125 | Actual: P2 Win ===
# Strat 2 requirement threshold: 0.062496 | Winner odds: 1.26 | Loser odds: 4.37 | Margin: 0.022484 | P1 Prob: 0.228833 | P2 Prob: 0.793651
# LogReg:      P1 Win: 20.17% | P2 Win: 79.83% | Pred: P2 ✓ | Strat1: 26.0 | Strat2: 0 | Strat2 Distance: -0.022139 | Requirement Met: ✗
# XGB (LL):    P1 Win: 17.20% | P2 Win: 82.80% | Pred: P2 ✓ | Strat1: 26.0 | Strat2: 0 | Strat2 Distance: -0.051806 | Requirement Met: ✗
# XGB (Err):   P1 Win: 18.56% | P2 Win: 81.44% | Pred: P2 ✓ | Strat1: 26.0 | Strat2: 0 | Strat2 Distance: -0.038180 | Requirement Met: ✗
# MLP (LL):    P1 Win: 16.13% | P2 Win: 83.87% | Pred: P2 ✓ | Strat1: 26.0 | Strat2: 5.68 | Strat2 Distance: -0.062515 | Requirement Met: ✓
# MLP (Err):   P1 Win: 12.07% | P2 Win: 87.93% | Pred: P2 ✓ | Strat1: 26.0 | Strat2: 10.79 | Strat2 Distance: -0.103085 | Requirement Met: ✓

# %% [markdown]
# Evaluation criteria for the models and strategies

# %%
results = [] #empty df to hold results in nice format
cum_profs=[] #cumulative profit lists for each model/strategy

#compute metrics for each model/strategy
for i in [log_reg_cum, xgb_ll_cum, xgb_err_cum, mlp_ll_cum, mlp_err_cum, log_reg_cum2, xgb_ll_cum2, xgb_err_cum2, mlp_ll_cum2, mlp_err_cum2]:
    prof_lst=[i['Winnings'][j]-i['Staked'][j] for j in range(len(i['Winnings'])) if i['Staked'][j]>0] #profit list for each game where we placed a bet
    wins_sum=sum([j for j in prof_lst if j>0])
    lose_sum=sum([j for j in prof_lst if j<=0])*-1 #amount lost in total (positive)
    ECE=(sum([abs(i['Prob'][k]-i['Act'][k]) for k in range(len(i['Prob']))]))/len(i['Prob']) #expected calibration error
    cum_prof_lst=[]
    cum_prof=0
    for p in prof_lst: #compute cumulative profit for each model/strategy
        cum_prof+=p
        cum_prof_lst.append(cum_prof)
    cum_profs.append(cum_prof_lst) #store for later
    #max drawdown
    max_drawdown = 0
    peak = cum_prof_lst[0]
    for x in cum_prof_lst:
        if x > peak:
            peak = x
        drawdown = peak - x
        if drawdown > max_drawdown:
            max_drawdown = drawdown
    prof=sum(prof_lst)
    staked=sum(i['Staked'])
    n_bets=len(prof_lst)
    n_wins=len([j for j in prof_lst if j>0])
    avg_prof=prof/n_bets
    volatility=((1/(n_bets-1))*sum([(prof_lst[j]-avg_prof)**2 for j in range(n_bets)]))**0.5
    results.append({
    'Bets': n_bets,
    'Win Rate': n_wins/n_bets * 100,
    'ROI': prof/staked * 100,
    'Avg Profit': avg_prof,
    'Sharpe': avg_prof/volatility,
    'Max Drawdown': max_drawdown,
    'Profit Factor': wins_sum/lose_sum,
    'ECE': ECE*100,
    'Volatility': volatility
    })

model_names = ['LogReg_S1', 'XGB_LL_S1', 'XGB_Err_S1', 'MLP_LL_S1', 'MLP_Err_S1',
               'LogReg_S2', 'XGB_LL_S2', 'XGB_Err_S2', 'MLP_LL_S2', 'MLP_Err_S2']
df_results = pd.DataFrame(results, index=model_names).T
df_results = df_results.round(2) #print results nicely
df_results
# Out:
#                LogReg_S1  XGB_LL_S1  XGB_Err_S1  MLP_LL_S1  MLP_Err_S1  \
# Bets              126.00     126.00      126.00     126.00      126.00
# Win Rate           71.43      71.43       70.63      71.43       73.81
# ROI                -3.21      -4.57       -6.20      -3.75        1.02
# Avg Profit         -3.21      -4.57       -6.20      -3.75        1.02
# Sharpe             -0.05      -0.07       -0.09      -0.06        0.02
# Max Drawdown      541.00     967.00     1065.00     758.00      541.00
# Profit Factor       0.89       0.84        0.79       0.87        1.04
# ECE                37.15      36.94       37.51      36.67       36.70
# Volatility         68.29      65.99       65.85      67.46       67.71
#
#                LogReg_S2  XGB_LL_S2  XGB_Err_S2  MLP_LL_S2  MLP_Err_S2
# Bets               49.00      52.00       53.00      53.00       59.00
# Win Rate           28.57      25.00       22.64      32.08       35.59
# ROI                -2.92      -8.36       -4.71      -5.69       -1.98
# Avg Profit         -2.92      -8.36       -4.71      -5.69       -1.98
# Sharpe             -0.11      -0.42       -0.17      -0.21       -0.07
# Max Drawdown      158.10     430.40      310.14     295.31      258.13
# Profit Factor       0.77       0.38        0.62       0.60        0.84
# ECE                40.66      38.39       37.22      39.94       41.79
# Volatility         27.50      19.73       26.92      27.25       28.42

# %% [markdown]
# While our models did not achieve profitability (except for 1) against Pinnacle's efficient market, a profit factor of over 0.85 for the strongest models demonstrates meaningful predictive power. The models successfully learned patterns that closely approximate professional bookmaker odds using only publicly available data. Closing the remaining 15% gap would likely require proprietary data sources or real-time market information.

# %% [markdown]
# # PLOTS

# %% [markdown]
# Equity curve

# %%
#Strategy 1 equity curves
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

strat1_data = [log_reg_cum, xgb_ll_cum, xgb_err_cum, mlp_ll_cum, mlp_err_cum]
strat1_models = ['LogReg_S1', 'XGB_LL_S1', 'XGB_Err_S1', 'MLP_LL_S1', 'MLP_Err_S1']

for i, name in enumerate(strat1_models):
    axes[0].plot(cum_profs[i], label=name, linewidth=1.5)

axes[0].axhline(y=0, color='black', linewidth=0.8)
axes[0].set_xlabel('Match Number')
axes[0].set_ylabel('Cumulative Profit (£)')
axes[0].set_title('Strategy 1: Equity Curves')
axes[0].legend(loc='lower left')
axes[0].grid(True, alpha=0.3)

# Strategy 2 equity curves
strat2_data = [log_reg_cum2, xgb_ll_cum2, xgb_err_cum2, mlp_ll_cum2, mlp_err_cum2]
strat2_models = ['LogReg_S2', 'XGB_LL_S2', 'XGB_Err_S2', 'MLP_LL_S2', 'MLP_Err_S2']

for i, name in enumerate(strat2_models):
    axes[1].plot(cum_profs[i+5], label=name, linewidth=1.5)

axes[1].axhline(y=0, color='black', linewidth=0.8)
axes[1].set_xlabel('Bet Number')
axes[1].set_ylabel('Cumulative Profit (£)')
axes[1].set_title('Strategy 2: Equity Curves')
axes[1].legend(loc='lower left')
axes[1].grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# Key metrics

# %%
# Metrics to include, we invert ECE since lower is better
metrics = ['ROI', 'Sharpe', 'Win Rate', 'Profit Factor', 'ECE']

fig, axes = plt.subplots(1, 2, figsize=(14, 6), subplot_kw=dict(polar=True))

# Number of metrics
num_metrics = len(metrics)
angles = np.linspace(0, 2 * np.pi, num_metrics, endpoint=False).tolist()
angles += angles[:1]  # Close the loop

# Normalise function (min-max scaling)
def normalise(values, invert=False):
    min_v, max_v = min(values), max(values)
    if max_v == min_v:
        return [0.5] * len(values)
    norm = [(v - min_v) / (max_v - min_v) for v in values]
    if invert:
        norm = [1 - n for n in norm]
    return norm

# Get normalised values for all models
all_models = strat1_models + strat2_models
roi_norm = normalise(df_results.loc['ROI'].values)
sharpe_norm = normalise(df_results.loc['Sharpe'].values)
wr_norm = normalise(df_results.loc['Win Rate'].values)
pf_norm = normalise(df_results.loc['Profit Factor'].values)
ece_norm = normalise(df_results.loc['ECE'].values, invert=True)  # Lower is better

# Strategy 1
for i, model in enumerate(zip(strat1_models)):
    values = [roi_norm[i], sharpe_norm[i], wr_norm[i], pf_norm[i], ece_norm[i]]
    values += values[:1]
    axes[0].plot(angles, values, 'o-', label=model)
    axes[0].fill(angles, values, alpha=0.1)

axes[0].set_xticks(angles[:-1])
axes[0].set_xticklabels(metrics)
axes[0].set_title('Strategy 1: Model Comparison')
axes[0].legend(loc='lower right', bbox_to_anchor=(1.25, 0))

# Strategy 2
for i, model in enumerate(zip(strat2_models)):
    values = [roi_norm[i+5], sharpe_norm[i+5], wr_norm[i+5], pf_norm[i+5], ece_norm[i+5]]
    values += values[:1]
    axes[1].plot(angles, values, 'o-', label=model)
    axes[1].fill(angles, values, alpha=0.1)

axes[1].set_xticks(angles[:-1])
axes[1].set_xticklabels(metrics)
axes[1].set_title('Strategy 2: Model Comparison')
axes[1].legend(loc='upper right', bbox_to_anchor=(1.3, 1))

plt.show()

# %% [markdown]
# Calib curve

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Strategy 1
for data, name in zip(strat1_data, strat1_models):
    prob_true, prob_pred = calibration_curve(data['Act'], data['Prob'], n_bins=10)
    axes[0].plot(prob_pred, prob_true, label=name, linewidth=1.5, marker='o')

axes[0].plot([0,1], [0,1], 'k--')
axes[0].set_xlabel('Predicted Probability')
axes[0].set_ylabel('Actual Win Rate')
axes[0].set_title('Strategy 1: Calibration Plot')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Strategy 2
for data, name in zip(strat2_data, strat2_models):
    prob_true, prob_pred = calibration_curve(data['Act'], data['Prob'], n_bins=10)
    axes[1].plot(prob_pred, prob_true, label=name, linewidth=1.5, marker='o')

axes[1].plot([0,1], [0,1], 'k--')
axes[1].set_xlabel('Predicted Probability')
axes[1].set_ylabel('Actual Win Rate')
axes[1].set_title('Strategy 2: Calibration Plot')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# Threshold Distances for strategy 2
# Model mostly agrees with Pinnacle, lack of edge due to small differences and it being wrong more than right on these ones. Few high conviction bets.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Threshold vs Distance scatter
for data, name in zip(strat2_data, strat2_models):
    axes[0].scatter(data['Thresh'], data['Dist'], label=name)
    max_thresh = max(data['Thresh'])

axes[0].plot([0, max_thresh], [0, max_thresh], 'k--', label='Threshold line')
axes[0].set_xlabel('Required Threshold')
axes[0].set_ylabel('Actual Distance |p - q̂|')
axes[0].set_title('Strategy 2: Threshold vs Distance')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Plot 2: Histogram of distances with threshold overlay
for data, name in zip(strat2_data, strat2_models):
    axes[1].hist(data['Dist'], bins=15, alpha=0.4, label=name)

avg_thresh = sum(strat2_data[0]['Thresh']) / len(strat2_data[0]['Thresh'])
axes[1].axvline(x=avg_thresh, color='black', label=f'Avg Threshold ({avg_thresh:.3f})')
axes[1].set_xlabel('Distance |p - q̂|')
axes[1].set_ylabel('Frequency')
axes[1].set_title('Strategy 2: Distribution of Model Distances')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# Confusion matrices

# %%
fig, axes = plt.subplots(2, 5, figsize=(20, 8))

# Strategy 1
for i, (data, name) in enumerate(zip(strat1_data, strat1_models)):
    preds = [1 if p >= 0.5 else 0 for p in data['Prob']]
    cm = confusion_matrix(data['Act'], preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[0, i], cbar=False)
    axes[0, i].set_ylabel('Actual')
    axes[0, i].set_title(f'S1: {name}')

# Strategy 2
for i, (data, name) in enumerate(zip(strat2_data, strat2_models)):
    preds = [1 if p >= 0.5 else 0 for p in data['Prob']]
    cm = confusion_matrix(data['Act'], preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges', ax=axes[1, i], cbar=False)
    axes[1, i].set_xlabel('Predicted')
    axes[1, i].set_ylabel('Actual')
    axes[1, i].set_title(f'S2: {name}')


plt.show()

# %% [markdown]
# Profit distribution

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Strategy 1
for data, name in zip(strat1_data, strat1_models):
    profits = [data['Winnings'][i] - data['Staked'][i] for i in range(len(data['Winnings']))]
    axes[0].hist(profits, bins=20, alpha=0.4, label=name)

axes[0].axvline(x=0, color='black')
axes[0].set_xlabel('Profit (£)')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Strategy 1: Profit Distribution')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Strategy 2
for data, name in zip(strat2_data, strat2_models):
    profits = [data['Winnings'][i] - data['Staked'][i] for i in range(len(data['Winnings'])) if data['Staked'][i] > 0] #only look at when we placed a bet
    axes[1].hist(profits, bins=20, alpha=0.4, label=name)

axes[1].axvline(x=0, color='black')
axes[1].set_xlabel('Profit (£)')
axes[1].set_ylabel('Frequency')
axes[1].set_title('Strategy 2: Profit Distribution')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.show()
